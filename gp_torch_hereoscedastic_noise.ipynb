# %% [markdown]
# Torch Implementation of GP
#
# Inspired by: https://docs.gpytorch.ai/en/stable/examples/01_Exact_GPs/Simple_GP_Regression.html

# %%
import math
import torch
import gpytorch
from matplotlib import pyplot as plt
import time

from data import Dataprep, update_data, load_data
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns

import pandas as pd


# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
dataset_type='Generated_2000'
sensor='foundation_origin xy FloaterOffset [m]'
samples_per_step=10
validation_size=0.1

# %%
data = Dataprep(dataset_type, sensor, initial_samplesize=samples_per_step)
known_data, pool_data = data.known_data, data.pool_data

# %% [markdown]
# Load Data and Normalize

# %%
# Define a GP model for predicting the noise variance
class NoiseModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super(NoiseModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = gpytorch.means.ConstantMean()
        self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel())

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

class HeteroscedasticGaussianLikelihood(gpytorch.likelihoods.GaussianLikelihood):
    def __init__(self, noise_model):
        super(HeteroscedasticGaussianLikelihood, self).__init__()
        self.noise_model = noise_model

    def forward(self, function_samples, **kwargs):
        # We still get the inputs from kwargs
        inputs = kwargs.get('inputs')
        # Get the predictive noise variance from the noise model
        noise = self.noise_model(inputs).mean.exp()
        # Use the predicted noise as the variance for the MultivariateNormal
        return gpytorch.distributions.MultivariateNormal(function_samples, noise.diag_embed())




# Assume we have a training set with inputs `train_x` and targets `train_y`
train_x = torch.rand(100, 1)
train_y = torch.sin(train_x * (2 * math.pi)) + torch.randn(train_x.size()) * 0.2

# Initialize the noise model and its likelihood
noise_likelihood = gpytorch.likelihoods.GaussianLikelihood()
noise_model = NoiseModel(train_x, torch.log(train_y.var() * torch.ones_like(train_y)), noise_likelihood)

# Initialize the main GP model
class GPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super(GPModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = gpytorch.means.ConstantMean()

        # Assuming you have an RBFKernel instance named `rbf_kernel`:
        rbf_kernel = gpytorch.kernels.RBFKernel()
        # To set an initial length scale:
        rbf_kernel.lengthscale = 0.1
        # kernel can be changed or combined !
        self.covar_module = gpytorch.kernels.ScaleKernel(rbf_kernel)

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

# %%
from torch.optim import Adam

# %%
def init_optimizer(learning_rate,model):
    optimizer = Adam(model.parameters(), lr=learning_rate)
    return optimizer
    
def train_model(step, learning_rate):
    print('K_D, P_D', known_data.shape, pool_data.shape)

    # Split the pool data into train and validation sets
    train, val = train_test_split(known_data, test_size=validation_size)

    X_train = torch.tensor(scaler.fit_transform(train[:, 0].reshape(-1, 1))).to(device)  # Adds an extra dimension to make X_train a 2D tensor
    y_train = torch.tensor(train[:, 1]).to(device)
    
    # Initialize likelihood and model with training data
    likelihood = gpytorch.likelihoods.GaussianLikelihood().to(device)

    # Assuming you have a GaussianLikelihood instance named `likelihood`:
    likelihood = gpytorch.likelihoods.GaussianLikelihood()

    # To set an initial noise level:
    likelihood.noise = 0.01

    model = GPModel(X_train, y_train, likelihood).to(device)
    
    optimizer = init_optimizer(learning_rate,model) # Initialize the optimizer

    model.train()
    likelihood.train()

    mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)
    total_train_loss = 0

    x, y = X_train, y_train

    # Find optimal model hyperparameters
    model.train()
    likelihood.train()

    # Use the adam optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr=0.1)  # Includes GaussianLikelihood parameters

    # "Loss" for GPs - the marginal log likelihood
    mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

    for epoch in range(epochs):
        # Zero gradients from previous iteration
        optimizer.zero_grad()
        # Output from model
        output = model(X_train)
        # Calc loss and backprop gradients
        loss = -mll(output, y_train)
        loss.backward()
        print('Epoch %d/%d - Loss: %.3f   lengthscale: %.3f   noise: %.3f' % (
            epoch +1, epochs, loss.item(),
            model.covar_module.base_kernel.lengthscale.item(),
            model.likelihood.noise.item()
        ))
        optimizer.step()

    preds = evaluate_model(likelihood, model,val, step, mll) # Evaluate the model on the validation set

    return preds

# %%
def evaluate_model(likelihood, model, val, step, mll): # 1: EVALUATE THE MODEL ON THE VALIDATION SET

    X_val = torch.tensor(scaler.fit_transform(val[:, 0].reshape(-1, 1))).to(device)  # Adds an extra dimension to make X_train a 2D tensor
    y_val = torch.tensor(val[:, 1]).to(device)
    x, y = X_val, y_val
    # Get into evaluation (predictive posterior) mode
    model.eval()
    likelihood.eval()

    total_val_loss = 0
    # Make predictions by feeding model through likelihood
    with torch.no_grad(), gpytorch.settings.fast_pred_var():
        test_x = torch.linspace(0, 1, 51)
        observed_pred = likelihood(model(X_val))
        output = model(X_val)
        loss = -mll(output, y_val)
        total_val_loss += loss.item()

    step_val_loss = total_val_loss  # Average loss over batches
    writer.add_scalar('loss/val', step_val_loss, step+1)
    if verbose:
        print('Step: {}, Val-Loss: {:.4f}'.format(step+1, step_val_loss))

    if known_data.shape[1] == 2:
        preds = plot(likelihood, model, step)
    return preds

# %%
def plot(likelihood, model, step, samples=500):
    x_pool = pool_data[:, :-1]
    y_pool = pool_data[:, -1]

    x_selected = known_data[:, :-1]
    y_selected = known_data[:, -1]

    scaler = MinMaxScaler()
    x_pool_scaled = scaler.fit_transform(x_pool)
    x_selected_scaled = scaler.transform(x_selected)
    
    x_pool_torch = torch.tensor(x_pool_scaled) 

    model.eval()
    likelihood.eval()

    # Make predictions by feeding model through likelihood
    with torch.no_grad(), gpytorch.settings.fast_pred_var():
        preds = likelihood(model(x_pool_torch))

    means = preds.mean.numpy()  # calculate the mean of the predictions
    lower, upper = preds.confidence_region()
    stds = preds.stddev.numpy()
    
    # Prepare data for plotting
    #df = pd.DataFrame({'x': x_pool_torch.squeeze(), 'mean': means.squeeze(), 'lower': lower, 'upper': upper})

    dfs = []
    y_vals = [means, means + 2 * stds, means - 2 * stds]

    for i in range(3): #len(y_vals)
        dfs.append(pd.DataFrame({'x': x_pool_torch.squeeze(), 'y': y_vals[i].squeeze()}))
    df = pd.concat(dfs)

    print(means.squeeze())
    
    # Plotting
    fig = plt.figure()
    sns.lineplot(data=df, x="x", y="y")
    plt.scatter(x_pool_scaled, y_pool, c="green", marker="*", alpha=0.1)  # Plot actual y values
    plt.scatter(x_selected_scaled, y_selected, c="red", marker="*", alpha=0.2) # plot train data on top
    plt.title(f'Predictions vs Actual Step {step+1}')
    plt.legend(['Mean prediction', 'Pool data (unseen)', 'Seen data'], fontsize='small')
    plt.close(fig)

    # Log the table figure
    writer.add_figure(f'Prediction vs Actual Table Epoch {step+1}', fig, step+1)

    # Log the table figure
    writer.add_figure(f'Prediction vs Actual Table Epoch {step+1}', fig, step+1)

    return preds

# %%
import random

# %%
def predict(self, x): # 2: PREDICT THE UNCERTAINTY ON THE POOL DATA
        pass

def acquisition_function(n, pool_data=pool_data, known_data=known_data): # 3: DECIDE WHICH SAMPLES TO SELECT FROM THE POOL DATA (USING ACQUISITION FUNCTION)
    selected_indices = random.sample(range(len(pool_data)), n)
    known_data, pool_data = update_data(known_data, pool_data, selected_indices)

    return known_data, pool_data

# %%
data = Dataprep(dataset_type, sensor, initial_samplesize=samples_per_step)
known_data, pool_data = data.known_data, data.pool_data

# %%
from torch.utils.tensorboard import SummaryWriter
import datetime
import os

# %%
steps = 10
learning_rate = 0.01
epochs = 150
verbose=True
current_time = datetime.datetime.now().strftime("%Y%m%d-%H%M%S") # Unique directory based on datetime for each run
log_dir = os.path.join('Models/runs', 'BNN_' + dataset_type  + '_' + current_time)
writer = SummaryWriter(log_dir) 
scaler = MinMaxScaler()

device = torch.device("cpu" if torch.backends.mps.is_available() else "cpu")

# %%
known_data, pool_data = data.known_data, data.pool_data

# %%
# Train the model
for step in range(steps):
    start_step = time.time()
    preds = train_model(step,learning_rate) # Train the model
    print('Step: {} of {}, time-taken: {:.2f} seconds'.format(step+1, steps, time.time() - start_step))
    known_data, pool_data = acquisition_function(samples_per_step, pool_data, known_data) # Select the next samples from the pool
# Out:
# K_D, P_D (10, 2) (1990, 2)
# Epoch 1/150 - Loss: 0.645   lengthscale: 0.100   noise: 0.010
# Epoch 2/150 - Loss: 0.631   lengthscale: 0.110   noise: 0.009
# Epoch 3/150 - Loss: 0.620   lengthscale: 0.121   noise: 0.009
# Epoch 4/150 - Loss: 0.618   lengthscale: 0.131   noise: 0.010
# Epoch 5/150 - Loss: 0.619   lengthscale: 0.139   noise: 0.010
# Epoch 6/150 - Loss: 0.618   lengthscale: 0.142   noise: 0.011
# Epoch 7/150 - Loss: 0.615   lengthscale: 0.142   noise: 0.012
# Epoch 8/150 - Loss: 0.613   lengthscale: 0.140   noise: 0.013
# Epoch 9/150 - Loss: 0.612   lengthscale: 0.137   noise: 0.014
# Epoch 10/150 - Loss: 0.612   lengthscale: 0.135   noise: 0.015
# Epoch 11/150 - Loss: 0.612   lengthscale: 0.134   noise: 0.016
# Epoch 12/150 - Loss: 0.612   lengthscale: 0.135   noise: 0.017
# Epoch 13/150 - Loss: 0.612   lengthscale: 0.137   noise: 0.017
# Epoch 14/150 - Loss: 0.612   lengthscale: 0.140   noise: 0.017
# Epoch 15/150 - Loss: 0.611   lengthscale: 0.144   noise: 0.017
# Epoch 16/150 - Loss: 0.610   lengthscale: 0.149   noise: 0.017
# Epoch 17/150 - Loss: 0.610   lengthscale: 0.152   noise: 0.016
# Epoch 18/150 - Loss: 0.610   lengthscale: 0.155   noise: 0.016
# Epoch 19/150 - Loss: 0.610   lengthscale: 0.155   noise: 0.015
150 - Loss: 0.608   lengthscale: 0.145   noise: 0.014
# Epoch 150/150 - Loss: 0.608   lengthscale: 0.145   noise: 0.014
# Step: 1, Val-Loss: -0.4221
# [ 0.02371837 -0.56052244  0.08204491 ... -0.24396826 -0.13028331
#   0.02967511]
# Step: 1 of 10, time-taken: 13.16 seconds
# K_D, P_D (20, 2) (1980, 2)
# Epoch 1/150 - Loss: 0.256   lengthscale: 0.100   noise: 0.010
# Epoch 2/150 - Loss: 0.200   lengthscale: 0.091   noise: 0.009
# Epoch 3/150 - Loss: 0.180   lengthscale: 0.083   noise: 0.008
# Epoch 4/150 - Loss: 0.179   lengthscale: 0.078   noise: 0.008
# Epoch 5/150 - Loss: 0.180   lengthscale: 0.075   noise: 0.007
# Epoch 6/150 - Loss: 0.174   lengthscale: 0.073   noise: 0.006
# Epoch 7/150 - Loss: 0.164   lengthscale: 0.073   noise: 0.006
# Epoch 8/150 - Loss: 0.153   lengthscale: 0.074   noise: 0.005
# Epoch 9/150 - Loss: 0.146   lengthscale: 0.076   noise: 0.005
# Epoch 10/150 - Loss: 0.143   lengthscale: 0.078   noise: 0.004
# Epoch 11/150 - Loss: 0.146   lengthscale: 0.079   noise: 0.004
# Epoch 12/150 - Loss: 0.151   lengthscale: 0.080   noise: 0.004
# Epoch 13/150 - Loss: 0.153   lengthscale: 0.080   noise: 0.004
# Epoch 14/150 - Loss: 0.152   lengthscale: 0.079   noise: 0.003
# Epoch 15/150 - Loss: 0.149   lengthscale: 0.077   noise: 0.003
# Epoch 16/150 - Loss: 0.147   lengthscale: 0.076   noise: 0.003
# Epoch 17/150 - Loss: 0.146   lengthscale: 0.074   noise: 0.003
# Epoch 18/150 - Loss: 0.146   lengthscale: 0.072   noise: 0.003
# Epoch 19/150 - Loss: 0.147   lengthscale: 0.070   noise: 0.003
# Epoch 20/150 - Loss: 0.148   lengthscale: 0.069   noise: 0.003
# Epoch 21/150 - Loss: 0.149   lengthscale: 0.069   noise: 0.003
# Epoch 22/150 - Loss: 0.149   lengthscale: 0.069   noise: 0.003
# Epoch 23/150 - Loss: 0.148   lengthscale: 0.069   noise: 0.003
# Epoch 24/150 - Loss: 0.148   lengthscale: 0.069   noise: 0.003
# Epoch 25/150 - Loss: 0.147   lengthscale: 0.070   noise: 0.003
# Epoch 26/150 - Loss: 0.146   lengthscale: 0.071   noise: 0.003
# Epoch 27/150 - Loss: 0.145   lengthscale: 0.072   noise: 0.003
# Epoch 28/150 - Loss: 0.145   lengthscale: 0.073   noise: 0.003
# Epoch 29/150 - Loss: 0.145   lengthscale: 0.074   noise: 0.003
# Epoch 30/150 - Loss: 0.145   lengthscale: 0.075   noise: 0.003
# Epoch 31/150 - Loss: 0.145   lengthscale: 0.076   noise: 0.004
# Epoch 32/150 - Loss: 0.145   lengthscale: 0.076   noise: 0.004
# Epoch 33/150 - Loss: 0.144   lengthscale: 0.076   noise: 0.004
# Epoch 34/150 - Loss: 0.143   lengthscale: 0.076   noise: 0.004
# Epoch 35/150 - Loss: 0.143   lengthscale: 0.076   noise: 0.004
# Epoch 36/150 - Loss: 0.143   lengthscale: 0.076   noise: 0.004
# Epoch 37/150 - Loss: 0.143   lengthscale: 0.075   noise: 0.004
# Epoch 38/150 - Loss: 0.143   lengthscale: 0.076   noise: 0.004
# Epoch 39/150 - Loss: 0.143   lengthscale: 0.076   noise: 0.004
# Epoch 40/150 - Loss: 0.143   lengthscale: 0.076   noise: 0.004
# Epoch 41/150 - Loss: 0.143   lengthscale: 0.077   noise: 0.004
# Epoch 42/150 - Loss: 0.143   lengthscale: 0.077   noise: 0.004
# Epoch
# Epoch 7/150 - Loss: 0.121   lengthscale: 0.170   noise: 0.018
# Epoch 8/150 - Loss: 0.112   lengthscale: 0.177   noise: 0.019
# Epoch 9/150 - Loss: 0.101   lengthscale: 0.179   noise: 0.021
# Epoch 10/150 - Loss: 0.087   lengthscale: 0.177   noise: 0.023
# Epoch 11/150 - Loss: 0.075   lengthscale: 0.173   noise: 0.024
# Epoch 12/150 - Loss: 0.067   lengthscale: 0.168   noise: 0.026
# Epoch 13/150 - Loss: 0.064   lengthscale: 0.163   noise: 0.028
# Epoch 14/150 - Loss: 0.065   lengthscale: 0.159   noise: 0.029
# Epoch 15/150 - Loss: 0.068   lengthscale: 0.155   noise: 0.031
# Epoch 16/150 - Loss: 0.072   lengthscale: 0.153   noise: 0.032
# Epoch 17/150 - Loss: 0.075   lengthscale: 0.152   noise: 0.033
# Epoch 18/150 - Loss: 0.078   lengthscale: 0.152   noise: 0.034
# Epoch 19/150 - Loss: 0.079   lengthscale: 0.154   noise: 0.035
# Epoch 20/150 - Loss: 0.079   lengthscale: 0.156   noise: 0.036
# Epoch 21/150 - Loss: 0.078   lengthscale: 0.159   noise: 0.036
# Epoch 22/150 - Loss: 0.078   lengthscale: 0.163   noise: 0.036
# Epoch 23/150 - Loss: 0.077   lengthscale: 0.167   noise: 0.036
# Epoch 24/150 - Loss: 0.077   lengthscale: 0.172   noise: 0.036
# Epoch 25/150 - Loss: 0.076   lengthscale: 0.175   noise: 0.036
# Epoch 26/150 - Loss: 0.076   lengthscale: 0.178   noise: 0.036
# Epoch 27/150 - Loss: 0.076   lengthscale: 0.180   noise: 0.035
# Epoch 28/150 - Loss: 0.075   lengthscale: 0.181   noise: 0.035
# Epoch 29/150 - Loss: 0.073   lengthscale: 0.181   noise: 0.034
# Epoch 30/150 - Loss: 0.071   lengthscale: 0.180   noise: 0.033
# Epoch 31/150 - Loss: 0.069   lengthscale: 0.178   noise: 0.033
# Epoch 32/150 - Loss: 0.067   lengthscale: 0.175   noise: 0.032
# Epoch 33/150 - Loss: 0.065   lengthscale: 0.173   noise: 0.031
# Epoch 34/150 - Loss: 0.065   lengthscale: 0.171   noise: 0.031
# Epoch 35/150 - Loss: 0.064   lengthscale: 0.169   noise: 0.030
# Epoch 36/150 - Loss: 0.064   lengthscale: 0.168   noise: 0.029
# Epoch 37/150 - Loss: 0.063   lengthscale: 0.167   noise: 0.028
# Epoch 38/150 - Loss: 0.063   lengthscale: 0.168   noise: 0.028
# Epoch 39/150 - Loss: 0.062   lengthscale: 0.169   noise: 0.027
# Epoch 40/150 - Loss: 0.062   lengthscale: 0.170   noise: 0.027
# Epoch 41/150 - Loss: 0.062   lengthscale: 0.172   noise: 0.026
# Epoch 42/150 - Loss: 0.062   lengthscale: 0.173   noise: 0.026
# Epoch 43/150 - Loss: 0.062   lengthscale: 0.175   noise: 0.026
# Epoch 44/150 - Loss: 0.063   lengthscale: 0.176   noise: 0.025
# Epoch 45/150 - Loss: 0.063   lengthscale: 0.176   noise: 0.025
150 - Loss: 0.062   lengthscale: 0.171   noise: 0.027
# Epoch 150/150 - Loss: 0.062   lengthscale: 0.171   noise: 0.027
# Step: 4, Val-Loss: 2.9001
# [ 0.05451413 -0.7663949   0.13390681 ... -0.40821794 -0.1577073
#  -0.02207474]
# Step: 4 of 10, time-taken: 12.63 seconds
# K_D, P_D (50, 2) (1950, 2)
# Epoch 1/150 - Loss: 1.292   lengthscale: 0.100   noise: 0.010
# Epoch 2/150 - Loss: 1.113   lengthscale: 0.110   noise: 0.011
# Epoch 3/150 - Loss: 0.954   lengthscale: 0.121   noise: 0.012
# Epoch 4/150 - Loss: 0.816   lengthscale: 0.133   noise: 0.013
# Epoch 5/150 - Loss: 0.700   lengthscale: 0.146   noise: 0.015
# Epoch 6/150 - Loss: 0.604   lengthscale: 0.159   noise: 0.016
# Epoch 7/150 - Loss: 0.529   lengthscale: 0.173   noise: 0.018
# Epoch 8/150 - Loss: 0.473   lengthscale: 0.185   noise: 0.019
# Epoch 9/150 - Loss: 0.430   lengthscale: 0.195   noise: 0.021
# Epoch 10/150 - Loss: 0.391   lengthscale: 0.199   noise: 0.023
# Epoch 11/150 - Loss: 0.352   lengthscale: 0.199   noise: 0.025
# Epoch 12/150 - Loss: 0.317   lengthscale: 0.195   noise: 0.027
# Epoch 13/150 - Loss: 0.287   lengthscale: 0.190   noise: 0.029
# Epoch 14/150 - Loss: 0.264   lengthscale: 0.185   noise: 0.031
# Epoch 15/150 - Loss: 0.247   lengthscale: 0.179   noise: 0.034
# Epoch 16/150 - Loss: 0.236   lengthscale: 0.174   noise: 0.036
# Epoch 17/150 - Loss: 0.228   lengthscale: 0.169   noise: 0.038
# Epoch 18/150 - Loss: 0.224   lengthscale: 0.166   noise: 0.040
# Epoch 19/150 - Loss: 0.221   lengthscale: 0.164   noise: 0.042
# Epoch 20/150 - Loss: 0.219   lengthscale: 0.163   noise: 0.045
# Epoch 21/150 - Loss: 0.218   lengthscale: 0.163   noise: 0.047
# Epoch 22/150 - Loss: 0.217   lengthscale: 0.164   noise: 0.049
# Epoch 23/150 - Loss: 0.216   lengthscale: 0.166   noise: 0.050
# Epoch 24/150 - Loss: 0.216   lengthscale: 0.169   noise: 0.052
# Epoch 25/150 - Loss: 0.215   lengthscale: 0.173   noise: 0.054
# Epoch 26/150 - Loss: 0.216   lengthscale: 0.176   noise: 0.055
# Epoch 27/150 - Loss: 0.216   lengthscale: 0.180   noise: 0.056
# Epoch 28/150 - Loss: 0.217   lengthscale: 0.185   noise: 0.058
# Epoch 29/150 - Loss: 0.218   lengthscale: 0.188   noise: 0.059
# Epoch 30/150 - Loss: 0.220   lengthscale: 0.192   noise: 0.060
# Epoch 31/150 - Loss: 0.221   lengthscale: 0.194   noise: 0.060
# Epoch 32/150 - Loss: 0.223   lengthscale: 0.196   noise: 0.061
# Epoch 33/150 - Loss: 0.223   lengthscale: 0.197   noise: 0.061
# Epoch 34/150 - Loss: 0.224   lengthscale: 0.197   noise: 0.062
# Epoch 35/150 - Loss: 0.224   lengthscale: 0.196   noise: 0.062
# Epoch 36/150 - Loss: 0.224   lengthscale: 0.195   noise: 0.062
# Epoch 37/150 - Loss: 0.223   lengthscale: 0.193   noise: 0.062
# Epoch 38/150 - Loss: 0.223   lengthscale: 0.191   noise: 0.062
# Epoch 66/150 - Loss: 0.290   lengthscale: 0.174   noise: 0.078
# Epoch 67/150 - Loss: 0.290   lengthscale: 0.174   noise: 0.077
# Epoch 68/150 - Loss: 0.290   lengthscale: 0.174   noise: 0.077
# Epoch 69/150 - Loss: 0.290   lengthscale: 0.174   noise: 0.076
# Epoch 70/150 - Loss: 0.290   lengthscale: 0.174   noise: 0.076
# Epoch 71/150 - Loss: 0.289   lengthscale: 0.174   noise: 0.076
# Epoch 72/150 - Loss: 0.289   lengthscale: 0.173   noise: 0.075
# Epoch 73/150 - Loss: 0.289   lengthscale: 0.173   noise: 0.075
# Epoch 74/150 - Loss: 0.289   lengthscale: 0.173   noise: 0.075
# Epoch 75/150 - Loss: 0.289   lengthscale: 0.173   noise: 0.074
# Epoch 76/150 - Loss: 0.289   lengthscale: 0.173   noise: 0.074
# Epoch 77/150 - Loss: 0.289   lengthscale: 0.172   noise: 0.074
# Epoch 78/150 - Loss: 0.289   lengthscale: 0.172   noise: 0.073
# Epoch 79/150 - Loss: 0.289   lengthscale: 0.172   noise: 0.073
# Epoch 80/150 - Loss: 0.289   lengthscale: 0.171   noise: 0.073
# Epoch 81/150 - Loss: 0.289   lengthscale: 0.171   noise: 0.073
# Epoch 82/150 - Loss: 0.289   lengthscale: 0.171   noise: 0.072
# Epoch 83/150 - Loss: 0.289   lengthscale: 0.170   noise: 0.072
# Epoch 84/150 - Loss: 0.289   lengthscale: 0.170   noise: 0.072
# Epoch 85/150 - Loss: 0.289   lengthscale: 0.169   noise: 0.072
# Epoch 86/150 - Loss: 0.289   lengthscale: 0.169   noise: 0.072
# Epoch 87/150 - Loss: 0.289   lengthscale: 0.168   noise: 0.072
# Epoch 88/150 - Loss: 0.289   lengthscale: 0.168   noise: 0.071
# Epoch 89/150 - Loss: 0.289   lengthscale: 0.168   noise: 0.071
# Epoch 90/150 - Loss: 0.289   lengthscale: 0.168   noise: 0.071
# Epoch 91/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.071
# Epoch 92/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.071
# Epoch 93/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.071
# Epoch 94/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.071
# Epoch 95/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.071
# Epoch 96/150 - Loss: 0.289   lengthscale: 0.166   noise: 0.071
# Epoch 97/150 - Loss: 0.289   lengthscale: 0.166   noise: 0.071
# Epoch 98/150 - Loss: 0.289   lengthscale: 0.166   noise: 0.071
# Epoch 99/150 - Loss: 0.289   lengthscale: 0.166   noise: 0.071
# Epoch 100/150 - Loss: 0.289   lengthscale: 0.166   noise: 0.071
# Epoch 101/150 - Loss: 0.289   lengthscale: 0.166   noise: 0.071
# Epoch 102/150 - Loss: 0.289   lengthscale: 0.166   noise: 0.071
# Epoch 103/150 - Loss: 0.289   lengthscale: 0.166   noise: 0.071
# Epoch 104/150 - Loss: 0.289   lengthscale: 0.166   noise: 0.071
# Epoch 105/150 - Loss: 0.289   lengthscale: 0.166   noise: 0.071
# Epoch 106/150 - Loss: 0.289   lengthscale: 0.166   noise: 0.071
# Epoch 107/150 - Loss: 0.289   lengthscale: 0.166   noise: 0.071
# Epoch 108/150 - Loss: 0.289   lengthscale: 0.166   noise: 0.071
# Epoch 109/150 - Loss: 0.289   lengthscale: 0.166   noise: 0.071
# Epoch 110/150 - Loss: 0.289   lengthscale: 0.166   noise: 0.071
# Epoch 111/150 - Loss: 0.289   lengthscale: 0.166   noise: 0.071
# Epoch 112/150 - Loss: 0.289   lengthscale: 0.166   noise: 0.071
# Epoch 113/150 - Loss: 0.289   lengthscale: 0.166   noise: 0.071
# Epoch 114/150 - Loss: 0.289   lengthscale: 0.166   noise: 0.071
# Epoch 115/150 - Loss: 0.289   lengthscale: 0.166   noise: 0.071
# Epoch 116/150 - Loss: 0.289   lengthscale: 0.166   noise: 0.071
# Epoch 117/150 - Loss: 0.289   lengthscale: 0.166   noise: 0.071
# Epoch 118/150 - Loss: 0.289   lengthscale: 0.166   noise: 0.071
# Epoch 119/150 - Loss: 0.289   lengthscale: 0.166   noise: 0.071
# Epoch 120/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.071
# Epoch 121/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.071
# Epoch 122/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.071
# Epoch 123/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.071
# Epoch 124/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.071
# Epoch 125/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.071
# Epoch 126/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.071
# Epoch 127/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.071
# Epoch 128/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.071
# Epoch 129/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.071
# Epoch 130/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.071
# Epoch 131/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.071
# Epoch 132/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.071
# Epoch 133/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.071
# Epoch 134/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.071
# Epoch 135/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.071
# Epoch 136/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.072
# Epoch 137/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.072
# Epoch 138/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.072
# Epoch 139/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.072
# Epoch 140/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.072
# Epoch 141/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.072
# Epoch 142/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.072
# Epoch 143/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.072
# Epoch 144/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.072
# Epoch 145/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.072
# Epoch 146/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.072
# Epoch 147/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.072
# Epoch 148/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.072
# Epoch 149/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.072
# Epoch 150/150 - Loss: 0.289   lengthscale: 0.167   noise: 0.072
# Step: 9, Val-Loss: 1.6418
# [ 0.40974557 -0.4437939   0.46949708 ... -0.3899945   0.2368797
#  -0.16130221]
# Step: 9 of 10, time-taken: 12.23 seconds
# K_D, P_D (100, 2) (1900, 2)
# Epoch 1/150 - Loss: 2.402   lengthscale: 0.100   noise: 0.010
# Epoch 2/150 - Loss: 2.111   lengthscale: 0.110   noise: 0.011
# Epoch 3/150 - Loss: 1.852   lengthscale: 0.121   noise: 0.012
# Epoch 4/150 - Loss: 1.625   lengthscale: 0.133   noise: 0.013
# Epoch 5/150 - Loss: 1.428   lengthscale: 0.145   noise: 0.015
# Epoch 6/150 - Loss: 1.260   lengthscale: 0.158   noise: 0.016
# Epoch 7/150 - Loss: 1.118   lengthscale: 0.168   noise: 0.018
# Epoch 8/150 - Loss: 0.994   lengthscale: 0.176   noise: 0.020
# Epoch 9/150 - Loss: 0.886   lengthscale: 0.181   noise: 0.021
# Epoch 10/150 - Loss: 0.790   lengthscale: 0.182   noise: 0.023
# Epoch 11/150 - Loss: 0.707   lengthscale: 0.181   noise: 0.025
# Epoch 12/150 - Loss: 0.636   lengthscale: 0.179   noise: 0.028
# Epoch 13/150 - Loss: 0.575   lengthscale: 0.176   noise: 0.030
# Epoch 14/150 - Loss: 0.524   lengthscale: 0.172   noise: 0.032
# Epoch 15/150 - Loss: 0.481   lengthscale: 0.168   noise: 0.035
# Epoch 16/150 - Loss: 0.446   lengthscale: 0.165   noise: 0.037
# Epoch 17/150 - Loss: 0.417   lengthscale: 0.163   noise: 0.040
# Epoch 18/150 - Loss: 0.393   lengthscale: 0.161   noise: 0.042
# Epoch 19/150 - Loss: 0.373   lengthscale: 0.161   noise: 0.045
# Epoch 20/150 - Loss: 0.356   lengthscale: 0.161   noise: 0.047
# Epoch 21/150 - Loss: 0.343   lengthscale: 0.162   noise: 0.050
# Epoch 22/150 - Loss: 0.331   lengthscale: 0.164   noise: 0.053
# Epoch 23/150 - Loss: 0.322   lengthscale: 0.167   noise: 0.055
# Epoch 24/150 - Loss: 0.315   lengthscale: 0.170   noise: 0.058
# Epoch 25/150 - Loss: 0.309   lengthscale: 0.174   noise: 0.060
# Epoch 26/150 - Loss: 0.304   lengthscale: 0.178   noise: 0.062
# Epoch 27/150 - Loss: 0.301   lengthscale: 0.183   noise: 0.065
# Epoch 28/150 - Loss: 0.298   lengthscale: 0.187   noise: 0.067
# Epoch 29/150 - Loss: 0.297   lengthscale: 0.191   noise: 0.069
# Epoch 30/150 - Loss: 0.296   lengthscale: 0.194   noise: 0.071
# Epoch 31/150 - Loss: 0.295   lengthscale: 0.197   noise: 0.073
# Epoch 32/150 - Loss: 0.295   lengthscale: 0.199   noise: 0.075
# Epoch 33/150 - Loss: 0.295   lengthscale: 0.200   noise: 0.076
# Epoch 34/150 - Loss: 0.295   lengthscale: 0.200   noise: 0.078
# Epoch 35/150 - Loss: 0.295   lengthscale: 0.199   noise: 0.079
# Epoch 36/150 - Loss: 0.295   lengthscale: 0.198   noise: 0.081
# Epoch 37/150 - Loss: 0.296   lengthscale: 0.196   noise: 0.082
# Epoch 38/150 - Loss: 0.296   lengthscale: 0.194   noise: 0.083
# Epoch 39/150 - Loss: 0.297   lengthscale: 0.192   noise: 0.084
# Epoch 40/150 - Loss: 0.297   lengthscale: 0.191   noise: 0.085
# Epoch 41/150 - Loss: 0.298   lengthscale: 0.190   noise: 0.085
# Epoch 42/150 - Loss: 0.298   lengthscale: 0.189   noise: 0.086
# Epoch 43/150 - Loss: 0.298   lengthscale: 0.189   noise: 0.086
# Epoch 44/150 - Loss: 0.299   lengthscale: 0.189   noise: 0.087
# Epoch 45/150 - Loss: 0.299   lengthscale: 0.190   noise: 0.087
# Epoch 46/150 - Loss: 0.299   lengthscale: 0.191   noise: 0.087
# Epoch 47/150 - Loss: 0.299   lengthscale: 0.193   noise: 0.088
# Epoch 48/150 - Loss: 0.299   lengthscale: 0.194   noise: 0.088
# Epoch 49/150 - Loss: 0.299   lengthscale: 0.196   noise: 0.088
# Epoch 50/150 - Loss: 0.299   lengthscale: 0.197   noise: 0.088
# Epoch 51/150 - Loss: 0.299   lengthscale: 0.198   noise: 0.088
# Epoch 52/150 - Loss: 0.299   lengthscale: 0.199   noise: 0.088
# Epoch 53/150 - Loss: 0.299   lengthscale: 0.200   noise: 0.087
# Epoch 54/150 - Loss: 0.299   lengthscale: 0.200   noise: 0.087
# Epoch 55/150 - Loss: 0.299   lengthscale: 0.199   noise: 0.087
# Epoch 56/150 - Loss: 0.298   lengthscale: 0.199   noise: 0.087
# Epoch 57/150 - Loss: 0.298   lengthscale: 0.198   noise: 0.086
# Epoch 58/150 - Loss: 0.298   lengthscale: 0.197   noise: 0.086
# Epoch 59/150 - Loss: 0.298   lengthscale: 0.196   noise: 0.086
# Epoch 60/150 - Loss: 0.297   lengthscale: 0.195   noise: 0.085
# Epoch 61/150 - Loss: 0.297   lengthscale: 0.195   noise: 0.085
# Epoch 62/150 - Loss: 0.297   lengthscale: 0.194   noise: 0.085
# Epoch 63/150 - Loss: 0.297   lengthscale: 0.194   noise: 0.084
# Epoch 64/150 - Loss: 0.297   lengthscale: 0.194   noise: 0.084
# Epoch 65/150 - Loss: 0.296   lengthscale: 0.195   noise: 0.083
# Epoch 66/150 - Loss: 0.296   lengthscale: 0.195   noise: 0.083
# Epoch 67/150 - Loss: 0.296   lengthscale: 0.195   noise: 0.082
# Epoch 68/150 - Loss: 0.296   lengthscale: 0.196   noise: 0.082
# Epoch 69/150 - Loss: 0.296   lengthscale: 0.196   noise: 0.082
# Epoch 70/150 - Loss: 0.295   lengthscale: 0.197   noise: 0.081
# Epoch 71/150 - Loss: 0.295   lengthscale: 0.197   noise: 0.081
# Epoch 72/150 - Loss: 0.295   lengthscale: 0.197   noise: 0.080
# Epoch 73/150 - Loss: 0.295   lengthscale: 0.197   noise: 0.080
# Epoch 74/150 - Loss: 0.295   lengthscale: 0.197   noise: 0.080
# Epoch 75/150 - Loss: 0.295   lengthscale: 0.196   noise: 0.079
# Epoch 76/150 - Loss: 0.295   lengthscale: 0.196   noise: 0.079
# Epoch 77/150 - Loss: 0.295   lengthscale: 0.195   noise: 0.079
# Epoch 78/150 - Loss: 0.295   lengthscale: 0.195   noise: 0.078
# Epoch 79/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.078
# Epoch 80/150 - Loss: 0.294   lengthscale: 0.194   noise: 0.078
# Epoch 81/150 - Loss: 0.294   lengthscale: 0.194   noise: 0.078
# Epoch 82/150 - Loss: 0.294   lengthscale: 0.194   noise: 0.077
# Epoch 83/150 - Loss: 0.294   lengthscale: 0.194   noise: 0.077
# Epoch 84/150 - Loss: 0.294   lengthscale: 0.194   noise: 0.077
# Epoch 85/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.077
# Epoch 86/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Epoch 87/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Epoch 88/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Epoch 89/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Epoch 90/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Epoch 91/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Epoch 92/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Epoch 93/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.075
# Epoch 94/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.075
# Epoch 95/150 - Loss: 0.294   lengthscale: 0.194   noise: 0.075
# Epoch 96/150 - Loss: 0.294   lengthscale: 0.194   noise: 0.075
# Epoch 97/150 - Loss: 0.294   lengthscale: 0.194   noise: 0.075
# Epoch 98/150 - Loss: 0.294   lengthscale: 0.194   noise: 0.075
# Epoch 99/150 - Loss: 0.294   lengthscale: 0.194   noise: 0.075
# Epoch 100/150 - Loss: 0.294   lengthscale: 0.194   noise: 0.075
# Epoch 101/150 - Loss: 0.294   lengthscale: 0.194   noise: 0.075
# Epoch 102/150 - Loss: 0.294   lengthscale: 0.194   noise: 0.075
# Epoch 103/150 - Loss: 0.294   lengthscale: 0.194   noise: 0.075
# Epoch 104/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.075
# Epoch 105/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.075
# Epoch 106/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.075
# Epoch 107/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.075
# Epoch 108/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.075
# Epoch 109/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.075
# Epoch 110/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.075
# Epoch 111/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.075
# Epoch 112/150 - Loss: 0.294   lengthscale: 0.194   noise: 0.075
# Epoch 113/150 - Loss: 0.294   lengthscale: 0.194   noise: 0.075
# Epoch 114/150 - Loss: 0.294   lengthscale: 0.194   noise: 0.075
# Epoch 115/150 - Loss: 0.294   lengthscale: 0.194   noise: 0.075
# Epoch 116/150 - Loss: 0.294   lengthscale: 0.194   noise: 0.075
# Epoch 117/150 - Loss: 0.294   lengthscale: 0.194   noise: 0.075
# Epoch 118/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.075
# Epoch 119/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.075
# Epoch 120/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.075
# Epoch 121/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.075
# Epoch 122/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.075
# Epoch 123/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.075
# Epoch 124/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.075
# Epoch 125/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.075
# Epoch 126/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.075
# Epoch 127/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Epoch 128/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Epoch 129/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Epoch 130/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Epoch 131/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Epoch 132/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Epoch 133/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Epoch 134/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Epoch 135/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Epoch 136/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Epoch 137/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Epoch 138/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Epoch 139/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Epoch 140/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Epoch 141/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Epoch 142/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Epoch 143/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Epoch 144/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Epoch 145/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Epoch 146/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Epoch 147/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Epoch 148/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Epoch 149/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Epoch 150/150 - Loss: 0.294   lengthscale: 0.195   noise: 0.076
# Step: 10, Val-Loss: 0.1657
# [ 0.35867906 -0.46247697  0.42151237 ... -0.29028273  0.18120979
#  -0.12997319]
# Step: 10 of 10, time-taken: 12.26 seconds

# %%
preds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 preds
#
# NameError: name 'preds' is not defined

# %%
preds[0].mean.numpy()
# Out:
# array(-0.58365375, dtype=float32)

# %%
len(preds.stddev)
# Out:
# 1000
