# %% [markdown]
# Torch Implementation of GP
#
# Inspired by: https://docs.gpytorch.ai/en/stable/examples/01_Exact_GPs/Simple_GP_Regression.html

# %%
import math
import torch
import gpytorch
from matplotlib import pyplot as plt
import time

from data import Dataprep, load_data
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns

import pandas as pd


# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dataset_type='Generated_2000'
sensor='foundation_origin xy FloaterOffset [m]'
samples_per_step=10
validation_size=0.1

# %%
data = Dataprep(dataset_type, sensor, initial_samplesize=samples_per_step, scaling='Minmax')
known_data, pool_data = data.known_data, data.pool_data

# %% [markdown]
# Load Data and Normalize

# %%
# We will use the simplest form of GP model, exact inference
class ExactGPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super(ExactGPModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = gpytorch.means.ConstantMean()

        # Assuming you have an RBFKernel instance named `rbf_kernel`:
        rbf_kernel = gpytorch.kernels.RBFKernel()

        # To set an initial length scale:
        rbf_kernel.lengthscale = 0.1

        # kernel can be changed or combined !
        self.covar_module = gpytorch.kernels.ScaleKernel(rbf_kernel)

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

# initialize likelihood and model
#likelihood = gpytorch.likelihoods.GaussianLikelihood()
#model = ExactGPModel(train_x, train_y, likelihood)

# %%
from torch.optim import Adam

# %%
def init_optimizer(learning_rate,model):
    optimizer = Adam(model.parameters(), lr=learning_rate)
    return optimizer
    
def train_model(step, learning_rate):
    print('K_D, P_D', known_data.shape, pool_data.shape)

    # Split the pool data into train and validation sets
    train, val = train_test_split(known_data, test_size=validation_size)

    X_train = torch.tensor(scaler.fit_transform(train[:, 0].reshape(-1, 1))).to(device)  # Adds an extra dimension to make X_train a 2D tensor
    y_train = torch.tensor(train[:, 1]).to(device)
    
    print(X_train.shape)
    print(X_train.dtype)
    # Initialize likelihood and model with training data
    likelihood = gpytorch.likelihoods.GaussianLikelihood().to(device)

    # Assuming you have a GaussianLikelihood instance named `likelihood`:
    likelihood = gpytorch.likelihoods.GaussianLikelihood()

    # To set an initial noise level:
    likelihood.noise = 0.01






    model = ExactGPModel(X_train, y_train, likelihood).to(device)
    
    optimizer = init_optimizer(learning_rate,model) # Initialize the optimizer

    model.train()
    likelihood.train()

    mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)
    total_train_loss = 0

    x, y = X_train, y_train



    # Find optimal model hyperparameters
    model.train()
    likelihood.train()

    # Use the adam optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr=0.1)  # Includes GaussianLikelihood parameters

    # "Loss" for GPs - the marginal log likelihood
    mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

    for epoch in range(epochs):
        # Zero gradients from previous iteration
        optimizer.zero_grad()
        # Output from model
        output = model(X_train)
        # Calc loss and backprop gradients
        loss = -mll(output, y_train)

        loss.backward()
        print('Epoch %d/%d - Loss: %.3f   lengthscale: %.3f   noise: %.3f' % (
            epoch +1, epochs, loss.item(),
            model.covar_module.base_kernel.lengthscale.item(),
            model.likelihood.noise.item()
        ))
        optimizer.step()

    preds = evaluate_model(likelihood, model,val, step, mll) # Evaluate the model on the validation set

    return preds

# %%
def evaluate_model(likelihood, model, val, step, mll): # 1: EVALUATE THE MODEL ON THE VALIDATION SET

    X_val = torch.tensor(scaler.fit_transform(val[:, 0].reshape(-1, 1))).to(device)  # Adds an extra dimension to make X_train a 2D tensor
    y_val = torch.tensor(val[:, 1]).to(device)
    x, y = X_val, y_val
    # Get into evaluation (predictive posterior) mode
    model.eval()
    likelihood.eval()

    total_val_loss = 0
    # Make predictions by feeding model through likelihood
    with torch.no_grad(), gpytorch.settings.fast_pred_var():
        output = model(X_val)
        loss = -mll(output, y_val)
        total_val_loss += loss.item()

    step_val_loss = total_val_loss  # Average loss over batches
    writer.add_scalar('loss/val', step_val_loss, step+1)
    if verbose:
        print('Step: {}, Val-Loss: {:.4f}'.format(step+1, step_val_loss))

    if known_data.shape[1] == 2:
        preds = plot(likelihood, model, step)
    return preds

# %%
def plot(likelihood, model, step, samples=500):
    x_pool = pool_data[:, :-1]
    y_pool = pool_data[:, -1]

    x_selected = known_data[:, :-1]
    y_selected = known_data[:, -1]

    scaler = MinMaxScaler()
    x_pool_scaled = scaler.fit_transform(x_pool)
    x_selected_scaled = scaler.transform(x_selected)
    
    x_pool_torch = torch.tensor(x_pool_scaled) 

    model.eval()
    likelihood.eval()

    # Make predictions by feeding model through likelihood
    with torch.no_grad(), gpytorch.settings.fast_pred_var():
        preds = likelihood(model(x_pool_torch))

    means = preds.mean.numpy()  # calculate the mean of the predictions
    lower, upper = preds.confidence_region()
    stds = preds.stddev.numpy()
    
    # Prepare data for plotting
    #df = pd.DataFrame({'x': x_pool_torch.squeeze(), 'mean': means.squeeze(), 'lower': lower, 'upper': upper})

    dfs = []
    y_vals = [means, means + 2 * stds, means - 2 * stds]

    for i in range(3): #len(y_vals)
        dfs.append(pd.DataFrame({'x': x_pool_torch.squeeze(), 'y': y_vals[i].squeeze()}))
    df = pd.concat(dfs)

    print(means.squeeze())
    
    # Plotting
    fig = plt.figure()
    sns.lineplot(data=df, x="x", y="y")
    plt.scatter(x_pool_scaled, y_pool, c="green", marker="*", alpha=0.1)  # Plot actual y values
    plt.scatter(x_selected_scaled, y_selected, c="red", marker="*", alpha=0.2) # plot train data on top
    plt.title(f'Predictions vs Actual Step {step+1}')
    plt.legend(['Mean prediction', 'Pool data (unseen)', 'Seen data'], fontsize='small')
    plt.close(fig)

    # Log the table figure
    writer.add_figure(f'Prediction vs Actual Table Epoch {step+1}', fig, step+1)

    # Log the table figure
    writer.add_figure(f'Prediction vs Actual Table Epoch {step+1}', fig, step+1)

    return preds

# %%
import random

# %%
def predict(self, x): # 2: PREDICT THE UNCERTAINTY ON THE POOL DATA
        pass

def acquisition_function(n, pool_data=pool_data, known_data=known_data): # 3: DECIDE WHICH SAMPLES TO SELECT FROM THE POOL DATA (USING ACQUISITION FUNCTION)
    selected_indices = random.sample(range(len(pool_data)), n)
    known_data, pool_data = update_data(known_data, pool_data, selected_indices)

    return known_data, pool_data

# %%
data = Dataprep(dataset_type, sensor, initial_samplesize=samples_per_step, scaling='Minmax')
known_data, pool_data = data.known_data, data.pool_data

# %%
from torch.utils.tensorboard import SummaryWriter
import datetime
import os

# %%
steps = 10
learning_rate = 0.01
epochs = 150
verbose=True
current_time = datetime.datetime.now().strftime("%Y%m%d-%H%M%S") # Unique directory based on datetime for each run
log_dir = os.path.join('Models/runs', 'BNN_' + dataset_type  + '_' + current_time)
writer = SummaryWriter(log_dir) 
scaler = MinMaxScaler()

device = torch.device("cpu" if torch.backends.mps.is_available() else "cpu")

# %%
known_data, pool_data = data.known_data, data.pool_data

# %%
# Train the model
for step in range(steps):
    start_step = time.time()
    preds = train_model(step,learning_rate) # Train the model
    print('Step: {} of {}, time-taken: {:.2f} seconds'.format(step+1, steps, time.time() - start_step))
    known_data, pool_data = acquisition_function(samples_per_step, pool_data, known_data) # Select the next samples from the pool
# Out:
# K_D, P_D (10, 2) (1990, 2)
# torch.Size([9, 1])
# torch.float32
# tensor(39.1808, grad_fn=<NegBackward0>)
# Epoch 1/150 - Loss: 39.181   lengthscale: 0.100   noise: 0.010
# tensor(34.3241, grad_fn=<NegBackward0>)
# Epoch 2/150 - Loss: 34.324   lengthscale: 0.110   noise: 0.011
# tensor(30.2369, grad_fn=<NegBackward0>)
# Epoch 3/150 - Loss: 30.237   lengthscale: 0.121   noise: 0.012
# tensor(26.7643, grad_fn=<NegBackward0>)
# Epoch 4/150 - Loss: 26.764   lengthscale: 0.132   noise: 0.013
# tensor(23.7549, grad_fn=<NegBackward0>)
# Epoch 5/150 - Loss: 23.755   lengthscale: 0.145   noise: 0.015
# tensor(21.1083, grad_fn=<NegBackward0>)
# Epoch 6/150 - Loss: 21.108   lengthscale: 0.158   noise: 0.016
# tensor(18.7745, grad_fn=<NegBackward0>)
# Epoch 7/150 - Loss: 18.775   lengthscale: 0.172   noise: 0.018
# tensor(16.7297, grad_fn=<NegBackward0>)
# Epoch 8/150 - Loss: 16.730   lengthscale: 0.187   noise: 0.020
# tensor(14.9531, grad_fn=<NegBackward0>)
# Epoch 9/150 - Loss: 14.953   lengthscale: 0.203   noise: 0.022
# tensor(13.4182, grad_fn=<NegBackward0>)
# Epoch 10/150 - Loss: 13.418   lengthscale: 0.220   noise: 0.024
# tensor(12.0950, grad_fn=<NegBackward0>)
# Epoch 11/150 - Loss: 12.095   lengthscale: 0.238   noise: 0.027
# tensor(10.9551, grad_fn=<NegBackward0>)
# Epoch 12/150 - Loss: 10.955   lengthscale: 0.257   noise: 0.030
# tensor(9.9752, grad_fn=<NegBackward0>)
# Epoch 13/150 - Loss: 9.975   lengthscale: 0.276   noise: 0.033
# tensor(9.1381, grad_fn=<NegBackward0>)
# Epoch 14/150 - Loss: 9.138   lengthscale: 0.295   noise: 0.037
# tensor(8.4306, grad_fn=<NegBackward0>)
# Epoch 15/150 - Loss: 8.431   lengthscale: 0.315   noise: 0.040
# tensor(7.8400, grad_fn=<NegBackward0>)
# Epoch 16/150 - Loss: 7.840   lengthscale: 0.335   noise: 0.044
# tensor(7.3511, grad_fn=<NegBackward0>)
# Epoch 17/150 - Loss: 7.351   lengthscale: 0.356   noise: 0.049
# tensor(6.9467, grad_fn=<NegBackward0>)
# Epoch 18/150 - Loss: 6.947   lengthscale: 0.375   noise: 0.054
# tensor(6.6090, grad_fn=<NegBackward0>)
# Epoch 19/150 - Loss: 6.609   lengthscale: 0.395   noise: 0.059
# tensor(6.3223, grad_fn=<NegBackward0>)
# Epoch 20/150 - Loss: 6.322   lengthscale: 0.413   noise: 0.064
# tensor(6.0737, grad_fn=<NegBackward0>)
# Epoch 21/150 - Loss: 6.074   lengthscale: 0.431   noise: 0.069
# tensor(5.8538, grad_fn=<NegBackward0>)
# Epoch 22/150 - Loss: 5.854   lengthscale: 0.448   noise: 0.075
# tensor(5.6559, grad_fn=<NegBackward0>)
# Epoch 23/150 - Loss: 5.656   lengthscale: 0.464   noise: 0.081
# tensor(5.4752, grad_fn=<NegBackward0>)
# Epoch 24/150 - Loss: 5.475   lengthscale: 0.479   noise: 0.088
# tensor(5.3085, grad_fn=<NegBackward0>)
# Epoch 25/150 - Loss: 5.308   lengthscale: 0.493   noise: 0.094
# tensor(5.1535, grad_fn=<NegBackward0>)
# Epoch 26/150 - Loss: 5.153   lengthscale: 0.506   noise: 0.101
# tensor(5.0086, grad_fn=<NegBackward0>)
# Epoch 27/150 - Loss: 5.009   lengthscale: 0.518   noise: 0.109
# tensor(4.8727, grad_fn=<NegBackward0>)
# Epoch 28/150 - Loss: 4.873   lengthscale: 0.530   noise: 0.116
# tensor(4.7450, grad_fn=<NegBackward0>)
# Epoch 29/150 - Loss: 4.745   lengthscale: 0.540   noise: 0.125
# tensor(4.6246, grad_fn=<NegBackward0>)
# Epoch 30/150 - Loss: 4.625   lengthscale: 0.550   noise: 0.133
# tensor(4.5111, grad_fn=<NegBackward0>)
# Epoch 31/150 - Loss: 4.511   lengthscale: 0.560   noise: 0.142
# tensor(4.4040, grad_fn=<NegBackward0>)
# Epoch 32/150 - Loss: 4.404   lengthscale: 0.569   noise: 0.151
# tensor(4.3028, grad_fn=<NegBackward0>)
# Epoch 33/150 - Loss: 4.303   lengthscale: 0.577   noise: 0.161
# tensor(4.2071, grad_fn=<NegBackward0>)
# Epoch 34/150 - Loss: 4.207   lengthscale: 0.585   noise: 0.171
# tensor(4.1166, grad_fn=<NegBackward0>)
# Epoch 35/150 - Loss: 4.117   lengthscale: 0.593   noise: 0.182
# tensor(4.0309, grad_fn=<NegBackward0>)
# Epoch 36/150 - Loss: 4.031   lengthscale: 0.601   noise: 0.193
# tensor(3.9498, grad_fn=<NegBackward0>)
# Epoch 37/150 - Loss: 3.950   lengthscale: 0.608   noise: 0.204
# tensor(3.8729, grad_fn=<NegBackward0>)
# Epoch 38/150 - Loss: 3.873   lengthscale: 0.615   noise: 0.216
# tensor(3.7999, grad_fn=<NegBackward0>)
# Epoch 39/150 - Loss: 3.800   lengthscale: 0.622   noise: 0.228
# tensor(3.7307, grad_fn=<NegBackward0>)
# Epoch 40/150 - Loss: 3.731   lengthscale: 0.629   noise: 0.240
# tensor(3.6649, grad_fn=<NegBackward0>)
# Epoch 41/150 - Loss: 3.665   lengthscale: 0.635   noise: 0.253
# tensor(3.6025, grad_fn=<NegBackward0>)
# Epoch 42/150 - Loss: 3.602   lengthscale: 0.642   noise: 0.265
# tensor(3.5431, grad_fn=<NegBackward0>)
# Epoch 43/150 - Loss: 3.543   lengthscale: 0.649   noise: 0.279
# tensor(3.4865, grad_fn=<NegBackward0>)
# Epoch 44/150 - Loss: 3.487   lengthscale: 0.656   noise: 0.292
# tensor(3.4327, grad_fn=<NegBackward0>)
# Epoch 45/150 - Loss: 3.433   lengthscale: 0.662   noise: 0.306
# tensor(3.3814, grad_fn=<NegBackward0>)
# Epoch 46/150 - Loss: 3.381   lengthscale: 0.669   noise: 0.319
# tensor(3.3325, grad_fn=<NegBackward0>)
# Epoch 47/150 - Loss: 3.333   lengthscale: 0.676   noise: 0.333
# tensor(3.2859, grad_fn=<NegBackward0>)
# Epoch 48/150 - Loss: 3.286   lengthscale: 0.682   noise: 0.347
# tensor(3.2414, grad_fn=<NegBackward0>)
# Epoch 49/150 - Loss: 3.241   lengthscale: 0.689   noise: 0.361
# tensor(3.1990, grad_fn=<NegBackward0>)
# Epoch 50/150 - Loss: 3.199   lengthscale: 0.696   noise: 0.375
# tensor(3.1584, grad_fn=<NegBackward0>)
# Epoch 51/150 - Loss: 3.158   lengthscale: 0.703   noise: 0.389
# tensor(3.1196, grad_fn=<NegBackward0>)
# Epoch 52/150 - Loss: 3.120   lengthscale: 0.710   noise: 0.403
# tensor(3.0826, grad_fn=<NegBackward0>)
# Epoch 53/150 - Loss: 3.083   lengthscale: 0.717   noise: 0.417
# tensor(3.0471, grad_fn=<NegBackward0>)
# Epoch 54/150 - Loss: 3.047   lengthscale: 0.724   noise: 0.431
# tensor(3.0132, grad_fn=<NegBackward0>)
# Epoch 55/150 - Loss: 3.013   lengthscale: 0.732   noise: 0.444
# tensor(2.9807, grad_fn=<NegBackward0>)
# Epoch 56/150 - Loss: 2.981   lengthscale: 0.739   noise: 0.458
# tensor(2.9496, grad_fn=<NegBackward0>)
# Epoch 57/150 - Loss: 2.950   lengthscale: 0.746   noise: 0.471
# tensor(2.9198, grad_fn=<NegBackward0>)
# Epoch 58/150 - Loss: 2.920   lengthscale: 0.754   noise: 0.484
# tensor(2.8912, grad_fn=<NegBackward0>)
# Epoch 59/150 - Loss: 2.891   lengthscale: 0.761   noise: 0.496
# tensor(2.8637, grad_fn=<NegBackward0>)
# Epoch 60/150 - Loss: 2.864   lengthscale: 0.768   noise: 0.508
# tensor(2.8373, grad_fn=<NegBackward0>)
# Epoch 61/150 - Loss: 2.837   lengthscale: 0.776   noise: 0.520
# tensor(2.8119, grad_fn=<NegBackward0>)
# Epoch 62/150 - Loss: 2.812   lengthscale: 0.783   noise: 0.532
# tensor(2.7875, grad_fn=<NegBackward0>)
# Epoch 63/150 - Loss: 2.788   lengthscale: 0.791   noise: 0.543
# tensor(2.7640, grad_fn=<NegBackward0>)
# Epoch 64/150 - Loss: 2.764   lengthscale: 0.798   noise: 0.553
# tensor(2.7414, grad_fn=<NegBackward0>)
# Epoch 65/150 - Loss: 2.741   lengthscale: 0.806   noise: 0.564
# tensor(2.7196, grad_fn=<NegBackward0>)
# Epoch 66/150 - Loss: 2.720   lengthscale: 0.813   noise: 0.574
# tensor(2.6985, grad_fn=<NegBackward0>)
# Epoch 67/150 - Loss: 2.699   lengthscale: 0.821   noise: 0.583
# tensor(2.6782, grad_fn=<NegBackward0>)
# Epoch 68/150 - Loss: 2.678   lengthscale: 0.828   noise: 0.592
# tensor(2.6585, grad_fn=<NegBackward0>)
# Epoch 69/150 - Loss: 2.658   lengthscale: 0.836   noise: 0.600
# tensor(2.6394, grad_fn=<NegBackward0>)
# Epoch 70/150 - Loss: 2.639   lengthscale: 0.843   noise: 0.608
# tensor(2.6210, grad_fn=<NegBackward0>)
# Epoch 71/150 - Loss: 2.621   lengthscale: 0.851   noise: 0.616
# tensor(2.6031, grad_fn=<NegBackward0>)
# Epoch 72/150 - Loss: 2.603   lengthscale: 0.858   noise: 0.623
# tensor(2.5858, grad_fn=<NegBackward0>)
# Epoch 73/150 - Loss: 2.586   lengthscale: 0.865   noise: 0.630
# tensor(2.5689, grad_fn=<NegBackward0>)
# Epoch 74/150 - Loss: 2.569   lengthscale: 0.873   noise: 0.636
# tensor(2.5525, grad_fn=<NegBackward0>)
# Epoch 75/150 - Loss: 2.553   lengthscale: 0.880   noise: 0.642
# tensor(2.5366, grad_fn=<NegBackward0>)
# Epoch 76/150 - Loss: 2.537   lengthscale: 0.887   noise: 0.647
# tensor(2.5211, grad_fn=<NegBackward0>)
# Epoch 77/150 - Loss: 2.521   lengthscale: 0.894   noise: 0.652
# tensor(2.5059, grad_fn=<NegBackward0>)
# Epoch 78/150 - Loss: 2.506   lengthscale: 0.901   noise: 0.656
# tensor(2.4912, grad_fn=<NegBackward0>)
# Epoch 79/150 - Loss: 2.491   lengthscale: 0.908   noise: 0.660
# tensor(2.4768, grad_fn=<NegBackward0>)
# Epoch 80/150 - Loss: 2.477   lengthscale: 0.915   noise: 0.664
# tensor(2.4627, grad_fn=<NegBackward0>)
# Epoch 81/150 - Loss: 2.463   lengthscale: 0.922   noise: 0.667
# tensor(2.4489, grad_fn=<NegBackward0>)
# Epoch 82/150 - Loss: 2.449   lengthscale: 0.929   noise: 0.670
# tensor(2.4354, grad_fn=<NegBackward0>)
# Epoch 83/150 - Loss: 2.435   lengthscale: 0.936   noise: 0.673
# tensor(2.4222, grad_fn=<NegBackward0>)
# Epoch 84/150 - Loss: 2.422   lengthscale: 0.943   noise: 0.675
# tensor(2.4093, grad_fn=<NegBackward0>)
# Epoch 85/150 - Loss: 2.409   lengthscale: 0.949   noise: 0.677
# tensor(2.3966, grad_fn=<NegBackward0>)
# Epoch 86/150 - Loss: 2.397   lengthscale: 0.956   noise: 0.678
# tensor(2.3842, grad_fn=<NegBackward0>)
# Epoch 87/150 - Loss: 2.384   lengthscale: 0.962   noise: 0.679
# tensor(2.3720, grad_fn=<NegBackward0>)
# Epoch 88/150 - Loss: 2.372   lengthscale: 0.969   noise: 0.680
# tensor(2.3600, grad_fn=<NegBackward0>)
# Epoch 89/150 - Loss: 2.360   lengthscale: 0.975   noise: 0.681
# tensor(2.3482, grad_fn=<NegBackward0>)
# Epoch 90/150 - Loss: 2.348   lengthscale: 0.982   noise: 0.681
# tensor(2.3366, grad_fn=<NegBackward0>)
# Epoch 91/150 - Loss: 2.337   lengthscale: 0.988   noise: 0.681
# tensor(2.3252, grad_fn=<NegBackward0>)
# Epoch 92/150 - Loss: 2.325   lengthscale: 0.995   noise: 0.680
# tensor(2.3139, grad_fn=<NegBackward0>)
# Epoch 93/150 - Loss: 2.314   lengthscale: 1.001   noise: 0.680
# tensor(2.3029, grad_fn=<NegBackward0>)
# Epoch 94/150 - Loss: 2.303   lengthscale: 1.007   noise: 0.679
# tensor(2.2920, grad_fn=<NegBackward0>)
# Epoch 95/150 - Loss: 2.292   lengthscale: 1.013   noise: 0.678
# tensor(2.2812, grad_fn=<NegBackward0>)
# Epoch 96/150 - Loss: 2.281   lengthscale: 1.019   noise: 0.677
# tensor(2.2706, grad_fn=<NegBackward0>)
# Epoch 97/150 - Loss: 2.271   lengthscale: 1.025   noise: 0.675
# tensor(2.2602, grad_fn=<NegBackward0>)
# Epoch 98/150 - Loss: 2.260   lengthscale: 1.031   noise: 0.674
# tensor(2.2499, grad_fn=<NegBackward0>)
# Epoch 99/150 - Loss: 2.250   lengthscale: 1.037   noise: 0.672
# tensor(2.2397, grad_fn=<NegBackward0>)
# Epoch 100/150 - Loss: 2.240   lengthscale: 1.043   noise: 0.670
# tensor(2.2297, grad_fn=<NegBackward0>)
# Epoch 101/150 - Loss: 2.230   lengthscale: 1.049   noise: 0.668
# tensor(2.2198, grad_fn=<NegBackward0>)
# Epoch 102/150 - Loss: 2.220   lengthscale: 1.055   noise: 0.665
# tensor(2.2100, grad_fn=<NegBackward0>)
# Epoch 103/150 - Loss: 2.210   lengthscale: 1.060   noise: 0.663
# tensor(2.2004, grad_fn=<NegBackward0>)
# Epoch 104/150 - Loss: 2.200   lengthscale: 1.066   noise: 0.660
# tensor(2.1908, grad_fn=<NegBackward0>)
# Epoch 105/150 - Loss: 2.191   lengthscale: 1.072   noise: 0.658
# tensor(2.1814, grad_fn=<NegBackward0>)
# Epoch 106/150 - Loss: 2.181   lengthscale: 1.077   noise: 0.655
# tensor(2.1721, grad_fn=<NegBackward0>)
# Epoch 107/150 - Loss: 2.172   lengthscale: 1.083   noise: 0.652
# tensor(2.1629, grad_fn=<NegBackward0>)
# Epoch 108/150 - Loss: 2.163   lengthscale: 1.088   noise: 0.649
# tensor(2.1538, grad_fn=<NegBackward0>)
# Epoch 109/150 - Loss: 2.154   lengthscale: 1.094   noise: 0.646
# tensor(2.1447, grad_fn=<NegBackward0>)
# Epoch 110/150 - Loss: 2.145   lengthscale: 1.099   noise: 0.643
# tensor(2.1358, grad_fn=<NegBackward0>)
# Epoch 111/150 - Loss: 2.136   lengthscale: 1.105   noise: 0.639
# tensor(2.1270, grad_fn=<NegBackward0>)
# Epoch 112/150 - Loss: 2.127   lengthscale: 1.110   noise: 0.636
# tensor(2.1183, grad_fn=<NegBackward0>)
# Epoch 113/150 - Loss: 2.118   lengthscale: 1.115   noise: 0.633
# tensor(2.1097, grad_fn=<NegBackward0>)
# Epoch 114/150 - Loss: 2.110   lengthscale: 1.121   noise: 0.629
# tensor(2.1012, grad_fn=<NegBackward0>)
# Epoch 115/150 - Loss: 2.101   lengthscale: 1.126   noise: 0.626
# tensor(2.0928, grad_fn=<NegBackward0>)
# Epoch 116/150 - Loss: 2.093   lengthscale: 1.131   noise: 0.622
# tensor(2.0844, grad_fn=<NegBackward0>)
# Epoch 117/150 - Loss: 2.084   lengthscale: 1.136   noise: 0.619
# tensor(2.0762, grad_fn=<NegBackward0>)
# Epoch 118/150 - Loss: 2.076   lengthscale: 1.141   noise: 0.615
# tensor(2.0680, grad_fn=<NegBackward0>)
# Epoch 119/150 - Loss: 2.068   lengthscale: 1.147   noise: 0.611
# tensor(2.0600, grad_fn=<NegBackward0>)
# Epoch 120/150 - Loss: 2.060   lengthscale: 1.152   noise: 0.608
# tensor(2.0520, grad_fn=<NegBackward0>)
# Epoch 121/150 - Loss: 2.052   lengthscale: 1.157   noise: 0.604
# tensor(2.0441, grad_fn=<NegBackward0>)
# Epoch 122/150 - Loss: 2.044   lengthscale: 1.162   noise: 0.601
# tensor(2.0362, grad_fn=<NegBackward0>)
# Epoch 123/150 - Loss: 2.036   lengthscale: 1.167   noise: 0.597
# tensor(2.0285, grad_fn=<NegBackward0>)
# Epoch 124/150 - Loss: 2.029   lengthscale: 1.172   noise: 0.593
# tensor(2.0208, grad_fn=<NegBackward0>)
# Epoch 125/150 - Loss: 2.021   lengthscale: 1.177   noise: 0.590
# tensor(2.0133, grad_fn=<NegBackward0>)
# Epoch 126/150 - Loss: 2.013   lengthscale: 1.182   noise: 0.586
# tensor(2.0058, grad_fn=<NegBackward0>)
# Epoch 127/150 - Loss: 2.006   lengthscale: 1.186   noise: 0.583
# tensor(1.9983, grad_fn=<NegBackward0>)
# Epoch 128/150 - Loss: 1.998   lengthscale: 1.191   noise: 0.579
# tensor(1.9910, grad_fn=<NegBackward0>)
# Epoch 129/150 - Loss: 1.991   lengthscale: 1.196   noise: 0.576
# tensor(1.9837, grad_fn=<NegBackward0>)
# Epoch 130/150 - Loss: 1.984   lengthscale: 1.201   noise: 0.572
# tensor(1.9765, grad_fn=<NegBackward0>)
# Epoch 131/150 - Loss: 1.977   lengthscale: 1.206   noise: 0.569
# tensor(1.9694, grad_fn=<NegBackward0>)
# Epoch 132/150 - Loss: 1.969   lengthscale: 1.210   noise: 0.565
# tensor(1.9624, grad_fn=<NegBackward0>)
# Epoch 133/150 - Loss: 1.962   lengthscale: 1.215   noise: 0.562
# tensor(1.9554, grad_fn=<NegBackward0>)
# Epoch 134/150 - Loss: 1.955   lengthscale: 1.220   noise: 0.559
# tensor(1.9485, grad_fn=<NegBackward0>)
# Epoch 135/150 - Loss: 1.949   lengthscale: 1.225   noise: 0.555
# tensor(1.9417, grad_fn=<NegBackward0>)
# Epoch 136/150 - Loss: 1.942   lengthscale: 1.229   noise: 0.552
# tensor(1.9349, grad_fn=<NegBackward0>)
# Epoch 137/150 - Loss: 1.935   lengthscale: 1.234   noise: 0.549
# tensor(1.9282, grad_fn=<NegBackward0>)
# Epoch 138/150 - Loss: 1.928   lengthscale: 1.239   noise: 0.546
# tensor(1.9216, grad_fn=<NegBackward0>)
# Epoch 139/150 - Loss: 1.922   lengthscale: 1.243   noise: 0.543
# tensor(1.9150, grad_fn=<NegBackward0>)
# Epoch 140/150 - Loss: 1.915   lengthscale: 1.248   noise: 0.540
# tensor(1.9086, grad_fn=<NegBackward0>)
# Epoch 141/150 - Loss: 1.909   lengthscale: 1.252   noise: 0.537
# tensor(1.9021, grad_fn=<NegBackward0>)
# Epoch 142/150 - Loss: 1.902   lengthscale: 1.257   noise: 0.534
# tensor(1.8958, grad_fn=<NegBackward0>)
# Epoch 143/150 - Loss: 1.896   lengthscale: 1.261   noise: 0.531
# tensor(1.8895, grad_fn=<NegBackward0>)
# Epoch 144/150 - Loss: 1.889   lengthscale: 1.266   noise: 0.528
# tensor(1.8833, grad_fn=<NegBackward0>)
# Epoch 145/150 - Loss: 1.883   lengthscale: 1.270   noise: 0.525
# tensor(1.8771, grad_fn=<NegBackward0>)
# Epoch 146/150 - Loss: 1.877   lengthscale: 1.275   noise: 0.523
# tensor(1.8710, grad_fn=<NegBackward0>)
# Epoch 147/150 - Loss: 1.871   lengthscale: 1.279   noise: 0.520
# tensor(1.8649, grad_fn=<NegBackward0>)
# Epoch 148/150 - Loss: 1.865   lengthscale: 1.284   noise: 0.517
# tensor(1.8590, grad_fn=<NegBackward0>)
# Epoch 149/150 - Loss: 1.859   lengthscale: 1.288   noise: 0.515
# tensor(1.8530, grad_fn=<NegBackward0>)
# Epoch 150/150 - Loss: 1.853   lengthscale: 1.292   noise: 0.513
# Step: 1, Val-Loss: 1.2800
# [10.349117 10.1066   10.419815 ... 10.413055 10.542593 10.532055]
# Step: 1 of 10, time-taken: 13.06 seconds
# K_D, P_D (20, 2) (1980, 2)
# torch.Size([18, 1])
# torch.float32
# tensor(22.7047, grad_fn=<NegBackward0>)
# Epoch 1/150 - Loss: 22.705   lengthscale: 0.100   noise: 0.010
# tensor(19.5617, grad_fn=<NegBackward0>)
# Epoch 2/150 - Loss: 19.562   lengthscale: 0.110   noise: 0.011
# tensor(16.8881, grad_fn=<NegBackward0>)
# Epoch 3/150 - Loss: 16.888   lengthscale: 0.121   noise: 0.012
# tensor(14.6112, grad_fn=<NegBackward0>)
# Epoch 4/150 - Loss: 14.611   lengthscale: 0.132   noise: 0.013
# tensor(12.6831, grad_fn=<NegBackward0>)
# Epoch 5/150 - Loss: 12.683   lengthscale: 0.145   noise: 0.015
# tensor(11.0523, grad_fn=<NegBackward0>)
# Epoch 6/150 - Loss: 11.052   lengthscale: 0.158   noise: 0.016
# tensor(9.6811, grad_fn=<NegBackward0>)
# Epoch 7/150 - Loss: 9.681   lengthscale: 0.173   noise: 0.018
# tensor(8.5433, grad_fn=<NegBackward0>)
# Epoch 8/150 - Loss: 8.543   lengthscale: 0.187   noise: 0.020
# tensor(7.6129, grad_fn=<NegBackward0>)
# Epoch 9/150 - Loss: 7.613   lengthscale: 0.203   noise: 0.022
# tensor(6.8590, grad_fn=<NegBackward0>)
# Epoch 10/150 - Loss: 6.859   lengthscale: 0.219   noise: 0.024
# tensor(6.2437, grad_fn=<NegBackward0>)
# Epoch 11/150 - Loss: 6.244   lengthscale: 0.235   noise: 0.026
# tensor(5.7289, grad_fn=<NegBackward0>)
# Epoch 12/150 - Loss: 5.729   lengthscale: 0.251   noise: 0.029
# tensor(5.2866, grad_fn=<NegBackward0>)
# Epoch 13/150 - Loss: 5.287   lengthscale: 0.267   noise: 0.031
# tensor(4.9011, grad_fn=<NegBackward0>)
# Epoch 14/150 - Loss: 4.901   lengthscale: 0.283   noise: 0.034
# tensor(4.5648, grad_fn=<NegBackward0>)
# Epoch 15/150 - Loss: 4.565   lengthscale: 0.299   noise: 0.037
# tensor(4.2740, grad_fn=<NegBackward0>)
# Epoch 16/150 - Loss: 4.274   lengthscale: 0.315   noise: 0.040
# tensor(4.0261, grad_fn=<NegBackward0>)
# Epoch 17/150 - Loss: 4.026   lengthscale: 0.330   noise: 0.043
# tensor(3.8180, grad_fn=<NegBackward0>)
# Epoch 18/150 - Loss: 3.818   lengthscale: 0.346   noise: 0.046
# tensor(3.6458, grad_fn=<NegBackward0>)
# Epoch 19/150 - Loss: 3.646   lengthscale: 0.360   noise: 0.050
# tensor(3.5048, grad_fn=<NegBackward0>)
# Epoch 20/150 - Loss: 3.505   lengthscale: 0.374   noise: 0.053
# tensor(3.3894, grad_fn=<NegBackward0>)
# Epoch 21/150 - Loss: 3.389   lengthscale: 0.387   noise: 0.057
# tensor(3.2938, grad_fn=<NegBackward0>)
# Epoch 22/150 - Loss: 3.294   lengthscale: 0.399   noise: 0.061
# tensor(3.2129, grad_fn=<NegBackward0>)
# Epoch 23/150 - Loss: 3.213   lengthscale: 0.409   noise: 0.064
# tensor(3.1423, grad_fn=<NegBackward0>)
# Epoch 24/150 - Loss: 3.142   lengthscale: 0.419   noise: 0.068
# tensor(3.0785, grad_fn=<NegBackward0>)
# Epoch 25/150 - Loss: 3.078   lengthscale: 0.427   noise: 0.072
# tensor(3.0191, grad_fn=<NegBackward0>)
# Epoch 26/150 - Loss: 3.019   lengthscale: 0.434   noise: 0.076
# tensor(2.9626, grad_fn=<NegBackward0>)
# Epoch 27/150 - Loss: 2.963   lengthscale: 0.439   noise: 0.079
# tensor(2.9080, grad_fn=<NegBackward0>)
# Epoch 28/150 - Loss: 2.908   lengthscale: 0.444   noise: 0.083
# tensor(2.8549, grad_fn=<NegBackward0>)
# Epoch 29/150 - Loss: 2.855   lengthscale: 0.447   noise: 0.087
# tensor(2.8031, grad_fn=<NegBackward0>)
# Epoch 30/150 - Loss: 2.803   lengthscale: 0.449   noise: 0.091
# tensor(2.7524, grad_fn=<NegBackward0>)
# Epoch 31/150 - Loss: 2.752   lengthscale: 0.450   noise: 0.095
# tensor(2.7032, grad_fn=<NegBackward0>)
# Epoch 32/150 - Loss: 2.703   lengthscale: 0.451   noise: 0.099
# tensor(2.6553, grad_fn=<NegBackward0>)
# Epoch 33/150 - Loss: 2.655   lengthscale: 0.450   noise: 0.103
# tensor(2.6091, grad_fn=<NegBackward0>)
# Epoch 34/150 - Loss: 2.609   lengthscale: 0.449   noise: 0.107
# tensor(2.5646, grad_fn=<NegBackward0>)
# Epoch 35/150 - Loss: 2.565   lengthscale: 0.447   noise: 0.110
# tensor(2.5218, grad_fn=<NegBackward0>)
# Epoch 36/150 - Loss: 2.522   lengthscale: 0.445   noise: 0.114
# tensor(2.4809, grad_fn=<NegBackward0>)
# Epoch 37/150 - Loss: 2.481   lengthscale: 0.442   noise: 0.118
# tensor(2.4419, grad_fn=<NegBackward0>)
# Epoch 38/150 - Loss: 2.442   lengthscale: 0.439   noise: 0.121
# tensor(2.4047, grad_fn=<NegBackward0>)
# Epoch 39/150 - Loss: 2.405   lengthscale: 0.436   noise: 0.125
# tensor(2.3693, grad_fn=<NegBackward0>)
# Epoch 40/150 - Loss: 2.369   lengthscale: 0.432   noise: 0.128
# tensor(2.3358, grad_fn=<NegBackward0>)
# Epoch 41/150 - Loss: 2.336   lengthscale: 0.429   noise: 0.131
# tensor(2.3040, grad_fn=<NegBackward0>)
# Epoch 42/150 - Loss: 2.304   lengthscale: 0.425   noise: 0.134
# tensor(2.2739, grad_fn=<NegBackward0>)
# Epoch 43/150 - Loss: 2.274   lengthscale: 0.421   noise: 0.137
# tensor(2.2453, grad_fn=<NegBackward0>)
# Epoch 44/150 - Loss: 2.245   lengthscale: 0.417   noise: 0.140
# tensor(2.2183, grad_fn=<NegBackward0>)
# Epoch 45/150 - Loss: 2.218   lengthscale: 0.413   noise: 0.142
# tensor(2.1927, grad_fn=<NegBackward0>)
# Epoch 46/150 - Loss: 2.193   lengthscale: 0.409   noise: 0.145
# tensor(2.1683, grad_fn=<NegBackward0>)
# Epoch 47/150 - Loss: 2.168   lengthscale: 0.405   noise: 0.147
# tensor(2.1452, grad_fn=<NegBackward0>)
# Epoch 48/150 - Loss: 2.145   lengthscale: 0.401   noise: 0.149
# tensor(2.1232, grad_fn=<NegBackward0>)
# Epoch 49/150 - Loss: 2.123   lengthscale: 0.398   noise: 0.151
# tensor(2.1023, grad_fn=<NegBackward0>)
# Epoch 50/150 - Loss: 2.102   lengthscale: 0.394   noise: 0.152
# tensor(2.0822, grad_fn=<NegBackward0>)
# Epoch 51/150 - Loss: 2.082   lengthscale: 0.391   noise: 0.154
# tensor(2.0630, grad_fn=<NegBackward0>)
# Epoch 52/150 - Loss: 2.063   lengthscale: 0.388   noise: 0.155
# tensor(2.0446, grad_fn=<NegBackward0>)
# Epoch 53/150 - Loss: 2.045   lengthscale: 0.385   noise: 0.156
# tensor(2.0268, grad_fn=<NegBackward0>)
# Epoch 54/150 - Loss: 2.027   lengthscale: 0.382   noise: 0.157
# tensor(2.0097, grad_fn=<NegBackward0>)
# Epoch 55/150 - Loss: 2.010   lengthscale: 0.379   noise: 0.158
# tensor(1.9931, grad_fn=<NegBackward0>)
# Epoch 56/150 - Loss: 1.993   lengthscale: 0.376   noise: 0.159
# tensor(1.9770, grad_fn=<NegBackward0>)
# Epoch 57/150 - Loss: 1.977   lengthscale: 0.374   noise: 0.159
# tensor(1.9613, grad_fn=<NegBackward0>)
# Epoch 58/150 - Loss: 1.961   lengthscale: 0.372   noise: 0.159
# tensor(1.9461, grad_fn=<NegBackward0>)
# Epoch 59/150 - Loss: 1.946   lengthscale: 0.370   noise: 0.159
# tensor(1.9311, grad_fn=<NegBackward0>)
# Epoch 60/150 - Loss: 1.931   lengthscale: 0.368   noise: 0.160
# tensor(1.9165, grad_fn=<NegBackward0>)
# Epoch 61/150 - Loss: 1.917   lengthscale: 0.366   noise: 0.159
# tensor(1.9022, grad_fn=<NegBackward0>)
# Epoch 62/150 - Loss: 1.902   lengthscale: 0.365   noise: 0.159
# tensor(1.8881, grad_fn=<NegBackward0>)
# Epoch 63/150 - Loss: 1.888   lengthscale: 0.363   noise: 0.159
# tensor(1.8743, grad_fn=<NegBackward0>)
# Epoch 64/150 - Loss: 1.874   lengthscale: 0.362   noise: 0.159
# tensor(1.8607, grad_fn=<NegBackward0>)
# Epoch 65/150 - Loss: 1.861   lengthscale: 0.361   noise: 0.158
# tensor(1.8473, grad_fn=<NegBackward0>)
# Epoch 66/150 - Loss: 1.847   lengthscale: 0.360   noise: 0.158
# tensor(1.8341, grad_fn=<NegBackward0>)
# Epoch 67/150 - Loss: 1.834   lengthscale: 0.359   noise: 0.157
# tensor(1.8211, grad_fn=<NegBackward0>)
# Epoch 68/150 - Loss: 1.821   lengthscale: 0.358   noise: 0.156
# tensor(1.8082, grad_fn=<NegBackward0>)
# Epoch 69/150 - Loss: 1.808   lengthscale: 0.358   noise: 0.155
# tensor(1.7956, grad_fn=<NegBackward0>)
# Epoch 70/150 - Loss: 1.796   lengthscale: 0.357   noise: 0.155
# tensor(1.7831, grad_fn=<NegBackward0>)
# Epoch 71/150 - Loss: 1.783   lengthscale: 0.357   noise: 0.154
# tensor(1.7708, grad_fn=<NegBackward0>)
# Epoch 72/150 - Loss: 1.771   lengthscale: 0.356   noise: 0.153
# tensor(1.7587, grad_fn=<NegBackward0>)
# Epoch 73/150 - Loss: 1.759   lengthscale: 0.356   noise: 0.152
# tensor(1.7467, grad_fn=<NegBackward0>)
# Epoch 74/150 - Loss: 1.747   lengthscale: 0.356   noise: 0.151
# tensor(1.7349, grad_fn=<NegBackward0>)
# Epoch 75/150 - Loss: 1.735   lengthscale: 0.356   noise: 0.150
# tensor(1.7233, grad_fn=<NegBackward0>)
# Epoch 76/150 - Loss: 1.723   lengthscale: 0.355   noise: 0.149
# tensor(1.7119, grad_fn=<NegBackward0>)
# Epoch 77/150 - Loss: 1.712   lengthscale: 0.355   noise: 0.148
# tensor(1.7006, grad_fn=<NegBackward0>)
# Epoch 78/150 - Loss: 1.701   lengthscale: 0.355   noise: 0.147
# tensor(1.6895, grad_fn=<NegBackward0>)
# Epoch 79/150 - Loss: 1.690   lengthscale: 0.355   noise: 0.146
# tensor(1.6786, grad_fn=<NegBackward0>)
# Epoch 80/150 - Loss: 1.679   lengthscale: 0.355   noise: 0.145
# tensor(1.6679, grad_fn=<NegBackward0>)
# Epoch 81/150 - Loss: 1.668   lengthscale: 0.355   noise: 0.144
# tensor(1.6573, grad_fn=<NegBackward0>)
# Epoch 82/150 - Loss: 1.657   lengthscale: 0.355   noise: 0.143
# tensor(1.6469, grad_fn=<NegBackward0>)
# Epoch 83/150 - Loss: 1.647   lengthscale: 0.355   noise: 0.142
# tensor(1.6366, grad_fn=<NegBackward0>)
# Epoch 84/150 - Loss: 1.637   lengthscale: 0.355   noise: 0.141
# tensor(1.6265, grad_fn=<NegBackward0>)
# Epoch 85/150 - Loss: 1.627   lengthscale: 0.355   noise: 0.140
# tensor(1.6166, grad_fn=<NegBackward0>)
# Epoch 86/150 - Loss: 1.617   lengthscale: 0.355   noise: 0.139
# tensor(1.6068, grad_fn=<NegBackward0>)
# Epoch 87/150 - Loss: 1.607   lengthscale: 0.355   noise: 0.138
# tensor(1.5972, grad_fn=<NegBackward0>)
# Epoch 88/150 - Loss: 1.597   lengthscale: 0.355   noise: 0.137
# tensor(1.5877, grad_fn=<NegBackward0>)
# Epoch 89/150 - Loss: 1.588   lengthscale: 0.355   noise: 0.136
# tensor(1.5784, grad_fn=<NegBackward0>)
# Epoch 90/150 - Loss: 1.578   lengthscale: 0.355   noise: 0.135
# tensor(1.5693, grad_fn=<NegBackward0>)
# Epoch 91/150 - Loss: 1.569   lengthscale: 0.355   noise: 0.134
# tensor(1.5602, grad_fn=<NegBackward0>)
# Epoch 92/150 - Loss: 1.560   lengthscale: 0.355   noise: 0.134
# tensor(1.5513, grad_fn=<NegBackward0>)
# Epoch 93/150 - Loss: 1.551   lengthscale: 0.355   noise: 0.133
# tensor(1.5426, grad_fn=<NegBackward0>)
# Epoch 94/150 - Loss: 1.543   lengthscale: 0.355   noise: 0.132
# tensor(1.5340, grad_fn=<NegBackward0>)
# Epoch 95/150 - Loss: 1.534   lengthscale: 0.355   noise: 0.131
# tensor(1.5255, grad_fn=<NegBackward0>)
# Epoch 96/150 - Loss: 1.525   lengthscale: 0.355   noise: 0.130
# tensor(1.5171, grad_fn=<NegBackward0>)
# Epoch 97/150 - Loss: 1.517   lengthscale: 0.355   noise: 0.130
# tensor(1.5089, grad_fn=<NegBackward0>)
# Epoch 98/150 - Loss: 1.509   lengthscale: 0.354   noise: 0.129
# tensor(1.5008, grad_fn=<NegBackward0>)
# Epoch 99/150 - Loss: 1.501   lengthscale: 0.354   noise: 0.128
# tensor(1.4928, grad_fn=<NegBackward0>)
# Epoch 100/150 - Loss: 1.493   lengthscale: 0.354   noise: 0.128
# tensor(1.4849, grad_fn=<NegBackward0>)
# Epoch 101/150 - Loss: 1.485   lengthscale: 0.354   noise: 0.127
# tensor(1.4771, grad_fn=<NegBackward0>)
# Epoch 102/150 - Loss: 1.477   lengthscale: 0.354   noise: 0.126
# tensor(1.4695, grad_fn=<NegBackward0>)
# Epoch 103/150 - Loss: 1.469   lengthscale: 0.353   noise: 0.126
# tensor(1.4619, grad_fn=<NegBackward0>)
# Epoch 104/150 - Loss: 1.462   lengthscale: 0.353   noise: 0.125
# tensor(1.4545, grad_fn=<NegBackward0>)
# Epoch 105/150 - Loss: 1.455   lengthscale: 0.353   noise: 0.125
# tensor(1.4472, grad_fn=<NegBackward0>)
# Epoch 106/150 - Loss: 1.447   lengthscale: 0.352   noise: 0.124
# tensor(1.4399, grad_fn=<NegBackward0>)
# Epoch 107/150 - Loss: 1.440   lengthscale: 0.352   noise: 0.124
# tensor(1.4328, grad_fn=<NegBackward0>)
# Epoch 108/150 - Loss: 1.433   lengthscale: 0.352   noise: 0.123
# tensor(1.4258, grad_fn=<NegBackward0>)
# Epoch 109/150 - Loss: 1.426   lengthscale: 0.351   noise: 0.123
# tensor(1.4188, grad_fn=<NegBackward0>)
# Epoch 110/150 - Loss: 1.419   lengthscale: 0.351   noise: 0.122
# tensor(1.4120, grad_fn=<NegBackward0>)
# Epoch 111/150 - Loss: 1.412   lengthscale: 0.351   noise: 0.122
# tensor(1.4052, grad_fn=<NegBackward0>)
# Epoch 112/150 - Loss: 1.405   lengthscale: 0.350   noise: 0.121
# tensor(1.3985, grad_fn=<NegBackward0>)
# Epoch 113/150 - Loss: 1.399   lengthscale: 0.350   noise: 0.121
# tensor(1.3920, grad_fn=<NegBackward0>)
# Epoch 114/150 - Loss: 1.392   lengthscale: 0.350   noise: 0.121
# tensor(1.3855, grad_fn=<NegBackward0>)
# Epoch 115/150 - Loss: 1.385   lengthscale: 0.349   noise: 0.120
# tensor(1.3791, grad_fn=<NegBackward0>)
# Epoch 116/150 - Loss: 1.379   lengthscale: 0.349   noise: 0.120
# tensor(1.3727, grad_fn=<NegBackward0>)
# Epoch 117/150 - Loss: 1.373   lengthscale: 0.348   noise: 0.120
# tensor(1.3665, grad_fn=<NegBackward0>)
# Epoch 118/150 - Loss: 1.367   lengthscale: 0.348   noise: 0.120
# tensor(1.3603, grad_fn=<NegBackward0>)
# Epoch 119/150 - Loss: 1.360   lengthscale: 0.348   noise: 0.119
# tensor(1.3543, grad_fn=<NegBackward0>)
# Epoch 120/150 - Loss: 1.354   lengthscale: 0.347   noise: 0.119
# tensor(1.3483, grad_fn=<NegBackward0>)
# Epoch 121/150 - Loss: 1.348   lengthscale: 0.347   noise: 0.119
# tensor(1.3423, grad_fn=<NegBackward0>)
# Epoch 122/150 - Loss: 1.342   lengthscale: 0.347   noise: 0.119
# tensor(1.3365, grad_fn=<NegBackward0>)
# Epoch 123/150 - Loss: 1.336   lengthscale: 0.346   noise: 0.119
# tensor(1.3307, grad_fn=<NegBackward0>)
# Epoch 124/150 - Loss: 1.331   lengthscale: 0.346   noise: 0.118
# tensor(1.3250, grad_fn=<NegBackward0>)
# Epoch 125/150 - Loss: 1.325   lengthscale: 0.346   noise: 0.118
# tensor(1.3194, grad_fn=<NegBackward0>)
# Epoch 126/150 - Loss: 1.319   lengthscale: 0.345   noise: 0.118
# tensor(1.3138, grad_fn=<NegBackward0>)
# Epoch 127/150 - Loss: 1.314   lengthscale: 0.345   noise: 0.118
# tensor(1.3083, grad_fn=<NegBackward0>)
# Epoch 128/150 - Loss: 1.308   lengthscale: 0.345   noise: 0.118
# tensor(1.3029, grad_fn=<NegBackward0>)
# Epoch 129/150 - Loss: 1.303   lengthscale: 0.344   noise: 0.118
# tensor(1.2975, grad_fn=<NegBackward0>)
# Epoch 130/150 - Loss: 1.298   lengthscale: 0.344   noise: 0.118
# tensor(1.2922, grad_fn=<NegBackward0>)
# Epoch 131/150 - Loss: 1.292   lengthscale: 0.344   noise: 0.118
# tensor(1.2870, grad_fn=<NegBackward0>)
# Epoch 132/150 - Loss: 1.287   lengthscale: 0.343   noise: 0.118
# tensor(1.2818, grad_fn=<NegBackward0>)
# Epoch 133/150 - Loss: 1.282   lengthscale: 0.343   noise: 0.118
# tensor(1.2767, grad_fn=<NegBackward0>)
# Epoch 134/150 - Loss: 1.277   lengthscale: 0.343   noise: 0.117
# tensor(1.2717, grad_fn=<NegBackward0>)
# Epoch 135/150 - Loss: 1.272   lengthscale: 0.342   noise: 0.117
# tensor(1.2667, grad_fn=<NegBackward0>)
# Epoch 136/150 - Loss: 1.267   lengthscale: 0.342   noise: 0.117
# tensor(1.2618, grad_fn=<NegBackward0>)
# Epoch 137/150 - Loss: 1.262   lengthscale: 0.342   noise: 0.117
# tensor(1.2569, grad_fn=<NegBackward0>)
# Epoch 138/150 - Loss: 1.257   lengthscale: 0.342   noise: 0.117
# tensor(1.2521, grad_fn=<NegBackward0>)
# Epoch 139/150 - Loss: 1.252   lengthscale: 0.341   noise: 0.117
# tensor(1.2474, grad_fn=<NegBackward0>)
# Epoch 140/150 - Loss: 1.247   lengthscale: 0.341   noise: 0.117
# tensor(1.2427, grad_fn=<NegBackward0>)
# Epoch 141/150 - Loss: 1.243   lengthscale: 0.341   noise: 0.117
# tensor(1.2381, grad_fn=<NegBackward0>)
# Epoch 142/150 - Loss: 1.238   lengthscale: 0.341   noise: 0.117
# tensor(1.2335, grad_fn=<NegBackward0>)
# Epoch 143/150 - Loss: 1.233   lengthscale: 0.340   noise: 0.117
# tensor(1.2290, grad_fn=<NegBackward0>)
# Epoch 144/150 - Loss: 1.229   lengthscale: 0.340   noise: 0.117
# tensor(1.2245, grad_fn=<NegBackward0>)
# Epoch 145/150 - Loss: 1.224   lengthscale: 0.340   noise: 0.117
# tensor(1.2201, grad_fn=<NegBackward0>)
# Epoch 146/150 - Loss: 1.220   lengthscale: 0.340   noise: 0.117
# tensor(1.2157, grad_fn=<NegBackward0>)
# Epoch 147/150 - Loss: 1.216   lengthscale: 0.339   noise: 0.117
# tensor(1.2114, grad_fn=<NegBackward0>)
# Epoch 148/150 - Loss: 1.211   lengthscale: 0.339   noise: 0.117
# tensor(1.2071, grad_fn=<NegBackward0>)
# Epoch 149/150 - Loss: 1.207   lengthscale: 0.339   noise: 0.117
# tensor(1.2029, grad_fn=<NegBackward0>)
# Epoch 150/150 - Loss: 1.203   lengthscale: 0.339   noise: 0.117
# Step: 2, Val-Loss: 6.4815
# [ 9.319548 10.148442  9.422626 ...  9.398891 10.767772 10.739778]
# Step: 2 of 10, time-taken: 13.24 seconds
# K_D, P_D (30, 2) (1970, 2)
# torch.Size([27, 1])
# torch.float32
# tensor(17.7323, grad_fn=<NegBackward0>)
# Epoch 1/150 - Loss: 17.732   lengthscale: 0.100   noise: 0.010
# tensor(15.3852, grad_fn=<NegBackward0>)
# Epoch 2/150 - Loss: 15.385   lengthscale: 0.110   noise: 0.011
# tensor(13.3394, grad_fn=<NegBackward0>)
# Epoch 3/150 - Loss: 13.339   lengthscale: 0.121   noise: 0.012
# tensor(11.6277, grad_fn=<NegBackward0>)
# Epoch 4/150 - Loss: 11.628   lengthscale: 0.133   noise: 0.013
# tensor(10.2134, grad_fn=<NegBackward0>)
# Epoch 5/150 - Loss: 10.213   lengthscale: 0.145   noise: 0.015
# tensor(9.0142, grad_fn=<NegBackward0>)
# Epoch 6/150 - Loss: 9.014   lengthscale: 0.158   noise: 0.016
# tensor(7.9690, grad_fn=<NegBackward0>)
# Epoch 7/150 - Loss: 7.969   lengthscale: 0.172   noise: 0.018
# tensor(7.0579, grad_fn=<NegBackward0>)
# Epoch 8/150 - Loss: 7.058   lengthscale: 0.187   noise: 0.020
# tensor(6.2754, grad_fn=<NegBackward0>)
# Epoch 9/150 - Loss: 6.275   lengthscale: 0.203   noise: 0.022
# tensor(5.6099, grad_fn=<NegBackward0>)
# Epoch 10/150 - Loss: 5.610   lengthscale: 0.219   noise: 0.024
# tensor(5.0461, grad_fn=<NegBackward0>)
# Epoch 11/150 - Loss: 5.046   lengthscale: 0.235   noise: 0.026
# tensor(4.5712, grad_fn=<NegBackward0>)
# Epoch 12/150 - Loss: 4.571   lengthscale: 0.252   noise: 0.028
# tensor(4.1755, grad_fn=<NegBackward0>)
# Epoch 13/150 - Loss: 4.176   lengthscale: 0.270   noise: 0.031
# tensor(3.8501, grad_fn=<NegBackward0>)
# Epoch 14/150 - Loss: 3.850   lengthscale: 0.287   noise: 0.033
# tensor(3.5859, grad_fn=<NegBackward0>)
# Epoch 15/150 - Loss: 3.586   lengthscale: 0.305   noise: 0.036
# tensor(3.3736, grad_fn=<NegBackward0>)
# Epoch 16/150 - Loss: 3.374   lengthscale: 0.321   noise: 0.039
# tensor(3.2045, grad_fn=<NegBackward0>)
# Epoch 17/150 - Loss: 3.205   lengthscale: 0.337   noise: 0.042
# tensor(3.0706, grad_fn=<NegBackward0>)
# Epoch 18/150 - Loss: 3.071   lengthscale: 0.353   noise: 0.045
# tensor(2.9641, grad_fn=<NegBackward0>)
# Epoch 19/150 - Loss: 2.964   lengthscale: 0.366   noise: 0.048
# tensor(2.8773, grad_fn=<NegBackward0>)
# Epoch 20/150 - Loss: 2.877   lengthscale: 0.379   noise: 0.051
# tensor(2.8034, grad_fn=<NegBackward0>)
# Epoch 21/150 - Loss: 2.803   lengthscale: 0.389   noise: 0.054
# tensor(2.7365, grad_fn=<NegBackward0>)
# Epoch 22/150 - Loss: 2.737   lengthscale: 0.398   noise: 0.057
# tensor(2.6726, grad_fn=<NegBackward0>)
# Epoch 23/150 - Loss: 2.673   lengthscale: 0.404   noise: 0.061
# tensor(2.6091, grad_fn=<NegBackward0>)
# Epoch 24/150 - Loss: 2.609   lengthscale: 0.409   noise: 0.064
# tensor(2.5448, grad_fn=<NegBackward0>)
# Epoch 25/150 - Loss: 2.545   lengthscale: 0.411   noise: 0.067
# tensor(2.4795, grad_fn=<NegBackward0>)
# Epoch 26/150 - Loss: 2.479   lengthscale: 0.412   noise: 0.071
# tensor(2.4137, grad_fn=<NegBackward0>)
# Epoch 27/150 - Loss: 2.414   lengthscale: 0.412   noise: 0.074
# tensor(2.3482, grad_fn=<NegBackward0>)
# Epoch 28/150 - Loss: 2.348   lengthscale: 0.410   noise: 0.078
# tensor(2.2839, grad_fn=<NegBackward0>)
# Epoch 29/150 - Loss: 2.284   lengthscale: 0.406   noise: 0.081
# tensor(2.2218, grad_fn=<NegBackward0>)
# Epoch 30/150 - Loss: 2.222   lengthscale: 0.402   noise: 0.084
# tensor(2.1627, grad_fn=<NegBackward0>)
# Epoch 31/150 - Loss: 2.163   lengthscale: 0.397   noise: 0.088
# tensor(2.1070, grad_fn=<NegBackward0>)
# Epoch 32/150 - Loss: 2.107   lengthscale: 0.392   noise: 0.091
# tensor(2.0553, grad_fn=<NegBackward0>)
# Epoch 33/150 - Loss: 2.055   lengthscale: 0.386   noise: 0.094
# tensor(2.0078, grad_fn=<NegBackward0>)
# Epoch 34/150 - Loss: 2.008   lengthscale: 0.379   noise: 0.097
# tensor(1.9645, grad_fn=<NegBackward0>)
# Epoch 35/150 - Loss: 1.965   lengthscale: 0.373   noise: 0.100
# tensor(1.9253, grad_fn=<NegBackward0>)
# Epoch 36/150 - Loss: 1.925   lengthscale: 0.367   noise: 0.103
# tensor(1.8900, grad_fn=<NegBackward0>)
# Epoch 37/150 - Loss: 1.890   lengthscale: 0.361   noise: 0.106
# tensor(1.8582, grad_fn=<NegBackward0>)
# Epoch 38/150 - Loss: 1.858   lengthscale: 0.355   noise: 0.109
# tensor(1.8297, grad_fn=<NegBackward0>)
# Epoch 39/150 - Loss: 1.830   lengthscale: 0.349   noise: 0.112
# tensor(1.8040, grad_fn=<NegBackward0>)
# Epoch 40/150 - Loss: 1.804   lengthscale: 0.344   noise: 0.114
# tensor(1.7807, grad_fn=<NegBackward0>)
# Epoch 41/150 - Loss: 1.781   lengthscale: 0.339   noise: 0.116
# tensor(1.7596, grad_fn=<NegBackward0>)
# Epoch 42/150 - Loss: 1.760   lengthscale: 0.334   noise: 0.119
# tensor(1.7402, grad_fn=<NegBackward0>)
# Epoch 43/150 - Loss: 1.740   lengthscale: 0.330   noise: 0.121
# tensor(1.7222, grad_fn=<NegBackward0>)
# Epoch 44/150 - Loss: 1.722   lengthscale: 0.326   noise: 0.123
# tensor(1.7055, grad_fn=<NegBackward0>)
# Epoch 45/150 - Loss: 1.705   lengthscale: 0.323   noise: 0.125
# tensor(1.6897, grad_fn=<NegBackward0>)
# Epoch 46/150 - Loss: 1.690   lengthscale: 0.320   noise: 0.127
# tensor(1.6747, grad_fn=<NegBackward0>)
# Epoch 47/150 - Loss: 1.675   lengthscale: 0.317   noise: 0.128
# tensor(1.6603, grad_fn=<NegBackward0>)
# Epoch 48/150 - Loss: 1.660   lengthscale: 0.315   noise: 0.130
# tensor(1.6465, grad_fn=<NegBackward0>)
# Epoch 49/150 - Loss: 1.646   lengthscale: 0.313   noise: 0.131
# tensor(1.6330, grad_fn=<NegBackward0>)
# Epoch 50/150 - Loss: 1.633   lengthscale: 0.311   noise: 0.133
# tensor(1.6199, grad_fn=<NegBackward0>)
# Epoch 51/150 - Loss: 1.620   lengthscale: 0.310   noise: 0.134
# tensor(1.6071, grad_fn=<NegBackward0>)
# Epoch 52/150 - Loss: 1.607   lengthscale: 0.308   noise: 0.135
# tensor(1.5946, grad_fn=<NegBackward0>)
# Epoch 53/150 - Loss: 1.595   lengthscale: 0.308   noise: 0.136
# tensor(1.5823, grad_fn=<NegBackward0>)
# Epoch 54/150 - Loss: 1.582   lengthscale: 0.307   noise: 0.137
# tensor(1.5701, grad_fn=<NegBackward0>)
# Epoch 55/150 - Loss: 1.570   lengthscale: 0.307   noise: 0.138
# tensor(1.5582, grad_fn=<NegBackward0>)
# Epoch 56/150 - Loss: 1.558   lengthscale: 0.307   noise: 0.139
# tensor(1.5465, grad_fn=<NegBackward0>)
# Epoch 57/150 - Loss: 1.547   lengthscale: 0.307   noise: 0.140
# tensor(1.5350, grad_fn=<NegBackward0>)
# Epoch 58/150 - Loss: 1.535   lengthscale: 0.307   noise: 0.141
# tensor(1.5237, grad_fn=<NegBackward0>)
# Epoch 59/150 - Loss: 1.524   lengthscale: 0.307   noise: 0.141
# tensor(1.5126, grad_fn=<NegBackward0>)
# Epoch 60/150 - Loss: 1.513   lengthscale: 0.308   noise: 0.142
# tensor(1.5018, grad_fn=<NegBackward0>)
# Epoch 61/150 - Loss: 1.502   lengthscale: 0.308   noise: 0.142
# tensor(1.4911, grad_fn=<NegBackward0>)
# Epoch 62/150 - Loss: 1.491   lengthscale: 0.309   noise: 0.143
# tensor(1.4807, grad_fn=<NegBackward0>)
# Epoch 63/150 - Loss: 1.481   lengthscale: 0.310   noise: 0.143
# tensor(1.4706, grad_fn=<NegBackward0>)
# Epoch 64/150 - Loss: 1.471   lengthscale: 0.310   noise: 0.144
# tensor(1.4606, grad_fn=<NegBackward0>)
# Epoch 65/150 - Loss: 1.461   lengthscale: 0.311   noise: 0.144
# tensor(1.4509, grad_fn=<NegBackward0>)
# Epoch 66/150 - Loss: 1.451   lengthscale: 0.312   noise: 0.144
# tensor(1.4414, grad_fn=<NegBackward0>)
# Epoch 67/150 - Loss: 1.441   lengthscale: 0.313   noise: 0.145
# tensor(1.4322, grad_fn=<NegBackward0>)
# Epoch 68/150 - Loss: 1.432   lengthscale: 0.314   noise: 0.145
# tensor(1.4232, grad_fn=<NegBackward0>)
# Epoch 69/150 - Loss: 1.423   lengthscale: 0.314   noise: 0.145
# tensor(1.4143, grad_fn=<NegBackward0>)
# Epoch 70/150 - Loss: 1.414   lengthscale: 0.315   noise: 0.145
# tensor(1.4057, grad_fn=<NegBackward0>)
# Epoch 71/150 - Loss: 1.406   lengthscale: 0.316   noise: 0.145
# tensor(1.3973, grad_fn=<NegBackward0>)
# Epoch 72/150 - Loss: 1.397   lengthscale: 0.317   noise: 0.145
# tensor(1.3891, grad_fn=<NegBackward0>)
# Epoch 73/150 - Loss: 1.389   lengthscale: 0.317   noise: 0.145
# tensor(1.3810, grad_fn=<NegBackward0>)
# Epoch 74/150 - Loss: 1.381   lengthscale: 0.318   noise: 0.145
# tensor(1.3732, grad_fn=<NegBackward0>)
# Epoch 75/150 - Loss: 1.373   lengthscale: 0.319   noise: 0.145
# tensor(1.3654, grad_fn=<NegBackward0>)
# Epoch 76/150 - Loss: 1.365   lengthscale: 0.319   noise: 0.145
# tensor(1.3579, grad_fn=<NegBackward0>)
# Epoch 77/150 - Loss: 1.358   lengthscale: 0.320   noise: 0.145
# tensor(1.3504, grad_fn=<NegBackward0>)
# Epoch 78/150 - Loss: 1.350   lengthscale: 0.320   noise: 0.145
# tensor(1.3431, grad_fn=<NegBackward0>)
# Epoch 79/150 - Loss: 1.343   lengthscale: 0.320   noise: 0.145
# tensor(1.3359, grad_fn=<NegBackward0>)
# Epoch 80/150 - Loss: 1.336   lengthscale: 0.320   noise: 0.145
# tensor(1.3289, grad_fn=<NegBackward0>)
# Epoch 81/150 - Loss: 1.329   lengthscale: 0.320   noise: 0.145
# tensor(1.3219, grad_fn=<NegBackward0>)
# Epoch 82/150 - Loss: 1.322   lengthscale: 0.321   noise: 0.145
# tensor(1.3151, grad_fn=<NegBackward0>)
# Epoch 83/150 - Loss: 1.315   lengthscale: 0.321   noise: 0.145
# tensor(1.3083, grad_fn=<NegBackward0>)
# Epoch 84/150 - Loss: 1.308   lengthscale: 0.320   noise: 0.145
# tensor(1.3017, grad_fn=<NegBackward0>)
# Epoch 85/150 - Loss: 1.302   lengthscale: 0.320   noise: 0.145
# tensor(1.2951, grad_fn=<NegBackward0>)
# Epoch 86/150 - Loss: 1.295   lengthscale: 0.320   noise: 0.144
# tensor(1.2886, grad_fn=<NegBackward0>)
# Epoch 87/150 - Loss: 1.289   lengthscale: 0.320   noise: 0.144
# tensor(1.2823, grad_fn=<NegBackward0>)
# Epoch 88/150 - Loss: 1.282   lengthscale: 0.320   noise: 0.144
# tensor(1.2760, grad_fn=<NegBackward0>)
# Epoch 89/150 - Loss: 1.276   lengthscale: 0.319   noise: 0.144
# tensor(1.2698, grad_fn=<NegBackward0>)
# Epoch 90/150 - Loss: 1.270   lengthscale: 0.319   noise: 0.144
# tensor(1.2637, grad_fn=<NegBackward0>)
# Epoch 91/150 - Loss: 1.264   lengthscale: 0.318   noise: 0.144
# tensor(1.2576, grad_fn=<NegBackward0>)
# Epoch 92/150 - Loss: 1.258   lengthscale: 0.318   noise: 0.144
# tensor(1.2517, grad_fn=<NegBackward0>)
# Epoch 93/150 - Loss: 1.252   lengthscale: 0.317   noise: 0.143
# tensor(1.2459, grad_fn=<NegBackward0>)
# Epoch 94/150 - Loss: 1.246   lengthscale: 0.317   noise: 0.143
# tensor(1.2401, grad_fn=<NegBackward0>)
# Epoch 95/150 - Loss: 1.240   lengthscale: 0.316   noise: 0.143
# tensor(1.2344, grad_fn=<NegBackward0>)
# Epoch 96/150 - Loss: 1.234   lengthscale: 0.316   noise: 0.143
# tensor(1.2288, grad_fn=<NegBackward0>)
# Epoch 97/150 - Loss: 1.229   lengthscale: 0.315   noise: 0.143
# tensor(1.2232, grad_fn=<NegBackward0>)
# Epoch 98/150 - Loss: 1.223   lengthscale: 0.315   noise: 0.143
# tensor(1.2178, grad_fn=<NegBackward0>)
# Epoch 99/150 - Loss: 1.218   lengthscale: 0.314   noise: 0.142
# tensor(1.2124, grad_fn=<NegBackward0>)
# Epoch 100/150 - Loss: 1.212   lengthscale: 0.314   noise: 0.142
# tensor(1.2071, grad_fn=<NegBackward0>)
# Epoch 101/150 - Loss: 1.207   lengthscale: 0.313   noise: 0.142
# tensor(1.2018, grad_fn=<NegBackward0>)
# Epoch 102/150 - Loss: 1.202   lengthscale: 0.313   noise: 0.142
# tensor(1.1967, grad_fn=<NegBackward0>)
# Epoch 103/150 - Loss: 1.197   lengthscale: 0.312   noise: 0.142
# tensor(1.1916, grad_fn=<NegBackward0>)
# Epoch 104/150 - Loss: 1.192   lengthscale: 0.312   noise: 0.142
# tensor(1.1866, grad_fn=<NegBackward0>)
# Epoch 105/150 - Loss: 1.187   lengthscale: 0.311   noise: 0.141
# tensor(1.1816, grad_fn=<NegBackward0>)
# Epoch 106/150 - Loss: 1.182   lengthscale: 0.311   noise: 0.141
# tensor(1.1767, grad_fn=<NegBackward0>)
# Epoch 107/150 - Loss: 1.177   lengthscale: 0.310   noise: 0.141
# tensor(1.1719, grad_fn=<NegBackward0>)
# Epoch 108/150 - Loss: 1.172   lengthscale: 0.310   noise: 0.141
# tensor(1.1672, grad_fn=<NegBackward0>)
# Epoch 109/150 - Loss: 1.167   lengthscale: 0.309   noise: 0.141
# tensor(1.1625, grad_fn=<NegBackward0>)
# Epoch 110/150 - Loss: 1.162   lengthscale: 0.309   noise: 0.141
# tensor(1.1578, grad_fn=<NegBackward0>)
# Epoch 111/150 - Loss: 1.158   lengthscale: 0.308   noise: 0.140
# tensor(1.1533, grad_fn=<NegBackward0>)
# Epoch 112/150 - Loss: 1.153   lengthscale: 0.308   noise: 0.140
# tensor(1.1487, grad_fn=<NegBackward0>)
# Epoch 113/150 - Loss: 1.149   lengthscale: 0.308   noise: 0.140
# tensor(1.1443, grad_fn=<NegBackward0>)
# Epoch 114/150 - Loss: 1.144   lengthscale: 0.307   noise: 0.140
# tensor(1.1399, grad_fn=<NegBackward0>)
# Epoch 115/150 - Loss: 1.140   lengthscale: 0.307   noise: 0.140
# tensor(1.1356, grad_fn=<NegBackward0>)
# Epoch 116/150 - Loss: 1.136   lengthscale: 0.307   noise: 0.140
# tensor(1.1313, grad_fn=<NegBackward0>)
# Epoch 117/150 - Loss: 1.131   lengthscale: 0.306   noise: 0.140
# tensor(1.1270, grad_fn=<NegBackward0>)
# Epoch 118/150 - Loss: 1.127   lengthscale: 0.306   noise: 0.139
# tensor(1.1229, grad_fn=<NegBackward0>)
# Epoch 119/150 - Loss: 1.123   lengthscale: 0.306   noise: 0.139
# tensor(1.1187, grad_fn=<NegBackward0>)
# Epoch 120/150 - Loss: 1.119   lengthscale: 0.305   noise: 0.139
# tensor(1.1147, grad_fn=<NegBackward0>)
# Epoch 121/150 - Loss: 1.115   lengthscale: 0.305   noise: 0.139
# tensor(1.1106, grad_fn=<NegBackward0>)
# Epoch 122/150 - Loss: 1.111   lengthscale: 0.305   noise: 0.139
# tensor(1.1067, grad_fn=<NegBackward0>)
# Epoch 123/150 - Loss: 1.107   lengthscale: 0.305   noise: 0.139
# tensor(1.1027, grad_fn=<NegBackward0>)
# Epoch 124/150 - Loss: 1.103   lengthscale: 0.304   noise: 0.139
# tensor(1.0989, grad_fn=<NegBackward0>)
# Epoch 125/150 - Loss: 1.099   lengthscale: 0.304   noise: 0.139
# tensor(1.0950, grad_fn=<NegBackward0>)
# Epoch 126/150 - Loss: 1.095   lengthscale: 0.304   noise: 0.138
# tensor(1.0913, grad_fn=<NegBackward0>)
# Epoch 127/150 - Loss: 1.091   lengthscale: 0.304   noise: 0.138
# tensor(1.0875, grad_fn=<NegBackward0>)
# Epoch 128/150 - Loss: 1.088   lengthscale: 0.304   noise: 0.138
# tensor(1.0838, grad_fn=<NegBackward0>)
# Epoch 129/150 - Loss: 1.084   lengthscale: 0.303   noise: 0.138
# tensor(1.0802, grad_fn=<NegBackward0>)
# Epoch 130/150 - Loss: 1.080   lengthscale: 0.303   noise: 0.138
# tensor(1.0766, grad_fn=<NegBackward0>)
# Epoch 131/150 - Loss: 1.077   lengthscale: 0.303   noise: 0.138
# tensor(1.0730, grad_fn=<NegBackward0>)
# Epoch 132/150 - Loss: 1.073   lengthscale: 0.303   noise: 0.138
# tensor(1.0695, grad_fn=<NegBackward0>)
# Epoch 133/150 - Loss: 1.070   lengthscale: 0.302   noise: 0.138
# tensor(1.0661, grad_fn=<NegBackward0>)
# Epoch 134/150 - Loss: 1.066   lengthscale: 0.302   noise: 0.138
# tensor(1.0626, grad_fn=<NegBackward0>)
# Epoch 135/150 - Loss: 1.063   lengthscale: 0.302   noise: 0.138
# tensor(1.0592, grad_fn=<NegBackward0>)
# Epoch 136/150 - Loss: 1.059   lengthscale: 0.302   noise: 0.137
# tensor(1.0559, grad_fn=<NegBackward0>)
# Epoch 137/150 - Loss: 1.056   lengthscale: 0.302   noise: 0.137
# tensor(1.0526, grad_fn=<NegBackward0>)
# Epoch 138/150 - Loss: 1.053   lengthscale: 0.301   noise: 0.137
# tensor(1.0493, grad_fn=<NegBackward0>)
# Epoch 139/150 - Loss: 1.049   lengthscale: 0.301   noise: 0.137
# tensor(1.0461, grad_fn=<NegBackward0>)
# Epoch 140/150 - Loss: 1.046   lengthscale: 0.301   noise: 0.137
# tensor(1.0429, grad_fn=<NegBackward0>)
# Epoch 141/150 - Loss: 1.043   lengthscale: 0.301   noise: 0.137
# tensor(1.0398, grad_fn=<NegBackward0>)
# Epoch 142/150 - Loss: 1.040   lengthscale: 0.300   noise: 0.137
# tensor(1.0367, grad_fn=<NegBackward0>)
# Epoch 143/150 - Loss: 1.037   lengthscale: 0.300   noise: 0.137
# tensor(1.0336, grad_fn=<NegBackward0>)
# Epoch 144/150 - Loss: 1.034   lengthscale: 0.300   noise: 0.137
# tensor(1.0306, grad_fn=<NegBackward0>)
# Epoch 145/150 - Loss: 1.031   lengthscale: 0.300   noise: 0.137
# tensor(1.0276, grad_fn=<NegBackward0>)
# Epoch 146/150 - Loss: 1.028   lengthscale: 0.300   noise: 0.137
# tensor(1.0246, grad_fn=<NegBackward0>)
# Epoch 147/150 - Loss: 1.025   lengthscale: 0.299   noise: 0.137
# tensor(1.0217, grad_fn=<NegBackward0>)
# Epoch 148/150 - Loss: 1.022   lengthscale: 0.299   noise: 0.137
# tensor(1.0188, grad_fn=<NegBackward0>)
# Epoch 149/150 - Loss: 1.019   lengthscale: 0.299   noise: 0.137
# tensor(1.0159, grad_fn=<NegBackward0>)
# Epoch 150/150 - Loss: 1.016   lengthscale: 0.299   noise: 0.137
# Step: 3, Val-Loss: 4.3714
# [ 9.038849  10.122773   9.212751  ...  9.175901  10.970913  10.6664295]
# Step: 3 of 10, time-taken: 12.89 seconds
# K_D, P_D (40, 2) (1960, 2)
# torch.Size([36, 1])
# torch.float32
# tensor(15.2899, grad_fn=<NegBackward0>)
# Epoch 1/150 - Loss: 15.290   lengthscale: 0.100   noise: 0.010
# tensor(13.5039, grad_fn=<NegBackward0>)
# Epoch 2/150 - Loss: 13.504   lengthscale: 0.110   noise: 0.011
# tensor(11.8511, grad_fn=<NegBackward0>)
# Epoch 3/150 - Loss: 11.851   lengthscale: 0.121   noise: 0.012
# tensor(10.4101, grad_fn=<NegBackward0>)
# Epoch 4/150 - Loss: 10.410   lengthscale: 0.133   noise: 0.013
# tensor(9.1966, grad_fn=<NegBackward0>)
# Epoch 5/150 - Loss: 9.197   lengthscale: 0.146   noise: 0.015
# tensor(8.1627, grad_fn=<NegBackward0>)
# Epoch 6/150 - Loss: 8.163   lengthscale: 0.159   noise: 0.016
# tensor(7.2574, grad_fn=<NegBackward0>)
# Epoch 7/150 - Loss: 7.257   lengthscale: 0.174   noise: 0.018
# tensor(6.4589, grad_fn=<NegBackward0>)
# Epoch 8/150 - Loss: 6.459   lengthscale: 0.190   noise: 0.020
# tensor(5.7651, grad_fn=<NegBackward0>)
# Epoch 9/150 - Loss: 5.765   lengthscale: 0.206   noise: 0.022
# tensor(5.1704, grad_fn=<NegBackward0>)
# Epoch 10/150 - Loss: 5.170   lengthscale: 0.223   noise: 0.024
# tensor(4.6608, grad_fn=<NegBackward0>)
# Epoch 11/150 - Loss: 4.661   lengthscale: 0.241   noise: 0.026
# tensor(4.2243, grad_fn=<NegBackward0>)
# Epoch 12/150 - Loss: 4.224   lengthscale: 0.259   noise: 0.028
# tensor(3.8550, grad_fn=<NegBackward0>)
# ...
# tensor(0.7622, grad_fn=<NegBackward0>)
# Epoch 148/150 - Loss: 0.762   lengthscale: 0.274   noise: 0.172
# tensor(0.7612, grad_fn=<NegBackward0>)
# Epoch 149/150 - Loss: 0.761   lengthscale: 0.274   noise: 0.172
# tensor(0.7602, grad_fn=<NegBackward0>)
# Epoch 150/150 - Loss: 0.760   lengthscale: 0.274   noise: 0.172
# Step: 9, Val-Loss: 0.5116
# [ 9.160943 10.243527  9.458333 ...  9.408574 10.838374 10.07746 ]
# Step: 9 of 10, time-taken: 12.57 seconds
# K_D, P_D (100, 2) (1900, 2)
# torch.Size([90, 1])
# torch.float32
# tensor(9.8284, grad_fn=<NegBackward0>)
# Epoch 1/150 - Loss: 9.828   lengthscale: 0.100   noise: 0.010
# tensor(8.7298, grad_fn=<NegBackward0>)
# Epoch 2/150 - Loss: 8.730   lengthscale: 0.110   noise: 0.011
# tensor(7.7147, grad_fn=<NegBackward0>)
# Epoch 3/150 - Loss: 7.715   lengthscale: 0.121   noise: 0.012
# tensor(6.8016, grad_fn=<NegBackward0>)
# Epoch 4/150 - Loss: 6.802   lengthscale: 0.133   noise: 0.013
# tensor(6.0074, grad_fn=<NegBackward0>)
# Epoch 5/150 - Loss: 6.007   lengthscale: 0.146   noise: 0.015
# tensor(5.3300, grad_fn=<NegBackward0>)
# Epoch 6/150 - Loss: 5.330   lengthscale: 0.160   noise: 0.016
# tensor(4.7497, grad_fn=<NegBackward0>)
# Epoch 7/150 - Loss: 4.750   lengthscale: 0.175   noise: 0.018
# tensor(4.2442, grad_fn=<NegBackward0>)
# Epoch 8/150 - Loss: 4.244   lengthscale: 0.190   noise: 0.020
# tensor(3.8030, grad_fn=<NegBackward0>)
# Epoch 9/150 - Loss: 3.803   lengthscale: 0.207   noise: 0.022
# tensor(3.4220, grad_fn=<NegBackward0>)
# Epoch 10/150 - Loss: 3.422   lengthscale: 0.224   noise: 0.024
# tensor(3.0948, grad_fn=<NegBackward0>)
# Epoch 11/150 - Loss: 3.095   lengthscale: 0.242   noise: 0.026
# tensor(2.8160, grad_fn=<NegBackward0>)
# Epoch 12/150 - Loss: 2.816   lengthscale: 0.260   noise: 0.028
# tensor(2.5837, grad_fn=<NegBackward0>)
# Epoch 13/150 - Loss: 2.584   lengthscale: 0.278   noise: 0.030
# tensor(2.3960, grad_fn=<NegBackward0>)
# Epoch 14/150 - Loss: 2.396   lengthscale: 0.295   noise: 0.033
# tensor(2.2459, grad_fn=<NegBackward0>)
# Epoch 15/150 - Loss: 2.246   lengthscale: 0.311   noise: 0.035
# tensor(2.1226, grad_fn=<NegBackward0>)
# Epoch 16/150 - Loss: 2.123   lengthscale: 0.325   noise: 0.038
# tensor(2.0154, grad_fn=<NegBackward0>)
# Epoch 17/150 - Loss: 2.015   lengthscale: 0.336   noise: 0.041
# tensor(1.9168, grad_fn=<NegBackward0>)
# Epoch 18/150 - Loss: 1.917   lengthscale: 0.344   noise: 0.044
# tensor(1.8230, grad_fn=<NegBackward0>)
# Epoch 19/150 - Loss: 1.823   lengthscale: 0.349   noise: 0.047
# tensor(1.7330, grad_fn=<NegBackward0>)
# Epoch 20/150 - Loss: 1.733   lengthscale: 0.351   noise: 0.050
# tensor(1.6471, grad_fn=<NegBackward0>)
# Epoch 21/150 - Loss: 1.647   lengthscale: 0.350   noise: 0.053
# tensor(1.5660, grad_fn=<NegBackward0>)
# Epoch 22/150 - Loss: 1.566   lengthscale: 0.347   noise: 0.057
# tensor(1.4906, grad_fn=<NegBackward0>)
# Epoch 23/150 - Loss: 1.491   lengthscale: 0.342   noise: 0.060
# tensor(1.4217, grad_fn=<NegBackward0>)
# Epoch 24/150 - Loss: 1.422   lengthscale: 0.336   noise: 0.063
# tensor(1.3595, grad_fn=<NegBackward0>)
# Epoch 25/150 - Loss: 1.360   lengthscale: 0.329   noise: 0.067
# tensor(1.3044, grad_fn=<NegBackward0>)
# Epoch 26/150 - Loss: 1.304   lengthscale: 0.322   noise: 0.070
# tensor(1.2562, grad_fn=<NegBackward0>)
# Epoch 27/150 - Loss: 1.256   lengthscale: 0.314   noise: 0.073
# tensor(1.2145, grad_fn=<NegBackward0>)
# Epoch 28/150 - Loss: 1.214   lengthscale: 0.307   noise: 0.076
# tensor(1.1786, grad_fn=<NegBackward0>)
# Epoch 29/150 - Loss: 1.179   lengthscale: 0.299   noise: 0.080
# tensor(1.1479, grad_fn=<NegBackward0>)
# Epoch 30/150 - Loss: 1.148   lengthscale: 0.293   noise: 0.083
# tensor(1.1215, grad_fn=<NegBackward0>)
# Epoch 31/150 - Loss: 1.121   lengthscale: 0.286   noise: 0.086
# tensor(1.0987, grad_fn=<NegBackward0>)
# Epoch 32/150 - Loss: 1.099   lengthscale: 0.281   noise: 0.089
# tensor(1.0787, grad_fn=<NegBackward0>)
# Epoch 33/150 - Loss: 1.079   lengthscale: 0.276   noise: 0.092
# tensor(1.0611, grad_fn=<NegBackward0>)
# Epoch 34/150 - Loss: 1.061   lengthscale: 0.271   noise: 0.095
# tensor(1.0453, grad_fn=<NegBackward0>)
# Epoch 35/150 - Loss: 1.045   lengthscale: 0.268   noise: 0.098
# tensor(1.0309, grad_fn=<NegBackward0>)
# Epoch 36/150 - Loss: 1.031   lengthscale: 0.265   noise: 0.101
# tensor(1.0176, grad_fn=<NegBackward0>)
# Epoch 37/150 - Loss: 1.018   lengthscale: 0.263   noise: 0.104
# tensor(1.0053, grad_fn=<NegBackward0>)
# Epoch 38/150 - Loss: 1.005   lengthscale: 0.261   noise: 0.106
# tensor(0.9936, grad_fn=<NegBackward0>)
# Epoch 39/150 - Loss: 0.994   lengthscale: 0.260   noise: 0.109
# tensor(0.9827, grad_fn=<NegBackward0>)
# Epoch 40/150 - Loss: 0.983   lengthscale: 0.259   noise: 0.111
# tensor(0.9722, grad_fn=<NegBackward0>)
# Epoch 41/150 - Loss: 0.972   lengthscale: 0.259   noise: 0.114
# tensor(0.9623, grad_fn=<NegBackward0>)
# Epoch 42/150 - Loss: 0.962   lengthscale: 0.259   noise: 0.116
# tensor(0.9528, grad_fn=<NegBackward0>)
# Epoch 43/150 - Loss: 0.953   lengthscale: 0.260   noise: 0.118
# tensor(0.9438, grad_fn=<NegBackward0>)
# Epoch 44/150 - Loss: 0.944   lengthscale: 0.261   noise: 0.120
# tensor(0.9352, grad_fn=<NegBackward0>)
# Epoch 45/150 - Loss: 0.935   lengthscale: 0.262   noise: 0.122
# tensor(0.9271, grad_fn=<NegBackward0>)
# Epoch 46/150 - Loss: 0.927   lengthscale: 0.264   noise: 0.124
# tensor(0.9194, grad_fn=<NegBackward0>)
# Epoch 47/150 - Loss: 0.919   lengthscale: 0.265   noise: 0.126
# tensor(0.9121, grad_fn=<NegBackward0>)
# Epoch 48/150 - Loss: 0.912   lengthscale: 0.267   noise: 0.128
# tensor(0.9052, grad_fn=<NegBackward0>)
# Epoch 49/150 - Loss: 0.905   lengthscale: 0.269   noise: 0.130
# tensor(0.8988, grad_fn=<NegBackward0>)
# Epoch 50/150 - Loss: 0.899   lengthscale: 0.271   noise: 0.131
# tensor(0.8928, grad_fn=<NegBackward0>)
# Epoch 51/150 - Loss: 0.893   lengthscale: 0.273   noise: 0.133
# tensor(0.8871, grad_fn=<NegBackward0>)
# Epoch 52/150 - Loss: 0.887   lengthscale: 0.276   noise: 0.134
# tensor(0.8818, grad_fn=<NegBackward0>)
# Epoch 53/150 - Loss: 0.882   lengthscale: 0.278   noise: 0.135
# tensor(0.8769, grad_fn=<NegBackward0>)
# Epoch 54/150 - Loss: 0.877   lengthscale: 0.280   noise: 0.137
# tensor(0.8722, grad_fn=<NegBackward0>)
# Epoch 55/150 - Loss: 0.872   lengthscale: 0.281   noise: 0.138
# tensor(0.8678, grad_fn=<NegBackward0>)
# Epoch 56/150 - Loss: 0.868   lengthscale: 0.283   noise: 0.139
# tensor(0.8636, grad_fn=<NegBackward0>)
# Epoch 57/150 - Loss: 0.864   lengthscale: 0.285   noise: 0.140
# tensor(0.8597, grad_fn=<NegBackward0>)
# Epoch 58/150 - Loss: 0.860   lengthscale: 0.286   noise: 0.141
# tensor(0.8559, grad_fn=<NegBackward0>)
# Epoch 59/150 - Loss: 0.856   lengthscale: 0.287   noise: 0.142
# tensor(0.8522, grad_fn=<NegBackward0>)
# Epoch 60/150 - Loss: 0.852   lengthscale: 0.288   noise: 0.143
# tensor(0.8487, grad_fn=<NegBackward0>)
# Epoch 61/150 - Loss: 0.849   lengthscale: 0.289   noise: 0.144
# tensor(0.8452, grad_fn=<NegBackward0>)
# Epoch 62/150 - Loss: 0.845   lengthscale: 0.289   noise: 0.145
# tensor(0.8419, grad_fn=<NegBackward0>)
# Epoch 63/150 - Loss: 0.842   lengthscale: 0.290   noise: 0.146
# tensor(0.8386, grad_fn=<NegBackward0>)
# Epoch 64/150 - Loss: 0.839   lengthscale: 0.290   noise: 0.146
# tensor(0.8354, grad_fn=<NegBackward0>)
# Epoch 65/150 - Loss: 0.835   lengthscale: 0.290   noise: 0.147
# tensor(0.8322, grad_fn=<NegBackward0>)
# Epoch 66/150 - Loss: 0.832   lengthscale: 0.289   noise: 0.148
# tensor(0.8291, grad_fn=<NegBackward0>)
# Epoch 67/150 - Loss: 0.829   lengthscale: 0.289   noise: 0.148
# tensor(0.8261, grad_fn=<NegBackward0>)
# Epoch 68/150 - Loss: 0.826   lengthscale: 0.288   noise: 0.149
# tensor(0.8231, grad_fn=<NegBackward0>)
# Epoch 69/150 - Loss: 0.823   lengthscale: 0.288   noise: 0.149
# tensor(0.8202, grad_fn=<NegBackward0>)
# Epoch 70/150 - Loss: 0.820   lengthscale: 0.287   noise: 0.150
# tensor(0.8173, grad_fn=<NegBackward0>)
# Epoch 71/150 - Loss: 0.817   lengthscale: 0.286   noise: 0.150
# tensor(0.8145, grad_fn=<NegBackward0>)
# Epoch 72/150 - Loss: 0.815   lengthscale: 0.285   noise: 0.151
# tensor(0.8118, grad_fn=<NegBackward0>)
# Epoch 73/150 - Loss: 0.812   lengthscale: 0.284   noise: 0.151
# tensor(0.8091, grad_fn=<NegBackward0>)
# Epoch 74/150 - Loss: 0.809   lengthscale: 0.284   noise: 0.152
# tensor(0.8065, grad_fn=<NegBackward0>)
# Epoch 75/150 - Loss: 0.807   lengthscale: 0.283   noise: 0.152
# tensor(0.8040, grad_fn=<NegBackward0>)
# Epoch 76/150 - Loss: 0.804   lengthscale: 0.282   noise: 0.153
# tensor(0.8015, grad_fn=<NegBackward0>)
# Epoch 77/150 - Loss: 0.802   lengthscale: 0.281   noise: 0.153
# tensor(0.7991, grad_fn=<NegBackward0>)
# Epoch 78/150 - Loss: 0.799   lengthscale: 0.280   noise: 0.153
# tensor(0.7968, grad_fn=<NegBackward0>)
# Epoch 79/150 - Loss: 0.797   lengthscale: 0.279   noise: 0.153
# tensor(0.7944, grad_fn=<NegBackward0>)
# Epoch 80/150 - Loss: 0.794   lengthscale: 0.278   noise: 0.154
# tensor(0.7922, grad_fn=<NegBackward0>)
# Epoch 81/150 - Loss: 0.792   lengthscale: 0.278   noise: 0.154
# tensor(0.7899, grad_fn=<NegBackward0>)
# Epoch 82/150 - Loss: 0.790   lengthscale: 0.277   noise: 0.154
# tensor(0.7877, grad_fn=<NegBackward0>)
# Epoch 83/150 - Loss: 0.788   lengthscale: 0.277   noise: 0.154
# tensor(0.7856, grad_fn=<NegBackward0>)
# Epoch 84/150 - Loss: 0.786   lengthscale: 0.276   noise: 0.155
# tensor(0.7835, grad_fn=<NegBackward0>)
# Epoch 85/150 - Loss: 0.783   lengthscale: 0.276   noise: 0.155
# tensor(0.7814, grad_fn=<NegBackward0>)
# Epoch 86/150 - Loss: 0.781   lengthscale: 0.275   noise: 0.155
# tensor(0.7794, grad_fn=<NegBackward0>)
# Epoch 87/150 - Loss: 0.779   lengthscale: 0.275   noise: 0.155
# tensor(0.7773, grad_fn=<NegBackward0>)
# Epoch 88/150 - Loss: 0.777   lengthscale: 0.275   noise: 0.155
# tensor(0.7753, grad_fn=<NegBackward0>)
# Epoch 89/150 - Loss: 0.775   lengthscale: 0.275   noise: 0.155
# tensor(0.7734, grad_fn=<NegBackward0>)
# Epoch 90/150 - Loss: 0.773   lengthscale: 0.275   noise: 0.156
# tensor(0.7715, grad_fn=<NegBackward0>)
# Epoch 91/150 - Loss: 0.771   lengthscale: 0.275   noise: 0.156
# tensor(0.7696, grad_fn=<NegBackward0>)
# Epoch 92/150 - Loss: 0.770   lengthscale: 0.274   noise: 0.156
# tensor(0.7677, grad_fn=<NegBackward0>)
# Epoch 93/150 - Loss: 0.768   lengthscale: 0.274   noise: 0.156
# tensor(0.7658, grad_fn=<NegBackward0>)
# Epoch 94/150 - Loss: 0.766   lengthscale: 0.274   noise: 0.156
# tensor(0.7640, grad_fn=<NegBackward0>)
# Epoch 95/150 - Loss: 0.764   lengthscale: 0.274   noise: 0.156
# tensor(0.7622, grad_fn=<NegBackward0>)
# Epoch 96/150 - Loss: 0.762   lengthscale: 0.275   noise: 0.156
# tensor(0.7605, grad_fn=<NegBackward0>)
# Epoch 97/150 - Loss: 0.760   lengthscale: 0.275   noise: 0.156
# tensor(0.7587, grad_fn=<NegBackward0>)
# Epoch 98/150 - Loss: 0.759   lengthscale: 0.275   noise: 0.156
# tensor(0.7570, grad_fn=<NegBackward0>)
# Epoch 99/150 - Loss: 0.757   lengthscale: 0.275   noise: 0.156
# tensor(0.7553, grad_fn=<NegBackward0>)
# Epoch 100/150 - Loss: 0.755   lengthscale: 0.275   noise: 0.156
# tensor(0.7537, grad_fn=<NegBackward0>)
# Epoch 101/150 - Loss: 0.754   lengthscale: 0.275   noise: 0.156
# tensor(0.7520, grad_fn=<NegBackward0>)
# Epoch 102/150 - Loss: 0.752   lengthscale: 0.275   noise: 0.156
# tensor(0.7504, grad_fn=<NegBackward0>)
# Epoch 103/150 - Loss: 0.750   lengthscale: 0.275   noise: 0.156
# tensor(0.7488, grad_fn=<NegBackward0>)
# Epoch 104/150 - Loss: 0.749   lengthscale: 0.275   noise: 0.157
# tensor(0.7473, grad_fn=<NegBackward0>)
# Epoch 105/150 - Loss: 0.747   lengthscale: 0.275   noise: 0.157
# tensor(0.7457, grad_fn=<NegBackward0>)
# Epoch 106/150 - Loss: 0.746   lengthscale: 0.275   noise: 0.157
# tensor(0.7442, grad_fn=<NegBackward0>)
# Epoch 107/150 - Loss: 0.744   lengthscale: 0.275   noise: 0.157
# tensor(0.7427, grad_fn=<NegBackward0>)
# Epoch 108/150 - Loss: 0.743   lengthscale: 0.275   noise: 0.157
# tensor(0.7412, grad_fn=<NegBackward0>)
# Epoch 109/150 - Loss: 0.741   lengthscale: 0.275   noise: 0.157
# tensor(0.7397, grad_fn=<NegBackward0>)
# Epoch 110/150 - Loss: 0.740   lengthscale: 0.275   noise: 0.157
# tensor(0.7383, grad_fn=<NegBackward0>)
# Epoch 111/150 - Loss: 0.738   lengthscale: 0.274   noise: 0.157
# tensor(0.7369, grad_fn=<NegBackward0>)
# Epoch 112/150 - Loss: 0.737   lengthscale: 0.274   noise: 0.157
# tensor(0.7355, grad_fn=<NegBackward0>)
# Epoch 113/150 - Loss: 0.735   lengthscale: 0.274   noise: 0.157
# tensor(0.7341, grad_fn=<NegBackward0>)
# Epoch 114/150 - Loss: 0.734   lengthscale: 0.274   noise: 0.157
# tensor(0.7327, grad_fn=<NegBackward0>)
# Epoch 115/150 - Loss: 0.733   lengthscale: 0.274   noise: 0.157
# tensor(0.7314, grad_fn=<NegBackward0>)
# Epoch 116/150 - Loss: 0.731   lengthscale: 0.274   noise: 0.157
# tensor(0.7300, grad_fn=<NegBackward0>)
# Epoch 117/150 - Loss: 0.730   lengthscale: 0.273   noise: 0.157
# tensor(0.7287, grad_fn=<NegBackward0>)
# Epoch 118/150 - Loss: 0.729   lengthscale: 0.273   noise: 0.157
# tensor(0.7274, grad_fn=<NegBackward0>)
# Epoch 119/150 - Loss: 0.727   lengthscale: 0.273   noise: 0.157
# tensor(0.7262, grad_fn=<NegBackward0>)
# Epoch 120/150 - Loss: 0.726   lengthscale: 0.273   noise: 0.157
# tensor(0.7249, grad_fn=<NegBackward0>)
# Epoch 121/150 - Loss: 0.725   lengthscale: 0.273   noise: 0.157
# tensor(0.7236, grad_fn=<NegBackward0>)
# Epoch 122/150 - Loss: 0.724   lengthscale: 0.272   noise: 0.157
# tensor(0.7224, grad_fn=<NegBackward0>)
# Epoch 123/150 - Loss: 0.722   lengthscale: 0.272   noise: 0.157
# tensor(0.7212, grad_fn=<NegBackward0>)
# Epoch 124/150 - Loss: 0.721   lengthscale: 0.272   noise: 0.157
# tensor(0.7200, grad_fn=<NegBackward0>)
# Epoch 125/150 - Loss: 0.720   lengthscale: 0.272   noise: 0.157
# tensor(0.7188, grad_fn=<NegBackward0>)
# Epoch 126/150 - Loss: 0.719   lengthscale: 0.272   noise: 0.156
# tensor(0.7177, grad_fn=<NegBackward0>)
# Epoch 127/150 - Loss: 0.718   lengthscale: 0.271   noise: 0.156
# tensor(0.7165, grad_fn=<NegBackward0>)
# Epoch 128/150 - Loss: 0.717   lengthscale: 0.271   noise: 0.156
# tensor(0.7154, grad_fn=<NegBackward0>)
# Epoch 129/150 - Loss: 0.715   lengthscale: 0.271   noise: 0.156
# tensor(0.7143, grad_fn=<NegBackward0>)
# Epoch 130/150 - Loss: 0.714   lengthscale: 0.271   noise: 0.156
# tensor(0.7132, grad_fn=<NegBackward0>)
# Epoch 131/150 - Loss: 0.713   lengthscale: 0.271   noise: 0.156
# tensor(0.7121, grad_fn=<NegBackward0>)
# Epoch 132/150 - Loss: 0.712   lengthscale: 0.271   noise: 0.156
# tensor(0.7110, grad_fn=<NegBackward0>)
# Epoch 133/150 - Loss: 0.711   lengthscale: 0.270   noise: 0.156
# tensor(0.7099, grad_fn=<NegBackward0>)
# Epoch 134/150 - Loss: 0.710   lengthscale: 0.270   noise: 0.156
# tensor(0.7089, grad_fn=<NegBackward0>)
# Epoch 135/150 - Loss: 0.709   lengthscale: 0.270   noise: 0.156
# tensor(0.7078, grad_fn=<NegBackward0>)
# Epoch 136/150 - Loss: 0.708   lengthscale: 0.270   noise: 0.156
# tensor(0.7068, grad_fn=<NegBackward0>)
# Epoch 137/150 - Loss: 0.707   lengthscale: 0.270   noise: 0.156
# tensor(0.7058, grad_fn=<NegBackward0>)
# Epoch 138/150 - Loss: 0.706   lengthscale: 0.270   noise: 0.156
# tensor(0.7048, grad_fn=<NegBackward0>)
# Epoch 139/150 - Loss: 0.705   lengthscale: 0.270   noise: 0.156
# tensor(0.7038, grad_fn=<NegBackward0>)
# Epoch 140/150 - Loss: 0.704   lengthscale: 0.270   noise: 0.156
# tensor(0.7028, grad_fn=<NegBackward0>)
# Epoch 141/150 - Loss: 0.703   lengthscale: 0.269   noise: 0.156
# tensor(0.7019, grad_fn=<NegBackward0>)
# Epoch 142/150 - Loss: 0.702   lengthscale: 0.269   noise: 0.156
# tensor(0.7009, grad_fn=<NegBackward0>)
# Epoch 143/150 - Loss: 0.701   lengthscale: 0.269   noise: 0.156
# tensor(0.7000, grad_fn=<NegBackward0>)
# Epoch 144/150 - Loss: 0.700   lengthscale: 0.269   noise: 0.156
# tensor(0.6991, grad_fn=<NegBackward0>)
# Epoch 145/150 - Loss: 0.699   lengthscale: 0.269   noise: 0.156
# tensor(0.6981, grad_fn=<NegBackward0>)
# Epoch 146/150 - Loss: 0.698   lengthscale: 0.269   noise: 0.156
# tensor(0.6972, grad_fn=<NegBackward0>)
# Epoch 147/150 - Loss: 0.697   lengthscale: 0.269   noise: 0.156
# tensor(0.6964, grad_fn=<NegBackward0>)
# Epoch 148/150 - Loss: 0.696   lengthscale: 0.269   noise: 0.156
# tensor(0.6955, grad_fn=<NegBackward0>)
# Epoch 149/150 - Loss: 0.695   lengthscale: 0.269   noise: 0.156
# tensor(0.6946, grad_fn=<NegBackward0>)
# Epoch 150/150 - Loss: 0.695   lengthscale: 0.269   noise: 0.156
# Step: 10, Val-Loss: 0.5124
# [ 9.14579  10.423227  9.357304 ...  9.313662 10.838572 10.077227]
# Step: 10 of 10, time-taken: 12.44 seconds

# %%
def update_data(known_data, pool_data, selected_indices): # 5. Update the known and pool data
        known_data = np.append(known_data, pool_data[selected_indices], axis=0)
        pool_data = np.delete(pool_data, selected_indices, axis=0)
        return known_data, pool_data

# %%
preds[0].mean.numpy()
# Out:
# array(-0.926515, dtype=float32)

# %%
len(preds.stddev)
# Out:
# 1900

# %%
plt.figure(figsize=(20, 6))  # Set the figure size to be wider
plt.plot(preds.stddev.numpy())
plt.xlabel('Data Point')
plt.ylabel('Standard Deviation')
plt.title('Standard Deviation Plot')
plt.show()

# %%
count = len(preds.stddev[preds.stddev > 0.4])
print(count)
count = len(preds.stddev[preds.stddev > 0.39])
print(count)
count = len(preds.stddev[preds.stddev > 0.38])
print(count)
count = len(preds.stddev[preds.stddev > 0.37])
print(count)
# Out:
# 4
# 25
# 53
# 108
