# %% [markdown]
# Torch Implementation of GP
#
# Inspired by: https://docs.gpytorch.ai/en/stable/examples/01_Exact_GPs/Simple_GP_Regression.html

# %%
import math
import torch
import gpytorch
from matplotlib import pyplot as plt
import time

from data import Dataprep, update_data, load_data
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns

import pandas as pd


# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dataset_type='Generated_2000'
sensor='foundation_origin xy FloaterOffset [m]'
samples_per_step=10
validation_size=0.1

# %%
data = Dataprep(dataset_type, sensor, initial_samplesize=samples_per_step)
known_data, pool_data = data.known_data, data.pool_data

# %% [markdown]
# Load Data and Normalize

# %%
# We will use the simplest form of GP model, exact inference
class ExactGPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super(ExactGPModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = gpytorch.means.ConstantMean()

        # Assuming you have an RBFKernel instance named `rbf_kernel`:
        rbf_kernel = gpytorch.kernels.RBFKernel()

        # To set an initial length scale:
        rbf_kernel.lengthscale = 0.1

        # kernel can be changed or combined !
        self.covar_module = gpytorch.kernels.ScaleKernel(rbf_kernel)

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

# initialize likelihood and model
#likelihood = gpytorch.likelihoods.GaussianLikelihood()
#model = ExactGPModel(train_x, train_y, likelihood)

# %%
from torch.optim import Adam

# %%
def init_optimizer(learning_rate,model):
    optimizer = Adam(model.parameters(), lr=learning_rate)
    return optimizer
    
def train_model(step, learning_rate):
    print('K_D, P_D', known_data.shape, pool_data.shape)

    # Split the pool data into train and validation sets
    train, val = train_test_split(known_data, test_size=validation_size)

    X_train = torch.tensor(scaler.fit_transform(train[:, 0].reshape(-1, 1))).to(device)  # Adds an extra dimension to make X_train a 2D tensor
    y_train = torch.tensor(train[:, 1]).to(device)
    
    # Initialize likelihood and model with training data
    likelihood = gpytorch.likelihoods.GaussianLikelihood().to(device)

    # Assuming you have a GaussianLikelihood instance named `likelihood`:
    likelihood = gpytorch.likelihoods.GaussianLikelihood()

    # To set an initial noise level:
    likelihood.noise = 0.01






    model = ExactGPModel(X_train, y_train, likelihood).to(device)
    
    optimizer = init_optimizer(learning_rate,model) # Initialize the optimizer

    model.train()
    likelihood.train()

    mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)
    total_train_loss = 0

    x, y = X_train, y_train

    # Find optimal model hyperparameters
    model.train()
    likelihood.train()

    # Use the adam optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr=0.1)  # Includes GaussianLikelihood parameters

    # "Loss" for GPs - the marginal log likelihood
    mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

    for epoch in range(epochs):
        # Zero gradients from previous iteration
        optimizer.zero_grad()
        # Output from model
        output = model(X_train)
        # Calc loss and backprop gradients
        loss = -mll(output, y_train)
        loss.backward()
        print('Epoch %d/%d - Loss: %.3f   lengthscale: %.3f   noise: %.3f' % (
            epoch +1, epochs, loss.item(),
            model.covar_module.base_kernel.lengthscale.item(),
            model.likelihood.noise.item()
        ))
        optimizer.step()

    preds = evaluate_model(likelihood, model,val, step, mll) # Evaluate the model on the validation set

    return preds

# %%
def evaluate_model(likelihood, model,val_loader, step, mll): # 1: EVALUATE THE MODEL ON THE VALIDATION SET

    X_val = torch.tensor(scaler.fit_transform(val[:, 0].reshape(-1, 1))).to(device)  # Adds an extra dimension to make X_train a 2D tensor
    y_val = torch.tensor(val[:, 1]).to(device)
    x, y = X_val, y_val
    # Get into evaluation (predictive posterior) mode
    model.eval()
    likelihood.eval()

    total_val_loss = 0
    # Make predictions by feeding model through likelihood
    with torch.no_grad(), gpytorch.settings.fast_pred_var():
        test_x = torch.linspace(0, 1, 51)
        observed_pred = likelihood(model(X_val))
        output = model(X_val)
        loss = -mll(output, y_val)
        total_val_loss += loss.item()

    step_val_loss = total_val_loss  # Average loss over batches
    writer.add_scalar('loss/val', step_val_loss, step+1)
    if verbose:
        print('Step: {}, Val-Loss: {:.4f}'.format(step+1, step_val_loss))

    if known_data.shape[1] == 2:
        preds = plot(likelihood, model, step)
    return preds

# %%
def plot(likelihood, model, step, samples=500):
    x_pool = pool_data[:, :-1]
    y_pool = pool_data[:, -1]

    x_selected = known_data[:, :-1]
    y_selected = known_data[:, -1]

    scaler = MinMaxScaler()
    x_pool_scaled = scaler.fit_transform(x_pool)
    x_selected_scaled = scaler.transform(x_selected)
    
    x_pool_torch = torch.tensor(x_pool_scaled) 

    model.eval()
    likelihood.eval()

    # Make predictions by feeding model through likelihood
    with torch.no_grad(), gpytorch.settings.fast_pred_var():
        preds = likelihood(model(x_pool_torch))

    means = preds.mean.numpy()  # calculate the mean of the predictions
    lower, upper = preds.confidence_region()
    stds = preds.stddev.numpy()
    
    # Prepare data for plotting
    #df = pd.DataFrame({'x': x_pool_torch.squeeze(), 'mean': means.squeeze(), 'lower': lower, 'upper': upper})

    dfs = []
    y_vals = [means, means + 2 * stds, means - 2 * stds]

    for i in range(3): #len(y_vals)
        dfs.append(pd.DataFrame({'x': x_pool_torch.squeeze(), 'y': y_vals[i].squeeze()}))
    df = pd.concat(dfs)

    print(means.squeeze())
    
    # Plotting
    fig = plt.figure()
    sns.lineplot(data=df, x="x", y="y")
    plt.scatter(x_pool_scaled, y_pool, c="green", marker="*", alpha=0.1)  # Plot actual y values
    plt.scatter(x_selected_scaled, y_selected, c="red", marker="*", alpha=0.2) # plot train data on top
    plt.title(f'Predictions vs Actual Step {step+1}')
    plt.legend(['Mean prediction', 'Pool data (unseen)', 'Seen data'], fontsize='small')
    plt.close(fig)

    # Log the table figure
    writer.add_figure(f'Prediction vs Actual Table Epoch {step+1}', fig, step+1)

    # Log the table figure
    writer.add_figure(f'Prediction vs Actual Table Epoch {step+1}', fig, step+1)

    return preds

# %%
import random

# %%
def predict(self, x): # 2: PREDICT THE UNCERTAINTY ON THE POOL DATA
        pass

def acquisition_function(n, pool_data=pool_data, known_data=known_data): # 3: DECIDE WHICH SAMPLES TO SELECT FROM THE POOL DATA (USING ACQUISITION FUNCTION)
    selected_indices = random.sample(range(len(pool_data)), n)
    known_data, pool_data = update_data(known_data, pool_data, selected_indices)

    return known_data, pool_data

# %%
data = Dataprep(dataset_type, sensor, initial_samplesize=samples_per_step)
known_data, pool_data = data.known_data, data.pool_data

# %%
from torch.utils.tensorboard import SummaryWriter
import datetime
import os

# %%
steps = 10
learning_rate = 0.01
epochs = 150
verbose=True
current_time = datetime.datetime.now().strftime("%Y%m%d-%H%M%S") # Unique directory based on datetime for each run
log_dir = os.path.join('Models/runs', 'BNN_' + dataset_type  + '_' + current_time)
writer = SummaryWriter(log_dir) 

device = torch.device("cpu" if torch.backends.mps.is_available() else "cpu")

# %%
known_data, pool_data = data.known_data, data.pool_data

# %%
# Train the model
for step in range(steps):
    start_step = time.time()
    preds = train_model(step,learning_rate) # Train the model
    print('Step: {} of {}, time-taken: {:.2f} seconds'.format(step+1, steps, time.time() - start_step))
    known_data, pool_data = acquisition_function(samples_per_step, pool_data, known_data) # Select the next samples from the pool
# Out:
# K_D, P_D (10, 2) (1990, 2)
# Epoch 1/150 - Loss: 0.955   lengthscale: 0.100   noise: 0.010
# Epoch 2/150 - Loss: 0.927   lengthscale: 0.091   noise: 0.011
# Epoch 3/150 - Loss: 0.931   lengthscale: 0.085   noise: 0.012
# Epoch 4/150 - Loss: 0.935   lengthscale: 0.083   noise: 0.013
# Epoch 5/150 - Loss: 0.932   lengthscale: 0.082   noise: 0.014
# Epoch 6/150 - Loss: 0.926   lengthscale: 0.084   noise: 0.015
# Epoch 7/150 - Loss: 0.920   lengthscale: 0.086   noise: 0.016
# Epoch 8/150 - Loss: 0.917   lengthscale: 0.088   noise: 0.018
# Epoch 9/150 - Loss: 0.917   lengthscale: 0.091   noise: 0.019
# Epoch 10/150 - Loss: 0.919   lengthscale: 0.093   noise: 0.020
# Epoch 11/150 - Loss: 0.919   lengthscale: 0.094   noise: 0.022
# Epoch 12/150 - Loss: 0.917   lengthscale: 0.095   noise: 0.024
# Epoch 13/150 - Loss: 0.914   lengthscale: 0.095   noise: 0.026
# Epoch 14/150 - Loss: 0.912   lengthscale: 0.095   noise: 0.029
# Epoch 15/150 - Loss: 0.911   lengthscale: 0.095   noise: 0.031
# Epoch 16/150 - Loss: 0.912   lengthscale: 0.095   noise: 0.034
# Epoch 17/150 - Loss: 0.912   lengthscale: 0.095   noise: 0.036
# Epoch 18/150 - Loss: 0.912   lengthscale: 0.096   noise: 0.039
# Epoch 19/150 - Loss: 0.912   lengthscale: 0.097   noise: 0.041
# Epoch 20/150 - Loss: 0.910   lengthscale: 0.099   noise: 0.042
# Epoch 21/150 - Loss: 0.909   lengthscale: 0.101   noise: 0.044
# Epoch 22/150 - Loss: 0.907   lengthscale: 0.104   noise: 0.045
# Epoch 23/150 - Loss: 0.905   lengthscale: 0.107   noise: 0.046
# Epoch 24/150 - Loss: 0.903   lengthscale: 0.110   noise: 0.048
# Epoch 25/150 - Loss: 0.900   lengthscale: 0.114   noise: 0.050
# Epoch 26/150 - Loss: 0.897   lengthscale: 0.118   noise: 0.052
150 - Loss: 0.883   lengthscale: 0.147   noise: 0.067
# Epoch 150/150 - Loss: 0.883   lengthscale: 0.147   noise: 0.067
# Step: 1, Val-Loss: 1.3028
# [ 0.30021274  0.6437533  -1.0655195  ... -0.837434   -0.5762032
#   0.6628903 ]
# Step: 1 of 10, time-taken: 13.27 seconds
# K_D, P_D (20, 2) (1980, 2)
# Epoch 1/150 - Loss: 2.698   lengthscale: 0.100   noise: 0.010
# Epoch 2/150 - Loss: 2.405   lengthscale: 0.091   noise: 0.011
# Epoch 3/150 - Loss: 2.193   lengthscale: 0.083   noise: 0.012
# Epoch 4/150 - Loss: 2.021   lengthscale: 0.078   noise: 0.013
# Epoch 5/150 - Loss: 1.871   lengthscale: 0.074   noise: 0.015
# Epoch 6/150 - Loss: 1.737   lengthscale: 0.071   noise: 0.016
# Epoch 7/150 - Loss: 1.616   lengthscale: 0.069   noise: 0.018
# Epoch 8/150 - Loss: 1.508   lengthscale: 0.068   noise: 0.020
# Epoch 9/150 - Loss: 1.411   lengthscale: 0.067   noise: 0.021
# Epoch 10/150 - Loss: 1.324   lengthscale: 0.068   noise: 0.023
# Epoch 11/150 - Loss: 1.247   lengthscale: 0.068   noise: 0.025
# Epoch 12/150 - Loss: 1.180   lengthscale: 0.069   noise: 0.028
# Epoch 13/150 - Loss: 1.122   lengthscale: 0.070   noise: 0.030
# Epoch 14/150 - Loss: 1.073   lengthscale: 0.071   noise: 0.032
# Epoch 15/150 - Loss: 1.031   lengthscale: 0.073   noise: 0.035
# Epoch 16/150 - Loss: 0.996   lengthscale: 0.074   noise: 0.037
# Epoch 17/150 - Loss: 0.966   lengthscale: 0.076   noise: 0.040
# Epoch 18/150 - Loss: 0.941   lengthscale: 0.077   noise: 0.043
# Epoch 19/150 - Loss: 0.918   lengthscale: 0.078   noise: 0.046
# Epoch 20/150 - Loss: 0.899   lengthscale: 0.079   noise: 0.049
# Epoch 21/150 - Loss: 0.881   lengthscale: 0.079   noise: 0.051
# Epoch 22/150 - Loss: 0.865   lengthscale: 0.080   noise: 0.054
# Epoch 23/150 - Loss: 0.850   lengthscale: 0.080   noise: 0.057
# Epoch 24/150 - Loss: 0.838   lengthscale: 0.081   noise: 0.060
# Epoch 25/150 - Loss: 0.827   lengthscale: 0.081   noise: 0.063
# Epoch 26/150 - Loss: 0.817   lengthscale: 0.081   noise: 0.066
# Epoch 27/150 - Loss: 0.809   lengthscale: 0.081   noise: 0.069
# Epoch 28/150 - Loss: 0.803   lengthscale: 0.081   noise: 0.072
# Epoch 29/150 - Loss: 0.797   lengthscale: 0.081   noise: 0.075
# Epoch 30/150 - Loss: 0.793   lengthscale: 0.082   noise: 0.078
# Epoch 31/150 - Loss: 0.789   lengthscale: 0.082   noise: 0.081
# Epoch 32/150 - Loss: 0.786   lengthscale: 0.082   noise: 0.083
# Epoch 33/150 - Loss: 0.784   lengthscale: 0.083   noise: 0.086
# Epoch 34/150 - Loss: 0.782   lengthscale: 0.083   noise: 0.088
# Epoch 35/150 - Loss: 0.780   lengthscale: 0.084   noise: 0.091
# Epoch 36/150 - Loss: 0.779   lengthscale: 0.084   noise: 0.093
# Epoch 37/150 - Loss: 0.777   lengthscale: 0.085   noise: 0.095
# Epoch 38/150 - Loss: 0.776   lengthscale: 0.086   noise: 0.097
# Epoch 39/150 - Loss: 0.775   lengthscale: 0.087   noise: 0.099
# Epoch 40/150 - Loss: 0.774   lengthscale: 0.087   noise: 0.101
# Epoch 41/150 - Loss: 0.774   lengthscale: 0.088   noise: 0.103
# Epoch 42/150 - Loss: 0.773   lengthscale: 0.089   noise: 0.104
# Epoch 43/150 - Loss: 0.773   lengthscale: 0.090   noise: 0.106
# Epoch 44/150 - Loss: 0.772   lengthscale: 0.091   noise: 0.107
# Epoch 45/150 - Loss: 0.772   lengthscale: 0.091   noise: 0.108
# Epoch 46/150 - Loss: 0.772   lengthscale: 0.092   noise: 0.110
# Epoch 47/150 - Loss: 0.772   lengthscale: 0.092   noise: 0.111
# Epoch 48/150 - Loss: 0.772   lengthscale: 0.093   noise: 0.112
# Epoch 49/150 - Loss: 0.772   lengthscale: 0.093   noise: 0.113
# Epoch 50/150 - Loss: 0.772   lengthscale: 0.093   noise: 0.114
# Epoch 51/150 - Loss: 0.772   lengthscale: 0.093   noise: 0.115
# Epoch 52/150 - Loss: 0.772   lengthscale: 0.093   noise: 0.116
# Epoch 53/150 - Loss: 0.772   lengthscale: 0.093   noise: 0.116
# Epoch 54/150 - Loss: 0.772   lengthscale: 0.093   noise: 0.117
# Epoch 55/150 - Loss: 0.772   lengthscale: 0.093   noise: 0.117
# Epoch 56/150 - Loss: 0.772   lengthscale: 0.093   noise: 0.118
# Epoch 57/150 - Loss: 0.772   lengthscale: 0.092   noise: 0.118
# Epoch 58/150 - Loss: 0.772   lengthscale: 0.092   noise: 0.119
# Epoch 59/150 - Loss: 0.772   lengthscale: 0.092   noise: 0.119
# Epoch 60/150 - Loss: 0.772   lengthscale: 0.091   noise: 0.120
# Epoch 61/150 - Loss: 0.772   lengthscale: 0.091   noise: 0.120
# Epoch 62/150 - Loss: 0.772   lengthscale: 0.091   noise: 0.120
# Epoch 63/150 - Loss: 0.772   lengthscale: 0.091   noise: 0.120
# Epoch 64/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.120
# Epoch 65/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.120
# Epoch 66/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.121
# Epoch 67/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.121
# Epoch 68/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.121
# Epoch 69/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.121
# Epoch 70/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.121
# Epoch 71/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.120
# Epoch 72/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.120
# Epoch 73/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.120
# Epoch 74/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.120
# Epoch 75/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.120
# Epoch 76/150 - Loss: 0.772   lengthscale: 0.091   noise: 0.120
# Epoch 77/150 - Loss: 0.772   lengthscale: 0.091   noise: 0.120
# Epoch 78/150 - Loss: 0.772   lengthscale: 0.091   noise: 0.120
# Epoch 79/150 - Loss: 0.772   lengthscale: 0.091   noise: 0.119
# Epoch 80/150 - Loss: 0.772   lengthscale: 0.091   noise: 0.119
# Epoch 81/150 - Loss: 0.772   lengthscale: 0.091   noise: 0.119
# Epoch 82/150 - Loss: 0.772   lengthscale: 0.091   noise: 0.119
# Epoch 83/150 - Loss: 0.772   lengthscale: 0.091   noise: 0.119
# Epoch 84/150 - Loss: 0.772   lengthscale: 0.091   noise: 0.118
# Epoch 85/150 - Loss: 0.772   lengthscale: 0.091   noise: 0.118
# Epoch 86/150 - Loss: 0.772   lengthscale: 0.091   noise: 0.118
# Epoch 87/150 - Loss: 0.772   lengthscale: 0.091   noise: 0.118
# Epoch 88/150 - Loss: 0.772   lengthscale: 0.091   noise: 0.118
# Epoch 89/150 - Loss: 0.772   lengthscale: 0.091   noise: 0.118
# Epoch 90/150 - Loss: 0.772   lengthscale: 0.091   noise: 0.117
# Epoch 91/150 - Loss: 0.772   lengthscale: 0.091   noise: 0.117
# Epoch 92/150 - Loss: 0.772   lengthscale: 0.091   noise: 0.117
# Epoch 93/150 - Loss: 0.772   lengthscale: 0.091   noise: 0.117
# Epoch 94/150 - Loss: 0.772   lengthscale: 0.091   noise: 0.117
# Epoch 95/150 - Loss: 0.772   lengthscale: 0.091   noise: 0.117
# Epoch 96/150 - Loss: 0.772   lengthscale: 0.091   noise: 0.116
# Epoch 97/150 - Loss: 0.772   lengthscale: 0.091   noise: 0.116
# Epoch 98/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.116
# Epoch 99/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.116
# Epoch 100/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.116
# Epoch 101/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.116
# Epoch 102/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.116
# Epoch 103/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.115
# Epoch 104/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.115
# Epoch 105/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.115
# Epoch 106/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.115
# Epoch 107/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.115
# Epoch 108/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.115
# Epoch 109/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.115
# Epoch 110/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.115
# Epoch 111/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.115
# Epoch 112/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 113/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 114/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 115/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 116/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 117/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 118/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 119/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 120/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 121/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 122/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 123/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 124/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 125/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 126/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 127/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 128/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 129/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 130/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 131/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 132/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 133/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 134/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 135/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 136/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 137/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 138/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 139/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 140/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 141/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 142/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 143/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 144/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 145/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 146/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 147/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 148/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 149/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Epoch 150/150 - Loss: 0.772   lengthscale: 0.090   noise: 0.114
# Step: 2, Val-Loss: 0.8438
# [ 0.40372807  0.24879804 -0.83311796 ... -0.37603366 -0.09372801
#   0.46796077]
# Step: 2 of 10, time-taken: 13.34 seconds
# K_D, P_D (30, 2) (1970, 2)
# Epoch 1/150 - Loss: 2.955   lengthscale: 0.100   noise: 0.010
# Epoch 2/150 - Loss: 2.512   lengthscale: 0.091   noise: 0.011
# Epoch 3/150 - Loss: 2.176   lengthscale: 0.083   noise: 0.012
# Epoch 4/150 - Loss: 1.929   lengthscale: 0.076   noise: 0.013
# Epoch 5/150 - Loss: 1.748   lengthscale: 0.070   noise: 0.015
# Epoch 6/150 - Loss: 1.614   lengthscale: 0.065   noise: 0.016
# Epoch 7/150 - Loss: 1.509   lengthscale: 0.060   noise: 0.018
# Epoch 8/150 - Loss: 1.420   lengthscale: 0.057   noise: 0.019
# Epoch 9/150 - Loss: 1.343   lengthscale: 0.055   noise: 0.021
# Epoch 10/150 - Loss: 1.274   lengthscale: 0.053   noise: 0.023
# Epoch 11/150 - Loss: 1.211   lengthscale: 0.051   noise: 0.025
# Epoch 12/150 - Loss: 1.154   lengthscale: 0.050   noise: 0.027
# Epoch 13/150 - Loss: 1.103   lengthscale: 0.049   noise: 0.029
# Epoch 14/150 - Loss: 1.057   lengthscale: 0.048   noise: 0.031
# Epoch 15/150 - Loss: 1.015   lengthscale: 0.048   noise: 0.033
# Epoch 16/150 - Loss: 0.977   lengthscale: 0.048   noise: 0.036
# Epoch 17/150 - Loss: 0.944   lengthscale: 0.048   noise: 0.038
# Epoch 18/150 - Loss: 0.914   lengthscale: 0.048   noise: 0.041
# Epoch 19/150 - Loss: 0.887   lengthscale: 0.048   noise: 0.043
# Epoch 20/150 - Loss: 0.863   lengthscale: 0.048   noise: 0.046
# Epoch 21/150 - Loss: 0.842   lengthscale: 0.049   noise: 0.048
# Epoch 22/150 - Loss: 0.824   lengthscale: 0.049   noise: 0.051
# Epoch 23/150 - Loss: 0.809   lengthscale: 0.050   noise: 0.053
# Epoch 24/150 - Loss: 0.796   lengthscale: 0.051   noise: 0.056
# Epoch 25/150 - Loss: 0.786   lengthscale: 0.052   noise: 0.059
# Epoch 26/150 - Loss: 0.777   lengthscale: 0.053   noise: 0.061
# Epoch 27/150 - Loss: 0.769   lengthscale: 0.054   noise: 0.064
# Epoch 28/150 - Loss: 0.762   lengthscale: 0.055   noise: 0.066
# Epoch 29/150 - Loss: 0.757   lengthscale: 0.056   noise: 0.069
# Epoch 30/150 - Loss: 0.751   lengthscale: 0.057   noise: 0.071
# Epoch 31/150 - Loss: 0.746   lengthscale: 0.058   noise: 0.073
# Epoch 70/150 - Loss: 0.691   lengthscale: 0.100   noise: 0.112
# Epoch 71/150 - Loss: 0.691   lengthscale: 0.101   noise: 0.112
# Epoch 72/150 - Loss: 0.691   lengthscale: 0.102   noise: 0.112
# Epoch 73/150 - Loss: 0.691   lengthscale: 0.103   noise: 0.112
# Epoch 74/150 - Loss: 0.690   lengthscale: 0.104   noise: 0.112
# Epoch 75/150 - Loss: 0.690   lengthscale: 0.105   noise: 0.112
# Epoch 76/150 - Loss: 0.690   lengthscale: 0.106   noise: 0.113
# Epoch 77/150 - Loss: 0.690   lengthscale: 0.107   noise: 0.113
# Epoch 78/150 - Loss: 0.689   lengthscale: 0.108   noise: 0.113
# Epoch 79/150 - Loss: 0.689   lengthscale: 0.109   noise: 0.113
# Epoch 80/150 - Loss: 0.689   lengthscale: 0.110   noise: 0.113
# Epoch 81/150 - Loss: 0.689   lengthscale: 0.110   noise: 0.114
# Epoch 82/150 - Loss: 0.688   lengthscale: 0.111   noise: 0.114
# Epoch 83/150 - Loss: 0.688   lengthscale: 0.112   noise: 0.114
# Epoch 84/150 - Loss: 0.688   lengthscale: 0.113   noise: 0.114
# Epoch 85/150 - Loss: 0.688   lengthscale: 0.114   noise: 0.114
# Epoch 86/150 - Loss: 0.688   lengthscale: 0.115   noise: 0.114
# Epoch 87/150 - Loss: 0.687   lengthscale: 0.115   noise: 0.114
# Epoch 88/150 - Loss: 0.687   lengthscale: 0.116   noise: 0.115
# Epoch 89/150 - Loss: 0.687   lengthscale: 0.117   noise: 0.115
# Epoch 90/150 - Loss: 0.687   lengthscale: 0.118   noise: 0.115
# Epoch 91/150 - Loss: 0.687   lengthscale: 0.118   noise: 0.115
# Epoch 92/150 - Loss: 0.687   lengthscale: 0.119   noise: 0.115
# Epoch 93/150 - Loss: 0.687   lengthscale: 0.120   noise: 0.115
# Epoch 94/150 - Loss: 0.687   lengthscale: 0.120   noise: 0.115
# Epoch 95/150 - Loss: 0.687   lengthscale: 0.121   noise: 0.115
# Epoch 96/150 - Loss: 0.687   lengthscale: 0.121   noise: 0.116
# Epoch 97/150 - Loss: 0.687   lengthscale: 0.122   noise: 0.116
# Epoch 98/150 - Loss: 0.686   lengthscale: 0.122   noise: 0.116
# Epoch 99/150 - Loss: 0.686   lengthscale: 0.123   noise: 0.116
# Epoch 100/150 - Loss: 0.686   lengthscale: 0.123   noise: 0.116
# Epoch 101/150 - Loss: 0.686   lengthscale: 0.124   noise: 0.116
# Epoch 102/150 - Loss: 0.686   lengthscale: 0.124   noise: 0.116
# Epoch 103/150 - Loss: 0.686   lengthscale: 0.125   noise: 0.116
# Epoch 104/150 - Loss: 0.686   lengthscale: 0.125   noise: 0.116
# Epoch 105/150 - Loss: 0.686   lengthscale: 0.126   noise: 0.116
# Epoch 106/150 - Loss: 0.686   lengthscale: 0.126   noise: 0.117
# Epoch 107/150 - Loss: 0.686   lengthscale: 0.126   noise: 0.117
# Epoch 108/150 - Loss: 0.686   lengthscale: 0.127   noise: 0.117
# Epoch 109/150 - Loss: 0.686   lengthscale: 0.127   noise: 0.117
# Epoch 110/150 - Loss: 0.686   lengthscale: 0.127   noise: 0.117
# Epoch 111/150 - Loss: 0.686   lengthscale: 0.127   noise: 0.117
# Epoch 112/150 - Loss: 0.686   lengthscale: 0.128   noise: 0.117
# Epoch 113/150 - Loss: 0.686   lengthscale: 0.128   noise: 0.117
# Epoch 114/150 - Loss: 0.686   lengthscale: 0.128   noise: 0.117
# Epoch 115/150 - Loss: 0.686   lengthscale: 0.128   noise: 0.117
# Epoch 116/150 - Loss: 0.686   lengthscale: 0.128   noise: 0.117
# Epoch 117/150 - Loss: 0.686   lengthscale: 0.129   noise: 0.117
# Epoch 118/150 - Loss: 0.686   lengthscale: 0.129   noise: 0.117
# Epoch 119/150 - Loss: 0.686   lengthscale: 0.129   noise: 0.117
# Epoch 120/150 - Loss: 0.686   lengthscale: 0.129   noise: 0.117
# Epoch 121/150 - Loss: 0.686   lengthscale: 0.129   noise: 0.117
# Epoch 122/150 - Loss: 0.686   lengthscale: 0.129   noise: 0.117
# Epoch 123/150 - Loss: 0.686   lengthscale: 0.129   noise: 0.118
# Epoch 124/150 - Loss: 0.686   lengthscale: 0.129   noise: 0.118
# Epoch 125/150 - Loss: 0.686   lengthscale: 0.129   noise: 0.118
# Epoch 126/150 - Loss: 0.686   lengthscale: 0.129   noise: 0.118
# Epoch 127/150 - Loss: 0.686   lengthscale: 0.129   noise: 0.118
# Epoch 128/150 - Loss: 0.686   lengthscale: 0.129   noise: 0.118
# Epoch 129/150 - Loss: 0.686   lengthscale: 0.129   noise: 0.118
# Epoch 130/150 - Loss: 0.686   lengthscale: 0.129   noise: 0.118
# Epoch 131/150 - Loss: 0.686   lengthscale: 0.129   noise: 0.118
# Epoch 132/150 - Loss: 0.686   lengthscale: 0.129   noise: 0.118
# Epoch 133/150 - Loss: 0.686   lengthscale: 0.129   noise: 0.118
# Epoch 134/150 - Loss: 0.686   lengthscale: 0.129   noise: 0.118
# Epoch 135/150 - Loss: 0.686   lengthscale: 0.129   noise: 0.118
# Epoch 136/150 - Loss: 0.686   lengthscale: 0.129   noise: 0.118
# Epoch 137/150 - Loss: 0.686   lengthscale: 0.129   noise: 0.118
# Epoch 138/150 - Loss: 0.686   lengthscale: 0.129   noise: 0.118
# Epoch 139/150 - Loss: 0.686   lengthscale: 0.129   noise: 0.118
# Epoch 140/150 - Loss: 0.686   lengthscale: 0.129   noise: 0.118
# Epoch 141/150 - Loss: 0.686   lengthscale: 0.129   noise: 0.118
# Epoch 142/150 - Loss: 0.686   lengthscale: 0.129   noise: 0.118
# Epoch 143/150 - Loss: 0.686   lengthscale: 0.129   noise: 0.118
# Epoch 144/150 - Loss: 0.686   lengthscale: 0.129   noise: 0.118
# Epoch 145/150 - Loss: 0.686   lengthscale: 0.128   noise: 0.118
# Epoch 146/150 - Loss: 0.686   lengthscale: 0.128   noise: 0.118
# Epoch 147/150 - Loss: 0.686   lengthscale: 0.128   noise: 0.118
# Epoch 148/150 - Loss: 0.686   lengthscale: 0.128   noise: 0.118
# Epoch 149/150 - Loss: 0.686   lengthscale: 0.128   noise: 0.118
# Epoch 150/150 - Loss: 0.686   lengthscale: 0.128   noise: 0.118
# Step: 3, Val-Loss: 0.6100
# [ 0.01028939 -0.56481594 -0.8691154  ... -0.10379247  0.07495923
#   0.8742735 ]
# Step: 3 of 10, time-taken: 13.07 seconds
# K_D, P_D (40, 2) (1960, 2)
# Epoch 1/150 - Loss: 2.826   lengthscale: 0.100   noise: 0.010
# Epoch 2/150 - Loss: 2.469   lengthscale: 0.091   noise: 0.011
# Epoch 3/150 - Loss: 2.139   lengthscale: 0.083   noise: 0.012
# Epoch 4/150 - Loss: 1.864   lengthscale: 0.075   noise: 0.013
# Epoch 5/150 - Loss: 1.663   lengthscale: 0.068   noise: 0.015
# Epoch 6/150 - Loss: 1.513   lengthscale: 0.062   noise: 0.016
# Epoch 7/150 - Loss: 1.391   lengthscale: 0.057   noise: 0.018
# Epoch 8/150 - Loss: 1.287   lengthscale: 0.053   noise: 0.019
# Epoch 9/150 - Loss: 1.201   lengthscale: 0.050   noise: 0.021
# Epoch 10/150 - Loss: 1.130   lengthscale: 0.047   noise: 0.023
# Epoch 11/150 - Loss: 1.070   lengthscale: 0.044   noise: 0.025
# Epoch 12/150 - Loss: 1.019   lengthscale: 0.042   noise: 0.027
# Epoch 13/150 - Loss: 0.975   lengthscale: 0.040   noise: 0.029
# Epoch 14/150 - Loss: 0.938   lengthscale: 0.039   noise: 0.031
# Epoch 15/150 - Loss: 0.906   lengthscale: 0.037   noise: 0.033
# Epoch 16/150 - Loss: 0.877   lengthscale: 0.036   noise: 0.035
# Epoch 17/150 - Loss: 0.853   lengthscale: 0.035   noise: 0.037
# Epoch 18/150 - Loss: 0.833   lengthscale: 0.035   noise: 0.039
# Epoch 19/150 - Loss: 0.816   lengthscale: 0.034   noise: 0.041
# Epoch 20/150 - Loss: 0.802   lengthscale: 0.034   noise: 0.044
# Epoch 21/150 - Loss: 0.791   lengthscale: 0.034   noise: 0.046
# Epoch 22/150 - Loss: 0.782   lengthscale: 0.033   noise: 0.048
# Epoch 23/150 - Loss: 0.774   lengthscale: 0.033   noise: 0.050
# Epoch 24/150 - Loss: 0.768   lengthscale: 0.034   noise: 0.052
# Epoch 25/150 - Loss: 0.762   lengthscale: 0.034   noise: 0.055
# Epoch 26/150 - Loss: 0.756   lengthscale: 0.034   noise: 0.057
# Epoch 27/150 - Loss: 0.750   lengthscale: 0.034   noise: 0.059
# Epoch 28/150 - Loss: 0.743   lengthscale: 0.035   noise: 0.061
# Epoch 29/150 - Loss: 0.737   lengthscale: 0.036   noise: 0.063
# Epoch 30/150 - Loss: 0.729   lengthscale: 0.036   noise: 0.065
# Epoch 31/150 - Loss: 0.722   lengthscale: 0.037   noise: 0.066
# Epoch 32/150 - Loss: 0.715   lengthscale: 0.038   noise: 0.068
# Epoch 33/150 - Loss: 0.708   lengthscale: 0.039   noise: 0.070
# Epoch 34/150 - Loss: 0.701   lengthscale: 0.040   noise: 0.072
# Epoch 35/150 - Loss: 0.694   lengthscale: 0.042   noise: 0.073
# Epoch 36/150 - Loss: 0.687   lengthscale: 0.043   noise: 0.075
# Epoch 37/150 - Loss: 0.681   lengthscale: 0.045   noise: 0.076
# Epoch 38/150 - Loss: 0.674   lengthscale: 0.046   noise: 0.078
# Epoch 39/150 - Loss: 0.668   lengthscale: 0.048   noise: 0.079
# Epoch 40/150 - Loss: 0.662   lengthscale: 0.050   noise: 0.080
# Epoch 41/150 - Loss: 0.656   lengthscale: 0.052   noise: 0.082
# Epoch 42/150 - Loss: 0.650   lengthscale: 0.054   noise: 0.083
# Epoch 43/150 - Loss: 0.645   lengthscale: 0.057   noise: 0.084
# Epoch 44/150 - Loss: 0.640   lengthscale: 0.059   noise: 0.085
# Epoch 45/150 - Loss: 0.635   lengthscale: 0.061   noise: 0.086
# Epoch 46/150 - Loss: 0.630   lengthscale: 0.064   noise: 0.087
# Epoch 47/150 - Loss: 0.626   lengthscale: 0.067   noise: 0.088
# Epoch 48/150 - Loss: 0.622   lengthscale: 0.069   noise: 0.089
# Epoch 49/150 - Loss: 0.618   lengthscale: 0.072   noise: 0.089
# Epoch 50/150 - Loss: 0.614   lengthscale: 0.075   noise: 0.090
150 - Loss: 0.573   lengthscale: 0.123   noise: 0.097
# Epoch 138/150 - Loss: 0.573   lengthscale: 0.123   noise: 0.097
# Epoch 139/150 - Loss: 0.573   lengthscale: 0.123   noise: 0.097
# Epoch 140/150 - Loss: 0.573   lengthscale: 0.123   noise: 0.097
# Epoch 141/150 - Loss: 0.573   lengthscale: 0.123   noise: 0.097
# Epoch 142/150 - Loss: 0.573   lengthscale: 0.123   noise: 0.097
# Epoch 143/150 - Loss: 0.573   lengthscale: 0.123   noise: 0.097
# Epoch 144/150 - Loss: 0.573   lengthscale: 0.123   noise: 0.097
# Epoch 145/150 - Loss: 0.573   lengthscale: 0.123   noise: 0.097
# Epoch 146/150 - Loss: 0.573   lengthscale: 0.123   noise: 0.097
# Epoch 147/150 - Loss: 0.573   lengthscale: 0.123   noise: 0.097
# Epoch 148/150 - Loss: 0.573   lengthscale: 0.123   noise: 0.097
# Epoch 149/150 - Loss: 0.573   lengthscale: 0.123   noise: 0.097
# Epoch 150/150 - Loss: 0.573   lengthscale: 0.123   noise: 0.097
# Step: 4, Val-Loss: 0.6684
# [ 0.30385906 -0.75518525 -0.9802663  ...  0.5923503   0.02517911
#   0.94973737]
# Step: 4 of 10, time-taken: 12.86 seconds
# K_D, P_D (50, 2) (1950, 2)
# Epoch 1/150 - Loss: 4.635   lengthscale: 0.100   noise: 0.010
# Epoch 2/150 - Loss: 4.166   lengthscale: 0.091   noise: 0.011
# Epoch 3/150 - Loss: 3.740   lengthscale: 0.083   noise: 0.012
# Epoch 4/150 - Loss: 3.360   lengthscale: 0.075   noise: 0.013
# Epoch 5/150 - Loss: 3.024   lengthscale: 0.069   noise: 0.015
# Epoch 6/150 - Loss: 2.730   lengthscale: 0.062   noise: 0.016
# Epoch 7/150 - Loss: 2.479   lengthscale: 0.057   noise: 0.018
# Epoch 8/150 - Loss: 2.264   lengthscale: 0.052   noise: 0.020
# Epoch 9/150 - Loss: 2.077   lengthscale: 0.047   noise: 0.021
# Epoch 10/150 - Loss: 1.913   lengthscale: 0.043   noise: 0.023
# Epoch 11/150 - Loss: 1.771   lengthscale: 0.040   noise: 0.025
# Epoch 12/150 - Loss: 1.649   lengthscale: 0.037   noise: 0.027
# Epoch 13/150 - Loss: 1.547   lengthscale: 0.034   noise: 0.030
# Epoch 14/150 - Loss: 1.460   lengthscale: 0.031   noise: 0.032
# Epoch 15/150 - Loss: 1.386   lengthscale: 0.029   noise: 0.034
# Epoch 16/150 - Loss: 1.323   lengthscale: 0.027   noise: 0.037
# Epoch 17/150 - Loss: 1.270   lengthscale: 0.025   noise: 0.039
# Epoch 18/150 - Loss: 1.223   lengthscale: 0.024   noise: 0.042
# Epoch 19/150 - Loss: 1.184   lengthscale: 0.022   noise: 0.045
# Epoch 20/150 - Loss: 1.150   lengthscale: 0.021   noise: 0.047
# Epoch 21/150 - Loss: 1.121   lengthscale: 0.020   noise: 0.050
# Epoch 22/150 - Loss: 1.095   lengthscale: 0.019   noise: 0.053
# Epoch 23/150 - Loss: 1.072   lengthscale: 0.017   noise: 0.055
# Epoch 24/150 - Loss: 1.052   lengthscale: 0.016   noise: 0.058
# Epoch 25/150 - Loss: 1.034   lengthscale: 0.015   noise: 0.060
# Epoch 26/150 - Loss: 1.018   lengthscale: 0.014   noise: 0.063
# Epoch 27/150 - Loss: 1.004   lengthscale: 0.013   noise: 0.065
# Epoch 28/150 - Loss: 0.991   lengthscale: 0.012   noise: 0.067
# Epoch 29/150 - Loss: 0.980   lengthscale: 0.011   noise: 0.069
# Epoch 30/150 - Loss: 0.972   lengthscale: 0.010   noise: 0.071
# Epoch 31/150 - Loss: 0.966   lengthscale: 0.009   noise: 0.073
# Epoch 32/150 - Loss: 0.963   lengthscale: 0.009   noise: 0.075
# Epoch 33/150 - Loss: 0.963   lengthscale: 0.008   noise: 0.077
# Epoch 34/150 - Loss: 0.964   lengthscale: 0.008   noise: 0.079
# Epoch 35/150 - Loss: 0.965   lengthscale: 0.007   noise: 0.080
# Epoch 36/150 - Loss: 0.968   lengthscale: 0.007   noise: 0.082
# Epoch 37/150 - Loss: 0.969   lengthscale: 0.007   noise: 0.083
# Epoch 38/150 - Loss: 0.970   lengthscale: 0.007   noise: 0.084
# Epoch 39/150 - Loss: 0.971   lengthscale: 0.007   noise: 0.085
# Epoch 40/150 - Loss: 0.970   lengthscale: 0.007   noise: 0.086
# Epoch 41/150 - Loss: 0.970   lengthscale: 0.007   noise: 0.087
# Epoch 42/150 - Loss: 0.968   lengthscale: 0.007   noise: 0.088
# Epoch 43/150 - Loss: 0.967   lengthscale: 0.007   noise: 0.089
# Epoch 44/150 - Loss: 0.966   lengthscale: 0.007   noise: 0.090
# Epoch 45/150 - Loss: 0.964   lengthscale: 0.007   noise: 0.091
# Epoch 46/150 - Loss: 0.962   lengthscale: 0.007   noise: 0.092
# Epoch 47/150 - Loss: 0.961   lengthscale: 0.008   noise: 0.092
# Epoch 48/150 - Loss: 0.959   lengthscale: 0.008   noise: 0.093
# Epoch 49/150 - Loss: 0.957   lengthscale: 0.008   noise: 0.093
# Epoch 50/150 - Loss: 0.956   lengthscale: 0.008   noise: 0.094
# Epoch 51/150 - Loss: 0.955   lengthscale: 0.009   noise: 0.094
# Epoch 52/150 - Loss: 0.954   lengthscale: 0.009   noise: 0.095
# Epoch 53/150 - Loss: 0.954   lengthscale: 0.009   noise: 0.095
# Epoch 54/150 - Loss: 0.954   lengthscale: 0.010   noise: 0.096
# Epoch 55/150 - Loss: 0.954   lengthscale: 0.010   noise: 0.096
# Epoch 56/150 - Loss: 0.954   lengthscale: 0.010   noise: 0.097
# Epoch 57/150 - Loss: 0.954   lengthscale: 0.010   noise: 0.097
# Epoch 58/150 - Loss: 0.954   lengthscale: 0.011   noise: 0.097
# Epoch 59/150 - Loss: 0.954   lengthscale: 0.011   noise: 0.098
# Epoch 60/150 - Loss: 0.954   lengthscale: 0.011   noise: 0.098
# Epoch 61/150 - Loss: 0.954   lengthscale: 0.011   noise: 0.098
# Epoch 62/150 - Loss: 0.954   lengthscale: 0.011   noise: 0.099
# Epoch 63/150 - Loss: 0.954   lengthscale: 0.011   noise: 0.099
# Epoch 64/150 - Loss: 0.954   lengthscale: 0.011   noise: 0.099
# Epoch 65/150 - Loss: 0.954   lengthscale: 0.011   noise: 0.100
# Epoch 66/150 - Loss: 0.954   lengthscale: 0.011   noise: 0.100
# Epoch 67/150 - Loss: 0.953   lengthscale: 0.011   noise: 0.100
# Epoch 68/150 - Loss: 0.953   lengthscale: 0.011   noise: 0.101
# Epoch 69/150 - Loss: 0.953   lengthscale: 0.011   noise: 0.101
# Epoch 70/150 - Loss: 0.953   lengthscale: 0.011   noise: 0.101
# ...
# Epoch 54/150 - Loss: 0.433   lengthscale: 0.158   noise: 0.107
# Epoch 55/150 - Loss: 0.434   lengthscale: 0.158   noise: 0.107
# Epoch 56/150 - Loss: 0.434   lengthscale: 0.157   noise: 0.107
# Epoch 57/150 - Loss: 0.434   lengthscale: 0.157   noise: 0.107
# Epoch 58/150 - Loss: 0.434   lengthscale: 0.157   noise: 0.107
# Epoch 59/150 - Loss: 0.434   lengthscale: 0.157   noise: 0.107
# Epoch 60/150 - Loss: 0.434   lengthscale: 0.157   noise: 0.107
# Epoch 61/150 - Loss: 0.434   lengthscale: 0.158   noise: 0.107
# Epoch 62/150 - Loss: 0.434   lengthscale: 0.158   noise: 0.107
# Epoch 63/150 - Loss: 0.434   lengthscale: 0.158   noise: 0.107
# Epoch 64/150 - Loss: 0.434   lengthscale: 0.158   noise: 0.107
# Epoch 65/150 - Loss: 0.434   lengthscale: 0.159   noise: 0.107
# Epoch 66/150 - Loss: 0.434   lengthscale: 0.159   noise: 0.107
# Epoch 67/150 - Loss: 0.433   lengthscale: 0.159   noise: 0.107
# Epoch 68/150 - Loss: 0.433   lengthscale: 0.159   noise: 0.107
# Epoch 69/150 - Loss: 0.433   lengthscale: 0.159   noise: 0.106
# Epoch 70/150 - Loss: 0.433   lengthscale: 0.159   noise: 0.106
# Epoch 71/150 - Loss: 0.433   lengthscale: 0.159   noise: 0.106
# Epoch 72/150 - Loss: 0.433   lengthscale: 0.159   noise: 0.106
# Epoch 73/150 - Loss: 0.433   lengthscale: 0.159   noise: 0.105
# Epoch 74/150 - Loss: 0.433   lengthscale: 0.159   noise: 0.105
# Epoch 75/150 - Loss: 0.433   lengthscale: 0.159   noise: 0.105
# Epoch 76/150 - Loss: 0.433   lengthscale: 0.159   noise: 0.105
# Epoch 77/150 - Loss: 0.433   lengthscale: 0.159   noise: 0.104
# Epoch 78/150 - Loss: 0.433   lengthscale: 0.159   noise: 0.104
# Epoch 79/150 - Loss: 0.433   lengthscale: 0.159   noise: 0.104
# Epoch 80/150 - Loss: 0.433   lengthscale: 0.159   noise: 0.104
# Epoch 81/150 - Loss: 0.433   lengthscale: 0.159   noise: 0.103
# Epoch 82/150 - Loss: 0.433   lengthscale: 0.159   noise: 0.103
# Epoch 83/150 - Loss: 0.433   lengthscale: 0.159   noise: 0.103
# Epoch 84/150 - Loss: 0.432   lengthscale: 0.159   noise: 0.103
# Epoch 85/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.102
# Epoch 86/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.102
# Epoch 87/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.102
# Epoch 88/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.102
# Epoch 89/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.102
# Epoch 90/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.101
# Epoch 91/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.101
# Epoch 92/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.101
# Epoch 93/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.101
# Epoch 94/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.101
# Epoch 95/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.100
# Epoch 96/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.100
# Epoch 97/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.100
# Epoch 98/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.100
# Epoch 99/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.100
# Epoch 100/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.100
# Epoch 101/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.100
# Epoch 102/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.099
# Epoch 103/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.099
# Epoch 104/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.099
# Epoch 105/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.099
# Epoch 106/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.099
# Epoch 107/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.099
# Epoch 108/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.099
# Epoch 109/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.099
# Epoch 110/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.099
# Epoch 111/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.099
# Epoch 112/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.099
# Epoch 113/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.099
# Epoch 114/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.099
# Epoch 115/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 116/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 117/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 118/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 119/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 120/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 121/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 122/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 123/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 124/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 125/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 126/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 127/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 128/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 129/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 130/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 131/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 132/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 133/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 134/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 135/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 136/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 137/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 138/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 139/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 140/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 141/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 142/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 143/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 144/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 145/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 146/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 147/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 148/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 149/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Epoch 150/150 - Loss: 0.432   lengthscale: 0.158   noise: 0.098
# Step: 9, Val-Loss: 0.8057
# [ 0.7260537  -0.6995629  -0.6990222  ...  0.46910706 -0.45144233
#   0.95790017]
# Step: 9 of 10, time-taken: 12.58 seconds
# K_D, P_D (100, 2) (1900, 2)
# Epoch 1/150 - Loss: 3.862   lengthscale: 0.100   noise: 0.010
# Epoch 2/150 - Loss: 3.436   lengthscale: 0.091   noise: 0.011
# Epoch 3/150 - Loss: 3.063   lengthscale: 0.083   noise: 0.012
# Epoch 4/150 - Loss: 2.742   lengthscale: 0.076   noise: 0.013
# Epoch 5/150 - Loss: 2.461   lengthscale: 0.072   noise: 0.015
# Epoch 6/150 - Loss: 2.212   lengthscale: 0.069   noise: 0.016
# Epoch 7/150 - Loss: 1.991   lengthscale: 0.069   noise: 0.018
# Epoch 8/150 - Loss: 1.796   lengthscale: 0.069   noise: 0.020
# Epoch 9/150 - Loss: 1.623   lengthscale: 0.071   noise: 0.021
# Epoch 10/150 - Loss: 1.471   lengthscale: 0.073   noise: 0.023
# Epoch 11/150 - Loss: 1.338   lengthscale: 0.076   noise: 0.025
# Epoch 12/150 - Loss: 1.222   lengthscale: 0.079   noise: 0.028
# Epoch 13/150 - Loss: 1.121   lengthscale: 0.083   noise: 0.030
# Epoch 14/150 - Loss: 1.032   lengthscale: 0.087   noise: 0.032
# Epoch 15/150 - Loss: 0.953   lengthscale: 0.092   noise: 0.035
# Epoch 16/150 - Loss: 0.884   lengthscale: 0.097   noise: 0.037
# Epoch 17/150 - Loss: 0.823   lengthscale: 0.102   noise: 0.040
# Epoch 18/150 - Loss: 0.769   lengthscale: 0.108   noise: 0.043
# Epoch 19/150 - Loss: 0.723   lengthscale: 0.115   noise: 0.046
# Epoch 20/150 - Loss: 0.684   lengthscale: 0.121   noise: 0.049
# Epoch 21/150 - Loss: 0.651   lengthscale: 0.128   noise: 0.051
# Epoch 22/150 - Loss: 0.622   lengthscale: 0.135   noise: 0.054
# Epoch 23/150 - Loss: 0.598   lengthscale: 0.142   noise: 0.057
# Epoch 24/150 - Loss: 0.578   lengthscale: 0.148   noise: 0.060
# Epoch 25/150 - Loss: 0.561   lengthscale: 0.153   noise: 0.063
# Epoch 26/150 - Loss: 0.546   lengthscale: 0.157   noise: 0.066
# Epoch 27/150 - Loss: 0.533   lengthscale: 0.160   noise: 0.069
# Epoch 28/150 - Loss: 0.522   lengthscale: 0.163   noise: 0.072
# Epoch 29/150 - Loss: 0.513   lengthscale: 0.164   noise: 0.074
# Epoch 30/150 - Loss: 0.505   lengthscale: 0.165   noise: 0.077
# Epoch 31/150 - Loss: 0.499   lengthscale: 0.165   noise: 0.080
# Epoch 32/150 - Loss: 0.493   lengthscale: 0.165   noise: 0.082
# Epoch 33/150 - Loss: 0.489   lengthscale: 0.165   noise: 0.085
# Epoch 34/150 - Loss: 0.485   lengthscale: 0.164   noise: 0.087
# Epoch 35/150 - Loss: 0.483   lengthscale: 0.163   noise: 0.089
# Epoch 36/150 - Loss: 0.480   lengthscale: 0.163   noise: 0.092
# Epoch 37/150 - Loss: 0.479   lengthscale: 0.163   noise: 0.094
# Epoch 38/150 - Loss: 0.477   lengthscale: 0.163   noise: 0.096
# Epoch 39/150 - Loss: 0.476   lengthscale: 0.163   noise: 0.098
# Epoch 40/150 - Loss: 0.475   lengthscale: 0.164   noise: 0.099
# Epoch 41/150 - Loss: 0.474   lengthscale: 0.165   noise: 0.101
# Epoch 42/150 - Loss: 0.474   lengthscale: 0.166   noise: 0.103
# Epoch 43/150 - Loss: 0.473   lengthscale: 0.167   noise: 0.104
# Epoch 44/150 - Loss: 0.473   lengthscale: 0.169   noise: 0.105
# Epoch 45/150 - Loss: 0.472   lengthscale: 0.171   noise: 0.107
# Epoch 46/150 - Loss: 0.472   lengthscale: 0.172   noise: 0.108
# Epoch 47/150 - Loss: 0.472   lengthscale: 0.174   noise: 0.109
# Epoch 48/150 - Loss: 0.472   lengthscale: 0.175   noise: 0.110
# Epoch 49/150 - Loss: 0.472   lengthscale: 0.176   noise: 0.111
# Epoch 50/150 - Loss: 0.472   lengthscale: 0.177   noise: 0.112
# Epoch 51/150 - Loss: 0.472   lengthscale: 0.177   noise: 0.112
# Epoch 52/150 - Loss: 0.472   lengthscale: 0.177   noise: 0.113
# Epoch 53/150 - Loss: 0.472   lengthscale: 0.177   noise: 0.114
# Epoch 54/150 - Loss: 0.472   lengthscale: 0.176   noise: 0.114
# Epoch 55/150 - Loss: 0.472   lengthscale: 0.176   noise: 0.115
# Epoch 56/150 - Loss: 0.472   lengthscale: 0.175   noise: 0.115
# Epoch 57/150 - Loss: 0.472   lengthscale: 0.174   noise: 0.116
# Epoch 58/150 - Loss: 0.472   lengthscale: 0.172   noise: 0.116
# Epoch 59/150 - Loss: 0.472   lengthscale: 0.171   noise: 0.116
# Epoch 60/150 - Loss: 0.472   lengthscale: 0.170   noise: 0.117
# Epoch 61/150 - Loss: 0.472   lengthscale: 0.169   noise: 0.117
# Epoch 62/150 - Loss: 0.473   lengthscale: 0.168   noise: 0.117
# Epoch 63/150 - Loss: 0.473   lengthscale: 0.167   noise: 0.117
# Epoch 64/150 - Loss: 0.473   lengthscale: 0.167   noise: 0.117
# Epoch 65/150 - Loss: 0.473   lengthscale: 0.166   noise: 0.117
# Epoch 66/150 - Loss: 0.473   lengthscale: 0.166   noise: 0.117
# Epoch 67/150 - Loss: 0.473   lengthscale: 0.166   noise: 0.117
# Epoch 68/150 - Loss: 0.473   lengthscale: 0.166   noise: 0.117
# Epoch 69/150 - Loss: 0.472   lengthscale: 0.166   noise: 0.117
# Epoch 70/150 - Loss: 0.472   lengthscale: 0.166   noise: 0.117
# Epoch 71/150 - Loss: 0.472   lengthscale: 0.166   noise: 0.117
# Epoch 72/150 - Loss: 0.472   lengthscale: 0.166   noise: 0.117
# Epoch 73/150 - Loss: 0.472   lengthscale: 0.166   noise: 0.117
# Epoch 74/150 - Loss: 0.472   lengthscale: 0.166   noise: 0.117
# Epoch 75/150 - Loss: 0.472   lengthscale: 0.166   noise: 0.117
# Epoch 76/150 - Loss: 0.472   lengthscale: 0.166   noise: 0.117
# Epoch 77/150 - Loss: 0.472   lengthscale: 0.166   noise: 0.116
# Epoch 78/150 - Loss: 0.472   lengthscale: 0.165   noise: 0.116
# Epoch 79/150 - Loss: 0.472   lengthscale: 0.165   noise: 0.116
# Epoch 80/150 - Loss: 0.472   lengthscale: 0.165   noise: 0.116
# Epoch 81/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.116
# Epoch 82/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.115
# Epoch 83/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.115
# Epoch 84/150 - Loss: 0.472   lengthscale: 0.163   noise: 0.115
# Epoch 85/150 - Loss: 0.472   lengthscale: 0.163   noise: 0.115
# Epoch 86/150 - Loss: 0.472   lengthscale: 0.163   noise: 0.115
# Epoch 87/150 - Loss: 0.472   lengthscale: 0.163   noise: 0.115
# Epoch 88/150 - Loss: 0.472   lengthscale: 0.163   noise: 0.114
# Epoch 89/150 - Loss: 0.472   lengthscale: 0.163   noise: 0.114
# Epoch 90/150 - Loss: 0.472   lengthscale: 0.163   noise: 0.114
# Epoch 91/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.114
# Epoch 92/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.114
# Epoch 93/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.113
# Epoch 94/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.113
# Epoch 95/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.113
# Epoch 96/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.113
# Epoch 97/150 - Loss: 0.472   lengthscale: 0.165   noise: 0.113
# Epoch 98/150 - Loss: 0.472   lengthscale: 0.165   noise: 0.113
# Epoch 99/150 - Loss: 0.472   lengthscale: 0.165   noise: 0.113
# Epoch 100/150 - Loss: 0.472   lengthscale: 0.165   noise: 0.112
# Epoch 101/150 - Loss: 0.472   lengthscale: 0.165   noise: 0.112
# Epoch 102/150 - Loss: 0.472   lengthscale: 0.165   noise: 0.112
# Epoch 103/150 - Loss: 0.472   lengthscale: 0.165   noise: 0.112
# Epoch 104/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.112
# Epoch 105/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.112
# Epoch 106/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.112
# Epoch 107/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.112
# Epoch 108/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.111
# Epoch 109/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.111
# Epoch 110/150 - Loss: 0.472   lengthscale: 0.165   noise: 0.111
# Epoch 111/150 - Loss: 0.472   lengthscale: 0.165   noise: 0.111
# Epoch 112/150 - Loss: 0.472   lengthscale: 0.165   noise: 0.111
# Epoch 113/150 - Loss: 0.472   lengthscale: 0.165   noise: 0.111
# Epoch 114/150 - Loss: 0.472   lengthscale: 0.165   noise: 0.111
# Epoch 115/150 - Loss: 0.472   lengthscale: 0.165   noise: 0.111
# Epoch 116/150 - Loss: 0.472   lengthscale: 0.165   noise: 0.111
# Epoch 117/150 - Loss: 0.472   lengthscale: 0.165   noise: 0.111
# Epoch 118/150 - Loss: 0.472   lengthscale: 0.165   noise: 0.111
# Epoch 119/150 - Loss: 0.472   lengthscale: 0.165   noise: 0.111
# Epoch 120/150 - Loss: 0.472   lengthscale: 0.165   noise: 0.111
# Epoch 121/150 - Loss: 0.472   lengthscale: 0.165   noise: 0.111
# Epoch 122/150 - Loss: 0.472   lengthscale: 0.165   noise: 0.110
# Epoch 123/150 - Loss: 0.472   lengthscale: 0.165   noise: 0.110
# Epoch 124/150 - Loss: 0.472   lengthscale: 0.165   noise: 0.110
# Epoch 125/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.110
# Epoch 126/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.110
# Epoch 127/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.110
# Epoch 128/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.110
# Epoch 129/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.110
# Epoch 130/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.110
# Epoch 131/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.110
# Epoch 132/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.110
# Epoch 133/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.110
# Epoch 134/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.110
# Epoch 135/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.110
# Epoch 136/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.110
# Epoch 137/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.110
# Epoch 138/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.110
# Epoch 139/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.110
# Epoch 140/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.110
# Epoch 141/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.110
# Epoch 142/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.110
# Epoch 143/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.110
# Epoch 144/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.110
# Epoch 145/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.110
# Epoch 146/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.110
# Epoch 147/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.110
# Epoch 148/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.110
# Epoch 149/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.110
# Epoch 150/150 - Loss: 0.472   lengthscale: 0.164   noise: 0.110
# Step: 10, Val-Loss: 0.9753
# [ 0.7528453  -0.69545406 -0.57016903 ...  0.5456138  -0.4962167
#   1.0560466 ]
# Step: 10 of 10, time-taken: 12.64 seconds

# %%
preds
# Out:
# MultivariateNormal(loc: torch.Size([1000]))

# %%
preds[0].mean.numpy()
# Out:
# array(-0.58365375, dtype=float32)

# %%
len(preds.stddev)
# Out:
# 1000
