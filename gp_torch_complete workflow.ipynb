# %% [markdown]
# Torch Implementation of GP
#
# Inspired by: https://docs.gpytorch.ai/en/stable/examples/01_Exact_GPs/Simple_GP_Regression.html

# %%
import math
import torch
import gpytorch
from matplotlib import pyplot as plt
import time

from data import Dataprep, load_data
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns

import pandas as pd


# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dataset_type='Generated_2000'
sensor='foundation_origin xy FloaterOffset [m]'
samples_per_step=10
validation_size=0.1

# %%
data = Dataprep(dataset_type, sensor, initial_samplesize=samples_per_step, scaling='Minmax')
known_data, pool_data = data.known_data, data.pool_data

# %% [markdown]
# Load Data and Normalize

# %%
# We will use the simplest form of GP model, exact inference
class ExactGPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super(ExactGPModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = gpytorch.means.ConstantMean()

        # Assuming you have an RBFKernel instance named `rbf_kernel`:
        rbf_kernel = gpytorch.kernels.RBFKernel()

        # To set an initial length scale:
        rbf_kernel.lengthscale = 0.1

        # kernel can be changed or combined !
        self.covar_module = gpytorch.kernels.ScaleKernel(rbf_kernel)

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

# initialize likelihood and model
#likelihood = gpytorch.likelihoods.GaussianLikelihood()
#model = ExactGPModel(train_x, train_y, likelihood)

# %%
from torch.optim import Adam

# %%
def init_optimizer(learning_rate,model):
    optimizer = Adam(model.parameters(), lr=learning_rate)
    return optimizer
    
def train_model(step, learning_rate):
    print('K_D, P_D', known_data.shape, pool_data.shape)

    # Split the pool data into train and validation sets
    train, val = train_test_split(known_data, test_size=validation_size)

    X_train = torch.tensor(scaler.fit_transform(train[:, 0].reshape(-1, 1))).to(device)  # Adds an extra dimension to make X_train a 2D tensor
    y_train = torch.tensor(train[:, 1]).to(device)
    
    print(X_train.shape)
    print(X_train.dtype)
    # Initialize likelihood and model with training data
    likelihood = gpytorch.likelihoods.GaussianLikelihood().to(device)

    # Assuming you have a GaussianLikelihood instance named `likelihood`:
    likelihood = gpytorch.likelihoods.GaussianLikelihood()

    # To set an initial noise level:
    likelihood.noise = 0.01






    model = ExactGPModel(X_train, y_train, likelihood).to(device)
    
    optimizer = init_optimizer(learning_rate,model) # Initialize the optimizer

    model.train()
    likelihood.train()

    mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)
    total_train_loss = 0

    x, y = X_train, y_train



    # Find optimal model hyperparameters
    model.train()
    likelihood.train()

    # Use the adam optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr=0.1)  # Includes GaussianLikelihood parameters

    # "Loss" for GPs - the marginal log likelihood
    mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

    for epoch in range(epochs):
        # Zero gradients from previous iteration
        optimizer.zero_grad()
        # Output from model
        output = model(X_train)
        # Calc loss and backprop gradients
        loss = -mll(output, y_train)
        print(loss)
        loss.backward()
        print('Epoch %d/%d - Loss: %.3f   lengthscale: %.3f   noise: %.3f' % (
            epoch +1, epochs, loss.item(),
            model.covar_module.base_kernel.lengthscale.item(),
            model.likelihood.noise.item()
        ))
        optimizer.step()

    preds = evaluate_model(likelihood, model,val, step, mll) # Evaluate the model on the validation set

    return preds

# %%
def evaluate_model(likelihood, model, val, step, mll): # 1: EVALUATE THE MODEL ON THE VALIDATION SET

    X_val = torch.tensor(scaler.fit_transform(val[:, 0].reshape(-1, 1))).to(device)  # Adds an extra dimension to make X_train a 2D tensor
    y_val = torch.tensor(val[:, 1]).to(device)
    x, y = X_val, y_val
    # Get into evaluation (predictive posterior) mode
    model.eval()
    likelihood.eval()

    total_val_loss = 0
    # Make predictions by feeding model through likelihood
    with torch.no_grad(), gpytorch.settings.fast_pred_var():
        test_x = torch.linspace(0, 1, 51)
        observed_pred = likelihood(model(X_val))
        output = model(X_val)
        loss = -mll(output, y_val)
        total_val_loss += loss.item()

    step_val_loss = total_val_loss  # Average loss over batches
    writer.add_scalar('loss/val', step_val_loss, step+1)
    if verbose:
        print('Step: {}, Val-Loss: {:.4f}'.format(step+1, step_val_loss))

    if known_data.shape[1] == 2:
        preds = plot(likelihood, model, step)
    return preds

# %%
def plot(likelihood, model, step, samples=500):
    x_pool = pool_data[:, :-1]
    y_pool = pool_data[:, -1]

    x_selected = known_data[:, :-1]
    y_selected = known_data[:, -1]

    scaler = MinMaxScaler()
    x_pool_scaled = scaler.fit_transform(x_pool)
    x_selected_scaled = scaler.transform(x_selected)
    
    x_pool_torch = torch.tensor(x_pool_scaled) 

    model.eval()
    likelihood.eval()

    # Make predictions by feeding model through likelihood
    with torch.no_grad(), gpytorch.settings.fast_pred_var():
        preds = likelihood(model(x_pool_torch))

    means = preds.mean.numpy()  # calculate the mean of the predictions
    lower, upper = preds.confidence_region()
    stds = preds.stddev.numpy()
    
    # Prepare data for plotting
    #df = pd.DataFrame({'x': x_pool_torch.squeeze(), 'mean': means.squeeze(), 'lower': lower, 'upper': upper})

    dfs = []
    y_vals = [means, means + 2 * stds, means - 2 * stds]

    for i in range(3): #len(y_vals)
        dfs.append(pd.DataFrame({'x': x_pool_torch.squeeze(), 'y': y_vals[i].squeeze()}))
    df = pd.concat(dfs)

    print(means.squeeze())
    
    # Plotting
    fig = plt.figure()
    sns.lineplot(data=df, x="x", y="y")
    plt.scatter(x_pool_scaled, y_pool, c="green", marker="*", alpha=0.1)  # Plot actual y values
    plt.scatter(x_selected_scaled, y_selected, c="red", marker="*", alpha=0.2) # plot train data on top
    plt.title(f'Predictions vs Actual Step {step+1}')
    plt.legend(['Mean prediction', 'Pool data (unseen)', 'Seen data'], fontsize='small')
    plt.close(fig)

    # Log the table figure
    writer.add_figure(f'Prediction vs Actual Table Epoch {step+1}', fig, step+1)

    # Log the table figure
    writer.add_figure(f'Prediction vs Actual Table Epoch {step+1}', fig, step+1)

    return preds

# %%
import random

# %%
def predict(self, x): # 2: PREDICT THE UNCERTAINTY ON THE POOL DATA
        pass

def acquisition_function(n, pool_data=pool_data, known_data=known_data): # 3: DECIDE WHICH SAMPLES TO SELECT FROM THE POOL DATA (USING ACQUISITION FUNCTION)
    selected_indices = random.sample(range(len(pool_data)), n)
    known_data, pool_data = update_data(known_data, pool_data, selected_indices)

    return known_data, pool_data

# %%
data = Dataprep(dataset_type, sensor, initial_samplesize=samples_per_step, scaling='Minmax')
known_data, pool_data = data.known_data, data.pool_data

# %%
from torch.utils.tensorboard import SummaryWriter
import datetime
import os

# %%
steps = 10
learning_rate = 0.01
epochs = 150
verbose=True
current_time = datetime.datetime.now().strftime("%Y%m%d-%H%M%S") # Unique directory based on datetime for each run
log_dir = os.path.join('Models/runs', 'BNN_' + dataset_type  + '_' + current_time)
writer = SummaryWriter(log_dir) 
scaler = MinMaxScaler()

device = torch.device("cpu" if torch.backends.mps.is_available() else "cpu")

# %%
known_data, pool_data = data.known_data, data.pool_data

# %%
# Train the model
for step in range(steps):
    start_step = time.time()
    preds = train_model(step,learning_rate) # Train the model
    print('Step: {} of {}, time-taken: {:.2f} seconds'.format(step+1, steps, time.time() - start_step))
    known_data, pool_data = acquisition_function(samples_per_step, pool_data, known_data) # Select the next samples from the pool
# Out:
# K_D, P_D (10, 2) (1990, 2)
# torch.Size([9, 1])
# torch.float32
# tensor(0.3556, grad_fn=<NegBackward0>)
# Epoch 1/150 - Loss: 0.356   lengthscale: 0.100   noise: 0.010
# tensor(0.2583, grad_fn=<NegBackward0>)
# Epoch 2/150 - Loss: 0.258   lengthscale: 0.110   noise: 0.009
# tensor(0.1639, grad_fn=<NegBackward0>)
# Epoch 3/150 - Loss: 0.164   lengthscale: 0.121   noise: 0.008
# tensor(0.0746, grad_fn=<NegBackward0>)
# Epoch 4/150 - Loss: 0.075   lengthscale: 0.133   noise: 0.007
# tensor(-0.0062, grad_fn=<NegBackward0>)
# Epoch 5/150 - Loss: -0.006   lengthscale: 0.146   noise: 0.007
# tensor(-0.0741, grad_fn=<NegBackward0>)
# Epoch 6/150 - Loss: -0.074   lengthscale: 0.160   noise: 0.006
# tensor(-0.1265, grad_fn=<NegBackward0>)
# Epoch 7/150 - Loss: -0.126   lengthscale: 0.175   noise: 0.006
# tensor(-0.1656, grad_fn=<NegBackward0>)
# Epoch 8/150 - Loss: -0.166   lengthscale: 0.191   noise: 0.005
# tensor(-0.1975, grad_fn=<NegBackward0>)
# Epoch 9/150 - Loss: -0.197   lengthscale: 0.207   noise: 0.005
# tensor(-0.2277, grad_fn=<NegBackward0>)
# Epoch 10/150 - Loss: -0.228   lengthscale: 0.224   noise: 0.004
# tensor(-0.2581, grad_fn=<NegBackward0>)
# Epoch 11/150 - Loss: -0.258   lengthscale: 0.243   noise: 0.004
# tensor(-0.2852, grad_fn=<NegBackward0>)
# Epoch 12/150 - Loss: -0.285   lengthscale: 0.262   noise: 0.004
# tensor(-0.3027, grad_fn=<NegBackward0>)
# Epoch 13/150 - Loss: -0.303   lengthscale: 0.282   noise: 0.004
# tensor(-0.3054, grad_fn=<NegBackward0>)
# Epoch 14/150 - Loss: -0.305   lengthscale: 0.301   noise: 0.004
# tensor(-0.2965, grad_fn=<NegBackward0>)
# Epoch 15/150 - Loss: -0.296   lengthscale: 0.315   noise: 0.004
# tensor(-0.2879, grad_fn=<NegBackward0>)
# Epoch 16/150 - Loss: -0.288   lengthscale: 0.323   noise: 0.004
# tensor(-0.2894, grad_fn=<NegBackward0>)
# Epoch 17/150 - Loss: -0.289   lengthscale: 0.323   noise: 0.004
# tensor(-0.3015, grad_fn=<NegBackward0>)
# Epoch 18/150 - Loss: -0.301   lengthscale: 0.318   noise: 0.004
# tensor(-0.3192, grad_fn=<NegBackward0>)
# Epoch 19/150 - Loss: -0.319   lengthscale: 0.308   noise: 0.004
# tensor(-0.3377, grad_fn=<NegBackward0>)
# Epoch 20/150 - Loss: -0.338   lengthscale: 0.295   noise: 0.004
# tensor(-0.3544, grad_fn=<NegBackward0>)
# Epoch 21/150 - Loss: -0.354   lengthscale: 0.282   noise: 0.004
# tensor(-0.3686, grad_fn=<NegBackward0>)
# Epoch 22/150 - Loss: -0.369   lengthscale: 0.268   noise: 0.005
# tensor(-0.3808, grad_fn=<NegBackward0>)
# Epoch 23/150 - Loss: -0.381   lengthscale: 0.255   noise: 0.005
# tensor(-0.3914, grad_fn=<NegBackward0>)
# Epoch 24/150 - Loss: -0.391   lengthscale: 0.243   noise: 0.005
# tensor(-0.4003, grad_fn=<NegBackward0>)
# Epoch 25/150 - Loss: -0.400   lengthscale: 0.232   noise: 0.005
# tensor(-0.4073, grad_fn=<NegBackward0>)
# Epoch 26/150 - Loss: -0.407   lengthscale: 0.222   noise: 0.005
# tensor(-0.4123, grad_fn=<NegBackward0>)
# Epoch 27/150 - Loss: -0.412   lengthscale: 0.214   noise: 0.005
# tensor(-0.4164, grad_fn=<NegBackward0>)
# Epoch 28/150 - Loss: -0.416   lengthscale: 0.206   noise: 0.005
# tensor(-0.4214, grad_fn=<NegBackward0>)
# Epoch 29/150 - Loss: -0.421   lengthscale: 0.199   noise: 0.005
# tensor(-0.4289, grad_fn=<NegBackward0>)
# Epoch 30/150 - Loss: -0.429   lengthscale: 0.193   noise: 0.005
# tensor(-0.4391, grad_fn=<NegBackward0>)
# Epoch 31/150 - Loss: -0.439   lengthscale: 0.188   noise: 0.005
# tensor(-0.4504, grad_fn=<NegBackward0>)
# Epoch 32/150 - Loss: -0.450   lengthscale: 0.183   noise: 0.005
# tensor(-0.4608, grad_fn=<NegBackward0>)
# Epoch 33/150 - Loss: -0.461   lengthscale: 0.178   noise: 0.005
# tensor(-0.4693, grad_fn=<NegBackward0>)
# Epoch 34/150 - Loss: -0.469   lengthscale: 0.174   noise: 0.005
# tensor(-0.4773, grad_fn=<NegBackward0>)
# Epoch 35/150 - Loss: -0.477   lengthscale: 0.170   noise: 0.005
# tensor(-0.4871, grad_fn=<NegBackward0>)
# Epoch 36/150 - Loss: -0.487   lengthscale: 0.165   noise: 0.005
# tensor(-0.4988, grad_fn=<NegBackward0>)
# Epoch 37/150 - Loss: -0.499   lengthscale: 0.161   noise: 0.005
# tensor(-0.5101, grad_fn=<NegBackward0>)
# Epoch 38/150 - Loss: -0.510   lengthscale: 0.157   noise: 0.004
# tensor(-0.5188, grad_fn=<NegBackward0>)
# Epoch 39/150 - Loss: -0.519   lengthscale: 0.153   noise: 0.004
# tensor(-0.5265, grad_fn=<NegBackward0>)
# Epoch 40/150 - Loss: -0.526   lengthscale: 0.148   noise: 0.004
# tensor(-0.5358, grad_fn=<NegBackward0>)
# Epoch 41/150 - Loss: -0.536   lengthscale: 0.144   noise: 0.004
# tensor(-0.5461, grad_fn=<NegBackward0>)
# Epoch 42/150 - Loss: -0.546   lengthscale: 0.139   noise: 0.004
# tensor(-0.5540, grad_fn=<NegBackward0>)
# Epoch 43/150 - Loss: -0.554   lengthscale: 0.134   noise: 0.003
# tensor(-0.5595, grad_fn=<NegBackward0>)
# Epoch 44/150 - Loss: -0.560   lengthscale: 0.130   noise: 0.003
# tensor(-0.5661, grad_fn=<NegBackward0>)
# Epoch 45/150 - Loss: -0.566   lengthscale: 0.125   noise: 0.003
# tensor(-0.5728, grad_fn=<NegBackward0>)
# Epoch 46/150 - Loss: -0.573   lengthscale: 0.120   noise: 0.003
# tensor(-0.5760, grad_fn=<NegBackward0>)
# Epoch 47/150 - Loss: -0.576   lengthscale: 0.116   noise: 0.003
# tensor(-0.5783, grad_fn=<NegBackward0>)
# Epoch 48/150 - Loss: -0.578   lengthscale: 0.112   noise: 0.003
# tensor(-0.5819, grad_fn=<NegBackward0>)
# Epoch 49/150 - Loss: -0.582   lengthscale: 0.108   noise: 0.003
# tensor(-0.5831, grad_fn=<NegBackward0>)
# Epoch 50/150 - Loss: -0.583   lengthscale: 0.105   noise: 0.003
# tensor(-0.5831, grad_fn=<NegBackward0>)
# Epoch 51/150 - Loss: -0.583   lengthscale: 0.101   noise: 0.002
# tensor(-0.5848, grad_fn=<NegBackward0>)
# Epoch 52/150 - Loss: -0.585   lengthscale: 0.098   noise: 0.002
# tensor(-0.5850, grad_fn=<NegBackward0>)
# Epoch 53/150 - Loss: -0.585   lengthscale: 0.096   noise: 0.002
# tensor(-0.5846, grad_fn=<NegBackward0>)
# Epoch 54/150 - Loss: -0.585   lengthscale: 0.093   noise: 0.002
# tensor(-0.5858, grad_fn=<NegBackward0>)
# Epoch 55/150 - Loss: -0.586   lengthscale: 0.091   noise: 0.002
# tensor(-0.5859, grad_fn=<NegBackward0>)
# Epoch 56/150 - Loss: -0.586   lengthscale: 0.089   noise: 0.002
# tensor(-0.5862, grad_fn=<NegBackward0>)
# Epoch 57/150 - Loss: -0.586   lengthscale: 0.087   noise: 0.002
# tensor(-0.5876, grad_fn=<NegBackward0>)
# Epoch 58/150 - Loss: -0.588   lengthscale: 0.086   noise: 0.002
# tensor(-0.5880, grad_fn=<NegBackward0>)
# Epoch 59/150 - Loss: -0.588   lengthscale: 0.084   noise: 0.002
# tensor(-0.5891, grad_fn=<NegBackward0>)
# Epoch 60/150 - Loss: -0.589   lengthscale: 0.083   noise: 0.002
# tensor(-0.5906, grad_fn=<NegBackward0>)
# Epoch 61/150 - Loss: -0.591   lengthscale: 0.081   noise: 0.002
# tensor(-0.5913, grad_fn=<NegBackward0>)
# Epoch 62/150 - Loss: -0.591   lengthscale: 0.080   noise: 0.002
# tensor(-0.5928, grad_fn=<NegBackward0>)
# Epoch 63/150 - Loss: -0.593   lengthscale: 0.079   noise: 0.002
# tensor(-0.5940, grad_fn=<NegBackward0>)
# Epoch 64/150 - Loss: -0.594   lengthscale: 0.078   noise: 0.002
# tensor(-0.5949, grad_fn=<NegBackward0>)
# Epoch 65/150 - Loss: -0.595   lengthscale: 0.078   noise: 0.001
# tensor(-0.5964, grad_fn=<NegBackward0>)
# Epoch 66/150 - Loss: -0.596   lengthscale: 0.077   noise: 0.001
# tensor(-0.5973, grad_fn=<NegBackward0>)
# Epoch 67/150 - Loss: -0.597   lengthscale: 0.076   noise: 0.001
# tensor(-0.5983, grad_fn=<NegBackward0>)
# Epoch 68/150 - Loss: -0.598   lengthscale: 0.076   noise: 0.001
# tensor(-0.5995, grad_fn=<NegBackward0>)
# Epoch 69/150 - Loss: -0.600   lengthscale: 0.075   noise: 0.001
# tensor(-0.6004, grad_fn=<NegBackward0>)
# Epoch 70/150 - Loss: -0.600   lengthscale: 0.075   noise: 0.001
# tensor(-0.6014, grad_fn=<NegBackward0>)
# Epoch 71/150 - Loss: -0.601   lengthscale: 0.075   noise: 0.001
# tensor(-0.6025, grad_fn=<NegBackward0>)
# Epoch 72/150 - Loss: -0.603   lengthscale: 0.074   noise: 0.001
# tensor(-0.6033, grad_fn=<NegBackward0>)
# Epoch 73/150 - Loss: -0.603   lengthscale: 0.074   noise: 0.001
# tensor(-0.6044, grad_fn=<NegBackward0>)
# Epoch 74/150 - Loss: -0.604   lengthscale: 0.074   noise: 0.001
# tensor(-0.6053, grad_fn=<NegBackward0>)
# Epoch 75/150 - Loss: -0.605   lengthscale: 0.074   noise: 0.001
# tensor(-0.6061, grad_fn=<NegBackward0>)
# Epoch 76/150 - Loss: -0.606   lengthscale: 0.074   noise: 0.001
# tensor(-0.6070, grad_fn=<NegBackward0>)
# Epoch 77/150 - Loss: -0.607   lengthscale: 0.074   noise: 0.001
# tensor(-0.6078, grad_fn=<NegBackward0>)
# Epoch 78/150 - Loss: -0.608   lengthscale: 0.074   noise: 0.001
# tensor(-0.6084, grad_fn=<NegBackward0>)
# Epoch 79/150 - Loss: -0.608   lengthscale: 0.074   noise: 0.001
# tensor(-0.6091, grad_fn=<NegBackward0>)
# Epoch 80/150 - Loss: -0.609   lengthscale: 0.074   noise: 0.001
# tensor(-0.6097, grad_fn=<NegBackward0>)
# Epoch 81/150 - Loss: -0.610   lengthscale: 0.074   noise: 0.001
# tensor(-0.6102, grad_fn=<NegBackward0>)
# Epoch 82/150 - Loss: -0.610   lengthscale: 0.074   noise: 0.001
# tensor(-0.6107, grad_fn=<NegBackward0>)
# Epoch 83/150 - Loss: -0.611   lengthscale: 0.073   noise: 0.001
# tensor(-0.6110, grad_fn=<NegBackward0>)
# Epoch 84/150 - Loss: -0.611   lengthscale: 0.073   noise: 0.001
# tensor(-0.6114, grad_fn=<NegBackward0>)
# Epoch 85/150 - Loss: -0.611   lengthscale: 0.073   noise: 0.001
# tensor(-0.6118, grad_fn=<NegBackward0>)
# Epoch 86/150 - Loss: -0.612   lengthscale: 0.073   noise: 0.001
# tensor(-0.6120, grad_fn=<NegBackward0>)
# Epoch 87/150 - Loss: -0.612   lengthscale: 0.072   noise: 0.001
# tensor(-0.6124, grad_fn=<NegBackward0>)
# Epoch 88/150 - Loss: -0.612   lengthscale: 0.072   noise: 0.001
# tensor(-0.6126, grad_fn=<NegBackward0>)
# Epoch 89/150 - Loss: -0.613   lengthscale: 0.071   noise: 0.001
# tensor(-0.6129, grad_fn=<NegBackward0>)
# Epoch 90/150 - Loss: -0.613   lengthscale: 0.071   noise: 0.001
# tensor(-0.6132, grad_fn=<NegBackward0>)
# Epoch 91/150 - Loss: -0.613   lengthscale: 0.070   noise: 0.001
# tensor(-0.6134, grad_fn=<NegBackward0>)
# Epoch 92/150 - Loss: -0.613   lengthscale: 0.070   noise: 0.001
# tensor(-0.6136, grad_fn=<NegBackward0>)
# Epoch 93/150 - Loss: -0.614   lengthscale: 0.069   noise: 0.000
# tensor(-0.6138, grad_fn=<NegBackward0>)
# Epoch 94/150 - Loss: -0.614   lengthscale: 0.069   noise: 0.000
# tensor(-0.6140, grad_fn=<NegBackward0>)
# Epoch 95/150 - Loss: -0.614   lengthscale: 0.068   noise: 0.000
# tensor(-0.6142, grad_fn=<NegBackward0>)
# Epoch 96/150 - Loss: -0.614   lengthscale: 0.068   noise: 0.000
# tensor(-0.6143, grad_fn=<NegBackward0>)
# Epoch 97/150 - Loss: -0.614   lengthscale: 0.067   noise: 0.000
# tensor(-0.6145, grad_fn=<NegBackward0>)
# Epoch 98/150 - Loss: -0.614   lengthscale: 0.067   noise: 0.000
# tensor(-0.6146, grad_fn=<NegBackward0>)
# Epoch 99/150 - Loss: -0.615   lengthscale: 0.066   noise: 0.000
# tensor(-0.6147, grad_fn=<NegBackward0>)
# Epoch 100/150 - Loss: -0.615   lengthscale: 0.066   noise: 0.000
# tensor(-0.6148, grad_fn=<NegBackward0>)
# Epoch 101/150 - Loss: -0.615   lengthscale: 0.065   noise: 0.000
# tensor(-0.6149, grad_fn=<NegBackward0>)
# Epoch 102/150 - Loss: -0.615   lengthscale: 0.065   noise: 0.000
# tensor(-0.6150, grad_fn=<NegBackward0>)
# Epoch 103/150 - Loss: -0.615   lengthscale: 0.064   noise: 0.000
# tensor(-0.6151, grad_fn=<NegBackward0>)
# Epoch 104/150 - Loss: -0.615   lengthscale: 0.064   noise: 0.000
# tensor(-0.6151, grad_fn=<NegBackward0>)
# Epoch 105/150 - Loss: -0.615   lengthscale: 0.064   noise: 0.000
# tensor(-0.6152, grad_fn=<NegBackward0>)
# Epoch 106/150 - Loss: -0.615   lengthscale: 0.063   noise: 0.000
# tensor(-0.6152, grad_fn=<NegBackward0>)
# Epoch 107/150 - Loss: -0.615   lengthscale: 0.063   noise: 0.000
# tensor(-0.6153, grad_fn=<NegBackward0>)
# Epoch 108/150 - Loss: -0.615   lengthscale: 0.063   noise: 0.000
# tensor(-0.6153, grad_fn=<NegBackward0>)
# Epoch 109/150 - Loss: -0.615   lengthscale: 0.062   noise: 0.000
# tensor(-0.6153, grad_fn=<NegBackward0>)
# Epoch 110/150 - Loss: -0.615   lengthscale: 0.062   noise: 0.000
# tensor(-0.6153, grad_fn=<NegBackward0>)
# Epoch 111/150 - Loss: -0.615   lengthscale: 0.062   noise: 0.000
# tensor(-0.6154, grad_fn=<NegBackward0>)
# Epoch 112/150 - Loss: -0.615   lengthscale: 0.062   noise: 0.000
# tensor(-0.6154, grad_fn=<NegBackward0>)
# Epoch 113/150 - Loss: -0.615   lengthscale: 0.061   noise: 0.000
# tensor(-0.6154, grad_fn=<NegBackward0>)
# Epoch 114/150 - Loss: -0.615   lengthscale: 0.061   noise: 0.000
# tensor(-0.6154, grad_fn=<NegBackward0>)
# Epoch 115/150 - Loss: -0.615   lengthscale: 0.061   noise: 0.000
# tensor(-0.6154, grad_fn=<NegBackward0>)
# Epoch 116/150 - Loss: -0.615   lengthscale: 0.061   noise: 0.000
# tensor(-0.6155, grad_fn=<NegBackward0>)
# Epoch 117/150 - Loss: -0.615   lengthscale: 0.061   noise: 0.000
# tensor(-0.6155, grad_fn=<NegBackward0>)
# Epoch 118/150 - Loss: -0.615   lengthscale: 0.061   noise: 0.000
# tensor(-0.6155, grad_fn=<NegBackward0>)
# Epoch 119/150 - Loss: -0.615   lengthscale: 0.061   noise: 0.000
# tensor(-0.6155, grad_fn=<NegBackward0>)
# Epoch 120/150 - Loss: -0.615   lengthscale: 0.061   noise: 0.000
# tensor(-0.6155, grad_fn=<NegBackward0>)
# Epoch 121/150 - Loss: -0.616   lengthscale: 0.060   noise: 0.000
# tensor(-0.6155, grad_fn=<NegBackward0>)
# Epoch 122/150 - Loss: -0.616   lengthscale: 0.060   noise: 0.000
# tensor(-0.6155, grad_fn=<NegBackward0>)
# Epoch 123/150 - Loss: -0.616   lengthscale: 0.060   noise: 0.000
# tensor(-0.6155, grad_fn=<NegBackward0>)
# Epoch 124/150 - Loss: -0.616   lengthscale: 0.060   noise: 0.000
# tensor(-0.6155, grad_fn=<NegBackward0>)
# Epoch 125/150 - Loss: -0.616   lengthscale: 0.060   noise: 0.000
# tensor(-0.6155, grad_fn=<NegBackward0>)
# Epoch 126/150 - Loss: -0.616   lengthscale: 0.060   noise: 0.000
# tensor(-0.6156, grad_fn=<NegBackward0>)
# Epoch 127/150 - Loss: -0.616   lengthscale: 0.060   noise: 0.000
# tensor(-0.6156, grad_fn=<NegBackward0>)
# Epoch 128/150 - Loss: -0.616   lengthscale: 0.060   noise: 0.000
# tensor(-0.6156, grad_fn=<NegBackward0>)
# Epoch 129/150 - Loss: -0.616   lengthscale: 0.060   noise: 0.000
# tensor(-0.6156, grad_fn=<NegBackward0>)
# Epoch 130/150 - Loss: -0.616   lengthscale: 0.060   noise: 0.000
# tensor(-0.6156, grad_fn=<NegBackward0>)
# Epoch 131/150 - Loss: -0.616   lengthscale: 0.060   noise: 0.000
# tensor(-0.6156, grad_fn=<NegBackward0>)
# Epoch 132/150 - Loss: -0.616   lengthscale: 0.060   noise: 0.000
# tensor(-0.6156, grad_fn=<NegBackward0>)
# Epoch 133/150 - Loss: -0.616   lengthscale: 0.060   noise: 0.000
# tensor(-0.6156, grad_fn=<NegBackward0>)
# Epoch 134/150 - Loss: -0.616   lengthscale: 0.060   noise: 0.000
# tensor(-0.6156, grad_fn=<NegBackward0>)
# Epoch 135/150 - Loss: -0.616   lengthscale: 0.060   noise: 0.000
# tensor(-0.6156, grad_fn=<NegBackward0>)
# Epoch 136/150 - Loss: -0.616   lengthscale: 0.060   noise: 0.000
# tensor(-0.6156, grad_fn=<NegBackward0>)
# Epoch 137/150 - Loss: -0.616   lengthscale: 0.060   noise: 0.000
# tensor(-0.6156, grad_fn=<NegBackward0>)
# Epoch 138/150 - Loss: -0.616   lengthscale: 0.060   noise: 0.000
# tensor(-0.6156, grad_fn=<NegBackward0>)
# Epoch 139/150 - Loss: -0.616   lengthscale: 0.060   noise: 0.000
# tensor(-0.6156, grad_fn=<NegBackward0>)
# Epoch 140/150 - Loss: -0.616   lengthscale: 0.060   noise: 0.000
# tensor(-0.6156, grad_fn=<NegBackward0>)
# Epoch 141/150 - Loss: -0.616   lengthscale: 0.060   noise: 0.000
# tensor(-0.6156, grad_fn=<NegBackward0>)
# Epoch 142/150 - Loss: -0.616   lengthscale: 0.060   noise: 0.000
# tensor(-0.6156, grad_fn=<NegBackward0>)
# Epoch 143/150 - Loss: -0.616   lengthscale: 0.060   noise: 0.000
# tensor(-0.6156, grad_fn=<NegBackward0>)
# Epoch 144/150 - Loss: -0.616   lengthscale: 0.060   noise: 0.000
# tensor(-0.6156, grad_fn=<NegBackward0>)
# Epoch 145/150 - Loss: -0.616   lengthscale: 0.060   noise: 0.000
# tensor(-0.6156, grad_fn=<NegBackward0>)
# Epoch 146/150 - Loss: -0.616   lengthscale: 0.060   noise: 0.000
# tensor(-0.6156, grad_fn=<NegBackward0>)
# Epoch 147/150 - Loss: -0.616   lengthscale: 0.060   noise: 0.000
# tensor(-0.6156, grad_fn=<NegBackward0>)
# Epoch 148/150 - Loss: -0.616   lengthscale: 0.060   noise: 0.000
# tensor(-0.6156, grad_fn=<NegBackward0>)
# Epoch 149/150 - Loss: -0.616   lengthscale: 0.060   noise: 0.000
# tensor(-0.6156, grad_fn=<NegBackward0>)
# Epoch 150/150 - Loss: -0.616   lengthscale: 0.060   noise: 0.000
# Step: 1, Val-Loss: -2.7274
# [0.5409082  0.6975755  0.6196141  ... 0.53064805 0.24283957 0.564052  ]
# Step: 1 of 10, time-taken: 13.30 seconds
# K_D, P_D (20, 2) (1980, 2)
# torch.Size([18, 1])
# torch.float32
# tensor(0.1349, grad_fn=<NegBackward0>)
# Epoch 1/150 - Loss: 0.135   lengthscale: 0.100   noise: 0.010
# tensor(0.0535, grad_fn=<NegBackward0>)
# Epoch 2/150 - Loss: 0.053   lengthscale: 0.110   noise: 0.011
# tensor(-0.0170, grad_fn=<NegBackward0>)
# Epoch 3/150 - Loss: -0.017   lengthscale: 0.121   noise: 0.012
# tensor(-0.0765, grad_fn=<NegBackward0>)
# Epoch 4/150 - Loss: -0.076   lengthscale: 0.133   noise: 0.013
# tensor(-0.1288, grad_fn=<NegBackward0>)
# Epoch 5/150 - Loss: -0.129   lengthscale: 0.145   noise: 0.014
# tensor(-0.1770, grad_fn=<NegBackward0>)
# Epoch 6/150 - Loss: -0.177   lengthscale: 0.159   noise: 0.014
# tensor(-0.2211, grad_fn=<NegBackward0>)
# Epoch 7/150 - Loss: -0.221   lengthscale: 0.174   noise: 0.014
# tensor(-0.2607, grad_fn=<NegBackward0>)
# Epoch 8/150 - Loss: -0.261   lengthscale: 0.190   noise: 0.014
# tensor(-0.2951, grad_fn=<NegBackward0>)
# Epoch 9/150 - Loss: -0.295   lengthscale: 0.208   noise: 0.013
# tensor(-0.3238, grad_fn=<NegBackward0>)
# Epoch 10/150 - Loss: -0.324   lengthscale: 0.226   noise: 0.012
# tensor(-0.3448, grad_fn=<NegBackward0>)
# Epoch 11/150 - Loss: -0.345   lengthscale: 0.245   noise: 0.012
# tensor(-0.3562, grad_fn=<NegBackward0>)
# Epoch 12/150 - Loss: -0.356   lengthscale: 0.264   noise: 0.011
# tensor(-0.3570, grad_fn=<NegBackward0>)
# Epoch 13/150 - Loss: -0.357   lengthscale: 0.282   noise: 0.010
# tensor(-0.3492, grad_fn=<NegBackward0>)
# Epoch 14/150 - Loss: -0.349   lengthscale: 0.298   noise: 0.010
# tensor(-0.3382, grad_fn=<NegBackward0>)
# Epoch 15/150 - Loss: -0.338   lengthscale: 0.309   noise: 0.010
# tensor(-0.3301, grad_fn=<NegBackward0>)
# Epoch 16/150 - Loss: -0.330   lengthscale: 0.316   noise: 0.010
# tensor(-0.3289, grad_fn=<NegBackward0>)
# Epoch 17/150 - Loss: -0.329   lengthscale: 0.318   noise: 0.010
# tensor(-0.3346, grad_fn=<NegBackward0>)
# Epoch 18/150 - Loss: -0.335   lengthscale: 0.314   noise: 0.010
# tensor(-0.3451, grad_fn=<NegBackward0>)
# Epoch 19/150 - Loss: -0.345   lengthscale: 0.307   noise: 0.010
# tensor(-0.3575, grad_fn=<NegBackward0>)
# Epoch 20/150 - Loss: -0.357   lengthscale: 0.298   noise: 0.011
# tensor(-0.3696, grad_fn=<NegBackward0>)
# Epoch 21/150 - Loss: -0.370   lengthscale: 0.287   noise: 0.011
# tensor(-0.3803, grad_fn=<NegBackward0>)
# Epoch 22/150 - Loss: -0.380   lengthscale: 0.275   noise: 0.012
# tensor(-0.3891, grad_fn=<NegBackward0>)
# Epoch 23/150 - Loss: -0.389   lengthscale: 0.262   noise: 0.012
# tensor(-0.3964, grad_fn=<NegBackward0>)
# Epoch 24/150 - Loss: -0.396   lengthscale: 0.251   noise: 0.012
# tensor(-0.4021, grad_fn=<NegBackward0>)
# Epoch 25/150 - Loss: -0.402   lengthscale: 0.239   noise: 0.012
# tensor(-0.4066, grad_fn=<NegBackward0>)
# Epoch 26/150 - Loss: -0.407   lengthscale: 0.229   noise: 0.012
# tensor(-0.4098, grad_fn=<NegBackward0>)
# Epoch 27/150 - Loss: -0.410   lengthscale: 0.220   noise: 0.012
# tensor(-0.4120, grad_fn=<NegBackward0>)
# Epoch 28/150 - Loss: -0.412   lengthscale: 0.213   noise: 0.012
# tensor(-0.4136, grad_fn=<NegBackward0>)
# Epoch 29/150 - Loss: -0.414   lengthscale: 0.206   noise: 0.011
# tensor(-0.4151, grad_fn=<NegBackward0>)
# Epoch 30/150 - Loss: -0.415   lengthscale: 0.201   noise: 0.011
# tensor(-0.4171, grad_fn=<NegBackward0>)
# Epoch 31/150 - Loss: -0.417   lengthscale: 0.196   noise: 0.011
# tensor(-0.4199, grad_fn=<NegBackward0>)
# Epoch 32/150 - Loss: -0.420   lengthscale: 0.193   noise: 0.010
# tensor(-0.4235, grad_fn=<NegBackward0>)
# Epoch 33/150 - Loss: -0.423   lengthscale: 0.191   noise: 0.010
# tensor(-0.4275, grad_fn=<NegBackward0>)
# Epoch 34/150 - Loss: -0.427   lengthscale: 0.189   noise: 0.010
# tensor(-0.4315, grad_fn=<NegBackward0>)
# Epoch 35/150 - Loss: -0.431   lengthscale: 0.188   noise: 0.010
# tensor(-0.4353, grad_fn=<NegBackward0>)
# Epoch 36/150 - Loss: -0.435   lengthscale: 0.188   noise: 0.010
# tensor(-0.4391, grad_fn=<NegBackward0>)
# Epoch 37/150 - Loss: -0.439   lengthscale: 0.188   noise: 0.010
# tensor(-0.4430, grad_fn=<NegBackward0>)
# Epoch 38/150 - Loss: -0.443   lengthscale: 0.188   noise: 0.010
# tensor(-0.4466, grad_fn=<NegBackward0>)
# Epoch 39/150 - Loss: -0.447   lengthscale: 0.188   noise: 0.010
# tensor(-0.4494, grad_fn=<NegBackward0>)
# Epoch 40/150 - Loss: -0.449   lengthscale: 0.189   noise: 0.011
# tensor(-0.4510, grad_fn=<NegBackward0>)
# Epoch 41/150 - Loss: -0.451   lengthscale: 0.189   noise: 0.011
# tensor(-0.4519, grad_fn=<NegBackward0>)
# Epoch 42/150 - Loss: -0.452   lengthscale: 0.189   noise: 0.011
# tensor(-0.4528, grad_fn=<NegBackward0>)
# Epoch 43/150 - Loss: -0.453   lengthscale: 0.189   noise: 0.011
# tensor(-0.4539, grad_fn=<NegBackward0>)
# Epoch 44/150 - Loss: -0.454   lengthscale: 0.188   noise: 0.011
# tensor(-0.4547, grad_fn=<NegBackward0>)
# Epoch 45/150 - Loss: -0.455   lengthscale: 0.187   noise: 0.011
# tensor(-0.4552, grad_fn=<NegBackward0>)
# Epoch 46/150 - Loss: -0.455   lengthscale: 0.185   noise: 0.011
# tensor(-0.4559, grad_fn=<NegBackward0>)
# Epoch 47/150 - Loss: -0.456   lengthscale: 0.183   noise: 0.011
# tensor(-0.4570, grad_fn=<NegBackward0>)
# Epoch 48/150 - Loss: -0.457   lengthscale: 0.181   noise: 0.011
# tensor(-0.4582, grad_fn=<NegBackward0>)
# Epoch 49/150 - Loss: -0.458   lengthscale: 0.178   noise: 0.011
# tensor(-0.4590, grad_fn=<NegBackward0>)
# Epoch 50/150 - Loss: -0.459   lengthscale: 0.175   noise: 0.011
# tensor(-0.4597, grad_fn=<NegBackward0>)
# Epoch 51/150 - Loss: -0.460   lengthscale: 0.172   noise: 0.011
# tensor(-0.4607, grad_fn=<NegBackward0>)
# Epoch 52/150 - Loss: -0.461   lengthscale: 0.169   noise: 0.011
# tensor(-0.4615, grad_fn=<NegBackward0>)
# Epoch 53/150 - Loss: -0.462   lengthscale: 0.166   noise: 0.011
# tensor(-0.4620, grad_fn=<NegBackward0>)
# Epoch 54/150 - Loss: -0.462   lengthscale: 0.163   noise: 0.011
# tensor(-0.4624, grad_fn=<NegBackward0>)
# Epoch 55/150 - Loss: -0.462   lengthscale: 0.160   noise: 0.011
# tensor(-0.4630, grad_fn=<NegBackward0>)
# Epoch 56/150 - Loss: -0.463   lengthscale: 0.157   noise: 0.011
# tensor(-0.4632, grad_fn=<NegBackward0>)
# Epoch 57/150 - Loss: -0.463   lengthscale: 0.155   noise: 0.011
# tensor(-0.4632, grad_fn=<NegBackward0>)
# Epoch 58/150 - Loss: -0.463   lengthscale: 0.152   noise: 0.011
# tensor(-0.4634, grad_fn=<NegBackward0>)
# Epoch 59/150 - Loss: -0.463   lengthscale: 0.150   noise: 0.011
# tensor(-0.4635, grad_fn=<NegBackward0>)
# Epoch 60/150 - Loss: -0.463   lengthscale: 0.148   noise: 0.011
# tensor(-0.4633, grad_fn=<NegBackward0>)
# Epoch 61/150 - Loss: -0.463   lengthscale: 0.147   noise: 0.011
# tensor(-0.4633, grad_fn=<NegBackward0>)
# Epoch 62/150 - Loss: -0.463   lengthscale: 0.145   noise: 0.011
# tensor(-0.4633, grad_fn=<NegBackward0>)
# Epoch 63/150 - Loss: -0.463   lengthscale: 0.144   noise: 0.011
# tensor(-0.4632, grad_fn=<NegBackward0>)
# Epoch 64/150 - Loss: -0.463   lengthscale: 0.143   noise: 0.011
# tensor(-0.4632, grad_fn=<NegBackward0>)
# Epoch 65/150 - Loss: -0.463   lengthscale: 0.142   noise: 0.011
# tensor(-0.4633, grad_fn=<NegBackward0>)
# Epoch 66/150 - Loss: -0.463   lengthscale: 0.142   noise: 0.011
# tensor(-0.4632, grad_fn=<NegBackward0>)
# Epoch 67/150 - Loss: -0.463   lengthscale: 0.141   noise: 0.011
# tensor(-0.4633, grad_fn=<NegBackward0>)
# Epoch 68/150 - Loss: -0.463   lengthscale: 0.141   noise: 0.011
# tensor(-0.4633, grad_fn=<NegBackward0>)
# Epoch 69/150 - Loss: -0.463   lengthscale: 0.141   noise: 0.011
# tensor(-0.4633, grad_fn=<NegBackward0>)
# Epoch 70/150 - Loss: -0.463   lengthscale: 0.141   noise: 0.011
# tensor(-0.4633, grad_fn=<NegBackward0>)
# Epoch 71/150 - Loss: -0.463   lengthscale: 0.141   noise: 0.011
# tensor(-0.4633, grad_fn=<NegBackward0>)
# Epoch 72/150 - Loss: -0.463   lengthscale: 0.141   noise: 0.011
# tensor(-0.4633, grad_fn=<NegBackward0>)
# Epoch 73/150 - Loss: -0.463   lengthscale: 0.141   noise: 0.011
# tensor(-0.4633, grad_fn=<NegBackward0>)
# Epoch 74/150 - Loss: -0.463   lengthscale: 0.141   noise: 0.011
# tensor(-0.4633, grad_fn=<NegBackward0>)
# Epoch 75/150 - Loss: -0.463   lengthscale: 0.142   noise: 0.011
# tensor(-0.4633, grad_fn=<NegBackward0>)
# Epoch 76/150 - Loss: -0.463   lengthscale: 0.142   noise: 0.011
# tensor(-0.4633, grad_fn=<NegBackward0>)
# Epoch 77/150 - Loss: -0.463   lengthscale: 0.142   noise: 0.011
# tensor(-0.4633, grad_fn=<NegBackward0>)
# Epoch 78/150 - Loss: -0.463   lengthscale: 0.142   noise: 0.011
# tensor(-0.4633, grad_fn=<NegBackward0>)
# Epoch 79/150 - Loss: -0.463   lengthscale: 0.143   noise: 0.011
# tensor(-0.4633, grad_fn=<NegBackward0>)
# Epoch 80/150 - Loss: -0.463   lengthscale: 0.143   noise: 0.011
# tensor(-0.4633, grad_fn=<NegBackward0>)
# Epoch 81/150 - Loss: -0.463   lengthscale: 0.143   noise: 0.011
# tensor(-0.4633, grad_fn=<NegBackward0>)
# Epoch 82/150 - Loss: -0.463   lengthscale: 0.143   noise: 0.011
# tensor(-0.4634, grad_fn=<NegBackward0>)
# Epoch 83/150 - Loss: -0.463   lengthscale: 0.144   noise: 0.011
# tensor(-0.4634, grad_fn=<NegBackward0>)
# Epoch 84/150 - Loss: -0.463   lengthscale: 0.144   noise: 0.011
# tensor(-0.4634, grad_fn=<NegBackward0>)
# Epoch 85/150 - Loss: -0.463   lengthscale: 0.144   noise: 0.011
# tensor(-0.4635, grad_fn=<NegBackward0>)
# Epoch 86/150 - Loss: -0.463   lengthscale: 0.144   noise: 0.011
# tensor(-0.4635, grad_fn=<NegBackward0>)
# Epoch 87/150 - Loss: -0.463   lengthscale: 0.144   noise: 0.011
# tensor(-0.4635, grad_fn=<NegBackward0>)
# Epoch 88/150 - Loss: -0.464   lengthscale: 0.144   noise: 0.011
# tensor(-0.4635, grad_fn=<NegBackward0>)
# Epoch 89/150 - Loss: -0.464   lengthscale: 0.144   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 90/150 - Loss: -0.464   lengthscale: 0.145   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 91/150 - Loss: -0.464   lengthscale: 0.145   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 92/150 - Loss: -0.464   lengthscale: 0.145   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 93/150 - Loss: -0.464   lengthscale: 0.145   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 94/150 - Loss: -0.464   lengthscale: 0.146   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 95/150 - Loss: -0.464   lengthscale: 0.146   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 96/150 - Loss: -0.464   lengthscale: 0.146   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 97/150 - Loss: -0.464   lengthscale: 0.146   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 98/150 - Loss: -0.464   lengthscale: 0.147   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 99/150 - Loss: -0.464   lengthscale: 0.147   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 100/150 - Loss: -0.464   lengthscale: 0.147   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 101/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 102/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 103/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 104/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 105/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 106/150 - Loss: -0.464   lengthscale: 0.149   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 107/150 - Loss: -0.464   lengthscale: 0.149   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 108/150 - Loss: -0.464   lengthscale: 0.149   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 109/150 - Loss: -0.464   lengthscale: 0.149   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 110/150 - Loss: -0.464   lengthscale: 0.149   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 111/150 - Loss: -0.464   lengthscale: 0.149   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 112/150 - Loss: -0.464   lengthscale: 0.149   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 113/150 - Loss: -0.464   lengthscale: 0.149   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 114/150 - Loss: -0.464   lengthscale: 0.149   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 115/150 - Loss: -0.464   lengthscale: 0.149   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 116/150 - Loss: -0.464   lengthscale: 0.149   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 117/150 - Loss: -0.464   lengthscale: 0.149   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 118/150 - Loss: -0.464   lengthscale: 0.149   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 119/150 - Loss: -0.464   lengthscale: 0.149   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 120/150 - Loss: -0.464   lengthscale: 0.149   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 121/150 - Loss: -0.464   lengthscale: 0.149   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 122/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 123/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 124/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 125/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 126/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 127/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 128/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 129/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 130/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 131/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 132/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 133/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 134/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 135/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 136/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 137/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 138/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 139/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 140/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 141/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 142/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 143/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 144/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 145/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 146/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 147/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 148/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 149/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# tensor(-0.4636, grad_fn=<NegBackward0>)
# Epoch 150/150 - Loss: -0.464   lengthscale: 0.148   noise: 0.011
# Step: 2, Val-Loss: 1.6456
# [0.5855151  0.6807621  0.6429843  ... 0.57338655 0.29871163 0.42607242]
# Step: 2 of 10, time-taken: 13.29 seconds
# K_D, P_D (30, 2) (1970, 2)
# torch.Size([27, 1])
# torch.float32
# tensor(-0.2862, grad_fn=<NegBackward0>)
# Epoch 1/150 - Loss: -0.286   lengthscale: 0.100   noise: 0.010
# tensor(-0.3680, grad_fn=<NegBackward0>)
# Epoch 2/150 - Loss: -0.368   lengthscale: 0.110   noise: 0.009
# tensor(-0.4396, grad_fn=<NegBackward0>)
# Epoch 3/150 - Loss: -0.440   lengthscale: 0.121   noise: 0.008
# tensor(-0.5016, grad_fn=<NegBackward0>)
# Epoch 4/150 - Loss: -0.502   lengthscale: 0.132   noise: 0.007
# tensor(-0.5557, grad_fn=<NegBackward0>)
# Epoch 5/150 - Loss: -0.556   lengthscale: 0.145   noise: 0.007
# tensor(-0.6033, grad_fn=<NegBackward0>)
# Epoch 6/150 - Loss: -0.603   lengthscale: 0.159   noise: 0.006
# tensor(-0.6447, grad_fn=<NegBackward0>)
# Epoch 7/150 - Loss: -0.645   lengthscale: 0.173   noise: 0.006
# tensor(-0.6791, grad_fn=<NegBackward0>)
# Epoch 8/150 - Loss: -0.679   lengthscale: 0.189   noise: 0.005
# tensor(-0.7052, grad_fn=<NegBackward0>)
# Epoch 9/150 - Loss: -0.705   lengthscale: 0.206   noise: 0.005
# tensor(-0.7216, grad_fn=<NegBackward0>)
# Epoch 10/150 - Loss: -0.722   lengthscale: 0.224   noise: 0.005
# tensor(-0.7263, grad_fn=<NegBackward0>)
# Epoch 11/150 - Loss: -0.726   lengthscale: 0.242   noise: 0.004
# tensor(-0.7180, grad_fn=<NegBackward0>)
# Epoch 12/150 - Loss: -0.718   lengthscale: 0.258   noise: 0.004
# tensor(-0.7023, grad_fn=<NegBackward0>)
# Epoch 13/150 - Loss: -0.702   lengthscale: 0.271   noise: 0.004
# tensor(-0.6916, grad_fn=<NegBackward0>)
# Epoch 14/150 - Loss: -0.692   lengthscale: 0.278   noise: 0.004
# tensor(-0.6933, grad_fn=<NegBackward0>)
# Epoch 15/150 - Loss: -0.693   lengthscale: 0.278   noise: 0.005
# tensor(-0.7056, grad_fn=<NegBackward0>)
# Epoch 16/150 - Loss: -0.706   lengthscale: 0.274   noise: 0.005
# tensor(-0.7228, grad_fn=<NegBackward0>)
# Epoch 17/150 - Loss: -0.723   lengthscale: 0.266   noise: 0.005
# tensor(-0.7392, grad_fn=<NegBackward0>)
# Epoch 18/150 - Loss: -0.739   lengthscale: 0.257   noise: 0.005
# tensor(-0.7515, grad_fn=<NegBackward0>)
# Epoch 19/150 - Loss: -0.752   lengthscale: 0.246   noise: 0.005
# tensor(-0.7588, grad_fn=<NegBackward0>)
# Epoch 20/150 - Loss: -0.759   lengthscale: 0.236   noise: 0.006
# tensor(-0.7621, grad_fn=<NegBackward0>)
# Epoch 21/150 - Loss: -0.762   lengthscale: 0.226   noise: 0.006
# tensor(-0.7630, grad_fn=<NegBackward0>)
# Epoch 22/150 - Loss: -0.763   lengthscale: 0.217   noise: 0.006
# tensor(-0.7634, grad_fn=<NegBackward0>)
# Epoch 23/150 - Loss: -0.763   lengthscale: 0.209   noise: 0.006
# tensor(-0.7642, grad_fn=<NegBackward0>)
# Epoch 24/150 - Loss: -0.764   lengthscale: 0.202   noise: 0.006
# tensor(-0.7658, grad_fn=<NegBackward0>)
# Epoch 25/150 - Loss: -0.766   lengthscale: 0.197   noise: 0.006
# tensor(-0.7683, grad_fn=<NegBackward0>)
# Epoch 26/150 - Loss: -0.768   lengthscale: 0.192   noise: 0.006
# tensor(-0.7712, grad_fn=<NegBackward0>)
# Epoch 27/150 - Loss: -0.771   lengthscale: 0.189   noise: 0.006
# tensor(-0.7742, grad_fn=<NegBackward0>)
# Epoch 28/150 - Loss: -0.774   lengthscale: 0.187   noise: 0.006
# tensor(-0.7771, grad_fn=<NegBackward0>)
# Epoch 29/150 - Loss: -0.777   lengthscale: 0.185   noise: 0.006
# tensor(-0.7803, grad_fn=<NegBackward0>)
# Epoch 30/150 - Loss: -0.780   lengthscale: 0.184   noise: 0.006
# tensor(-0.7839, grad_fn=<NegBackward0>)
# Epoch 31/150 - Loss: -0.784   lengthscale: 0.184   noise: 0.005
# tensor(-0.7881, grad_fn=<NegBackward0>)
# Epoch 32/150 - Loss: -0.788   lengthscale: 0.184   noise: 0.005
# tensor(-0.7923, grad_fn=<NegBackward0>)
# Epoch 33/150 - Loss: -0.792   lengthscale: 0.185   noise: 0.005
# tensor(-0.7960, grad_fn=<NegBackward0>)
# Epoch 34/150 - Loss: -0.796   lengthscale: 0.186   noise: 0.005
# tensor(-0.7985, grad_fn=<NegBackward0>)
# Epoch 35/150 - Loss: -0.798   lengthscale: 0.187   noise: 0.005
# tensor(-0.7997, grad_fn=<NegBackward0>)
# Epoch 36/150 - Loss: -0.800   lengthscale: 0.188   noise: 0.005
# tensor(-0.8002, grad_fn=<NegBackward0>)
# Epoch 37/150 - Loss: -0.800   lengthscale: 0.189   noise: 0.005
# tensor(-0.8008, grad_fn=<NegBackward0>)
# Epoch 38/150 - Loss: -0.801   lengthscale: 0.189   noise: 0.005
# tensor(-0.8019, grad_fn=<NegBackward0>)
# Epoch 39/150 - Loss: -0.802   lengthscale: 0.189   noise: 0.005
# tensor(-0.8030, grad_fn=<NegBackward0>)
# Epoch 40/150 - Loss: -0.803   lengthscale: 0.189   noise: 0.005
# tensor(-0.8036, grad_fn=<NegBackward0>)
# Epoch 41/150 - Loss: -0.804   lengthscale: 0.188   noise: 0.005
# tensor(-0.8038, grad_fn=<NegBackward0>)
# Epoch 42/150 - Loss: -0.804   lengthscale: 0.187   noise: 0.005
# tensor(-0.8041, grad_fn=<NegBackward0>)
# Epoch 43/150 - Loss: -0.804   lengthscale: 0.185   noise: 0.005
# tensor(-0.8052, grad_fn=<NegBackward0>)
# Epoch 44/150 - Loss: -0.805   lengthscale: 0.183   noise: 0.005
# tensor(-0.8066, grad_fn=<NegBackward0>)
# Epoch 45/150 - Loss: -0.807   lengthscale: 0.180   noise: 0.005
# tensor(-0.8076, grad_fn=<NegBackward0>)
# Epoch 46/150 - Loss: -0.808   lengthscale: 0.178   noise: 0.005
# tensor(-0.8080, grad_fn=<NegBackward0>)
# Epoch 47/150 - Loss: -0.808   lengthscale: 0.175   noise: 0.005
# tensor(-0.8083, grad_fn=<NegBackward0>)
# Epoch 48/150 - Loss: -0.808   lengthscale: 0.172   noise: 0.005
# tensor(-0.8090, grad_fn=<NegBackward0>)
# Epoch 49/150 - Loss: -0.809   lengthscale: 0.169   noise: 0.005
# tensor(-0.8097, grad_fn=<NegBackward0>)
# Epoch 50/150 - Loss: -0.810   lengthscale: 0.166   noise: 0.005
# tensor(-0.8098, grad_fn=<NegBackward0>)
# Epoch 51/150 - Loss: -0.810   lengthscale: 0.164   noise: 0.005
# tensor(-0.8096, grad_fn=<NegBackward0>)
# Epoch 52/150 - Loss: -0.810   lengthscale: 0.161   noise: 0.005
# tensor(-0.8097, grad_fn=<NegBackward0>)
# Epoch 53/150 - Loss: -0.810   lengthscale: 0.159   noise: 0.005
# tensor(-0.8099, grad_fn=<NegBackward0>)
# Epoch 54/150 - Loss: -0.810   lengthscale: 0.158   noise: 0.005
# tensor(-0.8099, grad_fn=<NegBackward0>)
# Epoch 55/150 - Loss: -0.810   lengthscale: 0.156   noise: 0.005
# tensor(-0.8096, grad_fn=<NegBackward0>)
# Epoch 56/150 - Loss: -0.810   lengthscale: 0.155   noise: 0.005
# tensor(-0.8095, grad_fn=<NegBackward0>)
# Epoch 57/150 - Loss: -0.810   lengthscale: 0.154   noise: 0.005
# tensor(-0.8097, grad_fn=<NegBackward0>)
# Epoch 58/150 - Loss: -0.810   lengthscale: 0.153   noise: 0.005
# tensor(-0.8097, grad_fn=<NegBackward0>)
# Epoch 59/150 - Loss: -0.810   lengthscale: 0.153   noise: 0.005
# tensor(-0.8096, grad_fn=<NegBackward0>)
# Epoch 60/150 - Loss: -0.810   lengthscale: 0.153   noise: 0.005
# tensor(-0.8096, grad_fn=<NegBackward0>)
# Epoch 61/150 - Loss: -0.810   lengthscale: 0.153   noise: 0.005
# tensor(-0.8098, grad_fn=<NegBackward0>)
# Epoch 62/150 - Loss: -0.810   lengthscale: 0.153   noise: 0.005
# tensor(-0.8098, grad_fn=<NegBackward0>)
# Epoch 63/150 - Loss: -0.810   lengthscale: 0.153   noise: 0.005
# tensor(-0.8098, grad_fn=<NegBackward0>)
# Epoch 64/150 - Loss: -0.810   lengthscale: 0.153   noise: 0.005
# tensor(-0.8098, grad_fn=<NegBackward0>)
# Epoch 65/150 - Loss: -0.810   lengthscale: 0.154   noise: 0.005
# tensor(-0.8099, grad_fn=<NegBackward0>)
# Epoch 66/150 - Loss: -0.810   lengthscale: 0.154   noise: 0.005
# tensor(-0.8099, grad_fn=<NegBackward0>)
# Epoch 67/150 - Loss: -0.810   lengthscale: 0.155   noise: 0.005
# tensor(-0.8098, grad_fn=<NegBackward0>)
# Epoch 68/150 - Loss: -0.810   lengthscale: 0.155   noise: 0.005
# tensor(-0.8098, grad_fn=<NegBackward0>)
# Epoch 69/150 - Loss: -0.810   lengthscale: 0.155   noise: 0.005
# tensor(-0.8098, grad_fn=<NegBackward0>)
# Epoch 70/150 - Loss: -0.810   lengthscale: 0.156   noise: 0.005
# tensor(-0.8098, grad_fn=<NegBackward0>)
# Epoch 71/150 - Loss: -0.810   lengthscale: 0.156   noise: 0.005
# tensor(-0.8098, grad_fn=<NegBackward0>)
# Epoch 72/150 - Loss: -0.810   lengthscale: 0.156   noise: 0.005
# tensor(-0.8099, grad_fn=<NegBackward0>)
# Epoch 73/150 - Loss: -0.810   lengthscale: 0.156   noise: 0.005
# tensor(-0.8099, grad_fn=<NegBackward0>)
# Epoch 74/150 - Loss: -0.810   lengthscale: 0.156   noise: 0.005
# tensor(-0.8100, grad_fn=<NegBackward0>)
# Epoch 75/150 - Loss: -0.810   lengthscale: 0.156   noise: 0.005
# tensor(-0.8100, grad_fn=<NegBackward0>)
# Epoch 76/150 - Loss: -0.810   lengthscale: 0.156   noise: 0.005
# tensor(-0.8101, grad_fn=<NegBackward0>)
# Epoch 77/150 - Loss: -0.810   lengthscale: 0.156   noise: 0.005
# tensor(-0.8101, grad_fn=<NegBackward0>)
# Epoch 78/150 - Loss: -0.810   lengthscale: 0.156   noise: 0.005
# tensor(-0.8101, grad_fn=<NegBackward0>)
# Epoch 79/150 - Loss: -0.810   lengthscale: 0.157   noise: 0.005
# tensor(-0.8101, grad_fn=<NegBackward0>)
# Epoch 80/150 - Loss: -0.810   lengthscale: 0.157   noise: 0.005
# tensor(-0.8102, grad_fn=<NegBackward0>)
# Epoch 81/150 - Loss: -0.810   lengthscale: 0.157   noise: 0.005
# tensor(-0.8102, grad_fn=<NegBackward0>)
# Epoch 82/150 - Loss: -0.810   lengthscale: 0.157   noise: 0.005
# tensor(-0.8102, grad_fn=<NegBackward0>)
# Epoch 83/150 - Loss: -0.810   lengthscale: 0.157   noise: 0.005
# tensor(-0.8102, grad_fn=<NegBackward0>)
# Epoch 84/150 - Loss: -0.810   lengthscale: 0.157   noise: 0.005
# tensor(-0.8102, grad_fn=<NegBackward0>)
# Epoch 85/150 - Loss: -0.810   lengthscale: 0.158   noise: 0.005
# tensor(-0.8102, grad_fn=<NegBackward0>)
# Epoch 86/150 - Loss: -0.810   lengthscale: 0.158   noise: 0.005
# tensor(-0.8102, grad_fn=<NegBackward0>)
# Epoch 87/150 - Loss: -0.810   lengthscale: 0.158   noise: 0.005
# tensor(-0.8102, grad_fn=<NegBackward0>)
# Epoch 88/150 - Loss: -0.810   lengthscale: 0.159   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 89/150 - Loss: -0.810   lengthscale: 0.159   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 90/150 - Loss: -0.810   lengthscale: 0.159   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 91/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 92/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 93/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 94/150 - Loss: -0.810   lengthscale: 0.161   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 95/150 - Loss: -0.810   lengthscale: 0.161   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 96/150 - Loss: -0.810   lengthscale: 0.161   noise: 0.005
# tensor(-0.8102, grad_fn=<NegBackward0>)
# Epoch 97/150 - Loss: -0.810   lengthscale: 0.161   noise: 0.005
# tensor(-0.8102, grad_fn=<NegBackward0>)
# Epoch 98/150 - Loss: -0.810   lengthscale: 0.161   noise: 0.005
# tensor(-0.8102, grad_fn=<NegBackward0>)
# Epoch 99/150 - Loss: -0.810   lengthscale: 0.161   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 100/150 - Loss: -0.810   lengthscale: 0.161   noise: 0.005
# tensor(-0.8102, grad_fn=<NegBackward0>)
# Epoch 101/150 - Loss: -0.810   lengthscale: 0.161   noise: 0.005
# tensor(-0.8102, grad_fn=<NegBackward0>)
# Epoch 102/150 - Loss: -0.810   lengthscale: 0.161   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 103/150 - Loss: -0.810   lengthscale: 0.161   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 104/150 - Loss: -0.810   lengthscale: 0.161   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 105/150 - Loss: -0.810   lengthscale: 0.161   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 106/150 - Loss: -0.810   lengthscale: 0.161   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 107/150 - Loss: -0.810   lengthscale: 0.161   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 108/150 - Loss: -0.810   lengthscale: 0.161   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 109/150 - Loss: -0.810   lengthscale: 0.161   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 110/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 111/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 112/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 113/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 114/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 115/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 116/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 117/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 118/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 119/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 120/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 121/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 122/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 123/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 124/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 125/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 126/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 127/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 128/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 129/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 130/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 131/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 132/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 133/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 134/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 135/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 136/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 137/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 138/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 139/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 140/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 141/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 142/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 143/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 144/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 145/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 146/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 147/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 148/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 149/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# tensor(-0.8103, grad_fn=<NegBackward0>)
# Epoch 150/150 - Loss: -0.810   lengthscale: 0.160   noise: 0.005
# Step: 3, Val-Loss: 0.9252
# [0.6398258  0.6992334  0.68793905 ... 0.62790847 0.22766209 0.3549273 ]
# Step: 3 of 10, time-taken: 13.13 seconds
# K_D, P_D (40, 2) (1960, 2)
# torch.Size([36, 1])
# torch.float32
# tensor(-0.3401, grad_fn=<NegBackward0>)
# Epoch 1/150 - Loss: -0.340   lengthscale: 0.100   noise: 0.010
# tensor(-0.4105, grad_fn=<NegBackward0>)
# Epoch 2/150 - Loss: -0.411   lengthscale: 0.110   noise: 0.009
# tensor(-0.4721, grad_fn=<NegBackward0>)
# Epoch 3/150 - Loss: -0.472   lengthscale: 0.121   noise: 0.008
# tensor(-0.5244, grad_fn=<NegBackward0>)
# Epoch 4/150 - Loss: -0.524   lengthscale: 0.133   noise: 0.008
# ...
# Step: 9, Val-Loss: -0.3102
# [0.6315193  0.69874173 0.67283094 ... 0.6224818  0.28492838 0.32271487]
# Step: 9 of 10, time-taken: 12.41 seconds
# K_D, P_D (100, 2) (1900, 2)
# torch.Size([90, 1])
# torch.float32
# tensor(-0.7375, grad_fn=<NegBackward0>)
# Epoch 1/150 - Loss: -0.738   lengthscale: 0.100   noise: 0.010
# tensor(-0.7804, grad_fn=<NegBackward0>)
# Epoch 2/150 - Loss: -0.780   lengthscale: 0.110   noise: 0.009
# tensor(-0.8149, grad_fn=<NegBackward0>)
# Epoch 3/150 - Loss: -0.815   lengthscale: 0.121   noise: 0.008
# tensor(-0.8422, grad_fn=<NegBackward0>)
# Epoch 4/150 - Loss: -0.842   lengthscale: 0.132   noise: 0.007
# tensor(-0.8633, grad_fn=<NegBackward0>)
# Epoch 5/150 - Loss: -0.863   lengthscale: 0.145   noise: 0.007
# tensor(-0.8798, grad_fn=<NegBackward0>)
# Epoch 6/150 - Loss: -0.880   lengthscale: 0.158   noise: 0.006
# tensor(-0.8939, grad_fn=<NegBackward0>)
# Epoch 7/150 - Loss: -0.894   lengthscale: 0.172   noise: 0.006
# tensor(-0.9065, grad_fn=<NegBackward0>)
# Epoch 8/150 - Loss: -0.907   lengthscale: 0.187   noise: 0.006
# tensor(-0.9182, grad_fn=<NegBackward0>)
# Epoch 9/150 - Loss: -0.918   lengthscale: 0.204   noise: 0.005
# tensor(-0.9285, grad_fn=<NegBackward0>)
# Epoch 10/150 - Loss: -0.928   lengthscale: 0.222   noise: 0.005
# tensor(-0.9363, grad_fn=<NegBackward0>)
# Epoch 11/150 - Loss: -0.936   lengthscale: 0.241   noise: 0.005
# tensor(-0.9394, grad_fn=<NegBackward0>)
# Epoch 12/150 - Loss: -0.939   lengthscale: 0.259   noise: 0.005
# tensor(-0.9358, grad_fn=<NegBackward0>)
# Epoch 13/150 - Loss: -0.936   lengthscale: 0.276   noise: 0.006
# tensor(-0.9287, grad_fn=<NegBackward0>)
# Epoch 14/150 - Loss: -0.929   lengthscale: 0.288   noise: 0.006
# tensor(-0.9248, grad_fn=<NegBackward0>)
# Epoch 15/150 - Loss: -0.925   lengthscale: 0.293   noise: 0.006
# tensor(-0.9266, grad_fn=<NegBackward0>)
# Epoch 16/150 - Loss: -0.927   lengthscale: 0.292   noise: 0.006
# tensor(-0.9323, grad_fn=<NegBackward0>)
# Epoch 17/150 - Loss: -0.932   lengthscale: 0.286   noise: 0.006
# tensor(-0.9388, grad_fn=<NegBackward0>)
# Epoch 18/150 - Loss: -0.939   lengthscale: 0.276   noise: 0.007
# tensor(-0.9441, grad_fn=<NegBackward0>)
# Epoch 19/150 - Loss: -0.944   lengthscale: 0.266   noise: 0.007
# tensor(-0.9474, grad_fn=<NegBackward0>)
# Epoch 20/150 - Loss: -0.947   lengthscale: 0.255   noise: 0.007
# tensor(-0.9490, grad_fn=<NegBackward0>)
# Epoch 21/150 - Loss: -0.949   lengthscale: 0.244   noise: 0.007
# tensor(-0.9495, grad_fn=<NegBackward0>)
# Epoch 22/150 - Loss: -0.949   lengthscale: 0.235   noise: 0.007
# tensor(-0.9496, grad_fn=<NegBackward0>)
# Epoch 23/150 - Loss: -0.950   lengthscale: 0.226   noise: 0.007
# tensor(-0.9496, grad_fn=<NegBackward0>)
# Epoch 24/150 - Loss: -0.950   lengthscale: 0.219   noise: 0.007
# tensor(-0.9499, grad_fn=<NegBackward0>)
# Epoch 25/150 - Loss: -0.950   lengthscale: 0.214   noise: 0.007
# tensor(-0.9503, grad_fn=<NegBackward0>)
# Epoch 26/150 - Loss: -0.950   lengthscale: 0.209   noise: 0.007
# tensor(-0.9508, grad_fn=<NegBackward0>)
# Epoch 27/150 - Loss: -0.951   lengthscale: 0.206   noise: 0.007
# tensor(-0.9515, grad_fn=<NegBackward0>)
# Epoch 28/150 - Loss: -0.951   lengthscale: 0.204   noise: 0.006
# tensor(-0.9523, grad_fn=<NegBackward0>)
# Epoch 29/150 - Loss: -0.952   lengthscale: 0.203   noise: 0.006
# tensor(-0.9533, grad_fn=<NegBackward0>)
# Epoch 30/150 - Loss: -0.953   lengthscale: 0.203   noise: 0.006
# tensor(-0.9545, grad_fn=<NegBackward0>)
# Epoch 31/150 - Loss: -0.955   lengthscale: 0.204   noise: 0.006
# tensor(-0.9560, grad_fn=<NegBackward0>)
# Epoch 32/150 - Loss: -0.956   lengthscale: 0.205   noise: 0.006
# tensor(-0.9575, grad_fn=<NegBackward0>)
# Epoch 33/150 - Loss: -0.957   lengthscale: 0.207   noise: 0.006
# tensor(-0.9589, grad_fn=<NegBackward0>)
# Epoch 34/150 - Loss: -0.959   lengthscale: 0.209   noise: 0.006
# tensor(-0.9600, grad_fn=<NegBackward0>)
# Epoch 35/150 - Loss: -0.960   lengthscale: 0.212   noise: 0.006
# tensor(-0.9608, grad_fn=<NegBackward0>)
# Epoch 36/150 - Loss: -0.961   lengthscale: 0.214   noise: 0.006
# tensor(-0.9613, grad_fn=<NegBackward0>)
# Epoch 37/150 - Loss: -0.961   lengthscale: 0.216   noise: 0.006
# tensor(-0.9616, grad_fn=<NegBackward0>)
# Epoch 38/150 - Loss: -0.962   lengthscale: 0.218   noise: 0.006
# tensor(-0.9616, grad_fn=<NegBackward0>)
# Epoch 39/150 - Loss: -0.962   lengthscale: 0.219   noise: 0.006
# tensor(-0.9615, grad_fn=<NegBackward0>)
# Epoch 40/150 - Loss: -0.962   lengthscale: 0.219   noise: 0.006
# tensor(-0.9615, grad_fn=<NegBackward0>)
# Epoch 41/150 - Loss: -0.961   lengthscale: 0.219   noise: 0.006
# tensor(-0.9615, grad_fn=<NegBackward0>)
# Epoch 42/150 - Loss: -0.962   lengthscale: 0.218   noise: 0.006
# tensor(-0.9619, grad_fn=<NegBackward0>)
# Epoch 43/150 - Loss: -0.962   lengthscale: 0.216   noise: 0.007
# tensor(-0.9624, grad_fn=<NegBackward0>)
# Epoch 44/150 - Loss: -0.962   lengthscale: 0.213   noise: 0.007
# tensor(-0.9630, grad_fn=<NegBackward0>)
# Epoch 45/150 - Loss: -0.963   lengthscale: 0.210   noise: 0.007
# tensor(-0.9635, grad_fn=<NegBackward0>)
# Epoch 46/150 - Loss: -0.963   lengthscale: 0.207   noise: 0.006
# tensor(-0.9639, grad_fn=<NegBackward0>)
# Epoch 47/150 - Loss: -0.964   lengthscale: 0.203   noise: 0.006
# tensor(-0.9642, grad_fn=<NegBackward0>)
# Epoch 48/150 - Loss: -0.964   lengthscale: 0.200   noise: 0.006
# tensor(-0.9645, grad_fn=<NegBackward0>)
# Epoch 49/150 - Loss: -0.964   lengthscale: 0.197   noise: 0.006
# tensor(-0.9645, grad_fn=<NegBackward0>)
# Epoch 50/150 - Loss: -0.965   lengthscale: 0.194   noise: 0.006
# tensor(-0.9645, grad_fn=<NegBackward0>)
# Epoch 51/150 - Loss: -0.964   lengthscale: 0.191   noise: 0.006
# tensor(-0.9644, grad_fn=<NegBackward0>)
# Epoch 52/150 - Loss: -0.964   lengthscale: 0.189   noise: 0.006
# tensor(-0.9644, grad_fn=<NegBackward0>)
# Epoch 53/150 - Loss: -0.964   lengthscale: 0.187   noise: 0.006
# tensor(-0.9644, grad_fn=<NegBackward0>)
# Epoch 54/150 - Loss: -0.964   lengthscale: 0.186   noise: 0.006
# tensor(-0.9644, grad_fn=<NegBackward0>)
# Epoch 55/150 - Loss: -0.964   lengthscale: 0.185   noise: 0.006
# tensor(-0.9645, grad_fn=<NegBackward0>)
# Epoch 56/150 - Loss: -0.965   lengthscale: 0.184   noise: 0.006
# tensor(-0.9646, grad_fn=<NegBackward0>)
# Epoch 57/150 - Loss: -0.965   lengthscale: 0.184   noise: 0.006
# tensor(-0.9647, grad_fn=<NegBackward0>)
# Epoch 58/150 - Loss: -0.965   lengthscale: 0.184   noise: 0.006
# tensor(-0.9648, grad_fn=<NegBackward0>)
# Epoch 59/150 - Loss: -0.965   lengthscale: 0.184   noise: 0.006
# tensor(-0.9648, grad_fn=<NegBackward0>)
# Epoch 60/150 - Loss: -0.965   lengthscale: 0.184   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 61/150 - Loss: -0.965   lengthscale: 0.185   noise: 0.006
# tensor(-0.9648, grad_fn=<NegBackward0>)
# Epoch 62/150 - Loss: -0.965   lengthscale: 0.185   noise: 0.006
# tensor(-0.9648, grad_fn=<NegBackward0>)
# Epoch 63/150 - Loss: -0.965   lengthscale: 0.186   noise: 0.006
# tensor(-0.9648, grad_fn=<NegBackward0>)
# Epoch 64/150 - Loss: -0.965   lengthscale: 0.186   noise: 0.006
# tensor(-0.9648, grad_fn=<NegBackward0>)
# Epoch 65/150 - Loss: -0.965   lengthscale: 0.186   noise: 0.006
# tensor(-0.9647, grad_fn=<NegBackward0>)
# Epoch 66/150 - Loss: -0.965   lengthscale: 0.186   noise: 0.006
# tensor(-0.9647, grad_fn=<NegBackward0>)
# Epoch 67/150 - Loss: -0.965   lengthscale: 0.186   noise: 0.006
# tensor(-0.9647, grad_fn=<NegBackward0>)
# Epoch 68/150 - Loss: -0.965   lengthscale: 0.186   noise: 0.006
# tensor(-0.9647, grad_fn=<NegBackward0>)
# Epoch 69/150 - Loss: -0.965   lengthscale: 0.186   noise: 0.006
# tensor(-0.9648, grad_fn=<NegBackward0>)
# Epoch 70/150 - Loss: -0.965   lengthscale: 0.185   noise: 0.006
# tensor(-0.9648, grad_fn=<NegBackward0>)
# Epoch 71/150 - Loss: -0.965   lengthscale: 0.185   noise: 0.006
# tensor(-0.9648, grad_fn=<NegBackward0>)
# Epoch 72/150 - Loss: -0.965   lengthscale: 0.184   noise: 0.006
# tensor(-0.9648, grad_fn=<NegBackward0>)
# Epoch 73/150 - Loss: -0.965   lengthscale: 0.184   noise: 0.006
# tensor(-0.9648, grad_fn=<NegBackward0>)
# Epoch 74/150 - Loss: -0.965   lengthscale: 0.184   noise: 0.006
# tensor(-0.9648, grad_fn=<NegBackward0>)
# Epoch 75/150 - Loss: -0.965   lengthscale: 0.183   noise: 0.006
# tensor(-0.9648, grad_fn=<NegBackward0>)
# Epoch 76/150 - Loss: -0.965   lengthscale: 0.183   noise: 0.006
# tensor(-0.9648, grad_fn=<NegBackward0>)
# Epoch 77/150 - Loss: -0.965   lengthscale: 0.183   noise: 0.006
# tensor(-0.9648, grad_fn=<NegBackward0>)
# Epoch 78/150 - Loss: -0.965   lengthscale: 0.183   noise: 0.006
# tensor(-0.9648, grad_fn=<NegBackward0>)
# Epoch 79/150 - Loss: -0.965   lengthscale: 0.183   noise: 0.006
# tensor(-0.9648, grad_fn=<NegBackward0>)
# Epoch 80/150 - Loss: -0.965   lengthscale: 0.183   noise: 0.006
# tensor(-0.9648, grad_fn=<NegBackward0>)
# Epoch 81/150 - Loss: -0.965   lengthscale: 0.183   noise: 0.006
# tensor(-0.9648, grad_fn=<NegBackward0>)
# Epoch 82/150 - Loss: -0.965   lengthscale: 0.183   noise: 0.006
# tensor(-0.9648, grad_fn=<NegBackward0>)
# Epoch 83/150 - Loss: -0.965   lengthscale: 0.184   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 84/150 - Loss: -0.965   lengthscale: 0.184   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 85/150 - Loss: -0.965   lengthscale: 0.185   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 86/150 - Loss: -0.965   lengthscale: 0.185   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 87/150 - Loss: -0.965   lengthscale: 0.186   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 88/150 - Loss: -0.965   lengthscale: 0.186   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 89/150 - Loss: -0.965   lengthscale: 0.186   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 90/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 91/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 92/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 93/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 94/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 95/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 96/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 97/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 98/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 99/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 100/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 101/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 102/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 103/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 104/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 105/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 106/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 107/150 - Loss: -0.965   lengthscale: 0.188   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 108/150 - Loss: -0.965   lengthscale: 0.188   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 109/150 - Loss: -0.965   lengthscale: 0.188   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 110/150 - Loss: -0.965   lengthscale: 0.188   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 111/150 - Loss: -0.965   lengthscale: 0.188   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 112/150 - Loss: -0.965   lengthscale: 0.188   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 113/150 - Loss: -0.965   lengthscale: 0.188   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 114/150 - Loss: -0.965   lengthscale: 0.188   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 115/150 - Loss: -0.965   lengthscale: 0.188   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 116/150 - Loss: -0.965   lengthscale: 0.188   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 117/150 - Loss: -0.965   lengthscale: 0.188   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 118/150 - Loss: -0.965   lengthscale: 0.188   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 119/150 - Loss: -0.965   lengthscale: 0.188   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 120/150 - Loss: -0.965   lengthscale: 0.188   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 121/150 - Loss: -0.965   lengthscale: 0.188   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 122/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 123/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 124/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 125/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 126/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 127/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 128/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 129/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 130/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 131/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 132/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 133/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 134/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 135/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 136/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 137/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 138/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 139/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 140/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 141/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 142/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 143/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 144/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 145/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 146/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 147/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 148/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 149/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# tensor(-0.9649, grad_fn=<NegBackward0>)
# Epoch 150/150 - Loss: -0.965   lengthscale: 0.187   noise: 0.006
# Step: 10, Val-Loss: -1.1681
# [0.62169015 0.7057483  0.6722686  ... 0.6108779  0.2687001  0.33515963]
# Step: 10 of 10, time-taken: 12.45 seconds

# %%
def update_data(known_data, pool_data, selected_indices): # 5. Update the known and pool data
        known_data = np.append(known_data, pool_data[selected_indices], axis=0)
        pool_data = np.delete(pool_data, selected_indices, axis=0)
        return known_data, pool_data

# %%
preds[0].mean.numpy()
# Out:
# array(-0.926515, dtype=float32)

# %%
len(preds.stddev)
# Out:
# 1900

# %%
plt.figure(figsize=(20, 6))  # Set the figure size to be wider
plt.plot(preds.stddev.numpy())
plt.xlabel('Data Point')
plt.ylabel('Standard Deviation')
plt.title('Standard Deviation Plot')
plt.show()

# %%
count = len(preds.stddev[preds.stddev > 0.4])
print(count)
count = len(preds.stddev[preds.stddev > 0.39])
print(count)
count = len(preds.stddev[preds.stddev > 0.38])
print(count)
count = len(preds.stddev[preds.stddev > 0.37])
print(count)
# Out:
# 4
# 25
# 53
# 108
