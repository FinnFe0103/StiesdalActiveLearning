# %% [markdown]
# Torch Implementation of GP
#
# Inspired by: https://docs.gpytorch.ai/en/stable/examples/01_Exact_GPs/Simple_GP_Regression.html

# %%
import math
import torch
import gpytorch
from matplotlib import pyplot as plt
import time

from data import Dataprep, update_data, load_data
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns

import pandas as pd


# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
dataset_type='Generated_2000'
sensor='foundation_origin xy FloaterOffset [m]'
samples_per_step=10
validation_size=0.1

# %%
data = Dataprep(dataset_type, sensor, initial_samplesize=samples_per_step)
known_data, pool_data = data.known_data, data.pool_data

# %% [markdown]
# Load Data and Normalize

# %%
# We will use the simplest form of GP model, exact inference
class ExactGPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super(ExactGPModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = gpytorch.means.ConstantMean()

        # Assuming you have an RBFKernel instance named `rbf_kernel`:
        rbf_kernel = gpytorch.kernels.RBFKernel()

        # To set an initial length scale:
        rbf_kernel.lengthscale = 0.1

        # kernel can be changed or combined !
        self.covar_module = gpytorch.kernels.ScaleKernel(rbf_kernel)

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

# initialize likelihood and model
#likelihood = gpytorch.likelihoods.GaussianLikelihood()
#model = ExactGPModel(train_x, train_y, likelihood)

# %%
from torch.optim import Adam

# %%
def init_optimizer(learning_rate,model):
    optimizer = Adam(model.parameters(), lr=learning_rate)
    return optimizer
    
def train_model(step, learning_rate):
    print('K_D, P_D', known_data.shape, pool_data.shape)

    # Split the pool data into train and validation sets
    train, val = train_test_split(known_data, test_size=validation_size)

    X_train = torch.tensor(scaler.fit_transform(train[:, 0].reshape(-1, 1))).to(device)  # Adds an extra dimension to make X_train a 2D tensor
    y_train = torch.tensor(train[:, 1]).to(device)
    
    # Initialize likelihood and model with training data
    likelihood = gpytorch.likelihoods.GaussianLikelihood().to(device)

    # Assuming you have a GaussianLikelihood instance named `likelihood`:
    likelihood = gpytorch.likelihoods.GaussianLikelihood()

    # To set an initial noise level:
    likelihood.noise = 0.01






    model = ExactGPModel(X_train, y_train, likelihood).to(device)
    
    optimizer = init_optimizer(learning_rate,model) # Initialize the optimizer

    model.train()
    likelihood.train()

    mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)
    total_train_loss = 0

    x, y = X_train, y_train

    # Find optimal model hyperparameters
    model.train()
    likelihood.train()

    # Use the adam optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr=0.1)  # Includes GaussianLikelihood parameters

    # "Loss" for GPs - the marginal log likelihood
    mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

    for epoch in range(epochs):
        # Zero gradients from previous iteration
        optimizer.zero_grad()
        # Output from model
        output = model(X_train)
        # Calc loss and backprop gradients
        loss = -mll(output, y_train)
        loss.backward()
        print('Epoch %d/%d - Loss: %.3f   lengthscale: %.3f   noise: %.3f' % (
            epoch +1, epochs, loss.item(),
            model.covar_module.base_kernel.lengthscale.item(),
            model.likelihood.noise.item()
        ))
        optimizer.step()

    preds = evaluate_model(likelihood, model,val, step, mll) # Evaluate the model on the validation set

    return preds

# %%
def evaluate_model(likelihood, model, val, step, mll): # 1: EVALUATE THE MODEL ON THE VALIDATION SET

    X_val = torch.tensor(scaler.fit_transform(val[:, 0].reshape(-1, 1))).to(device)  # Adds an extra dimension to make X_train a 2D tensor
    y_val = torch.tensor(val[:, 1]).to(device)
    x, y = X_val, y_val
    # Get into evaluation (predictive posterior) mode
    model.eval()
    likelihood.eval()

    total_val_loss = 0
    # Make predictions by feeding model through likelihood
    with torch.no_grad(), gpytorch.settings.fast_pred_var():
        test_x = torch.linspace(0, 1, 51)
        observed_pred = likelihood(model(X_val))
        output = model(X_val)
        loss = -mll(output, y_val)
        total_val_loss += loss.item()

    step_val_loss = total_val_loss  # Average loss over batches
    writer.add_scalar('loss/val', step_val_loss, step+1)
    if verbose:
        print('Step: {}, Val-Loss: {:.4f}'.format(step+1, step_val_loss))

    if known_data.shape[1] == 2:
        preds = plot(likelihood, model, step)
    return preds

# %%
def plot(likelihood, model, step, samples=500):
    x_pool = pool_data[:, :-1]
    y_pool = pool_data[:, -1]

    x_selected = known_data[:, :-1]
    y_selected = known_data[:, -1]

    scaler = MinMaxScaler()
    x_pool_scaled = scaler.fit_transform(x_pool)
    x_selected_scaled = scaler.transform(x_selected)
    
    x_pool_torch = torch.tensor(x_pool_scaled) 

    model.eval()
    likelihood.eval()

    # Make predictions by feeding model through likelihood
    with torch.no_grad(), gpytorch.settings.fast_pred_var():
        preds = likelihood(model(x_pool_torch))

    means = preds.mean.numpy()  # calculate the mean of the predictions
    lower, upper = preds.confidence_region()
    stds = preds.stddev.numpy()
    
    # Prepare data for plotting
    #df = pd.DataFrame({'x': x_pool_torch.squeeze(), 'mean': means.squeeze(), 'lower': lower, 'upper': upper})

    dfs = []
    y_vals = [means, means + 2 * stds, means - 2 * stds]

    for i in range(3): #len(y_vals)
        dfs.append(pd.DataFrame({'x': x_pool_torch.squeeze(), 'y': y_vals[i].squeeze()}))
    df = pd.concat(dfs)

    print(means.squeeze())
    
    # Plotting
    fig = plt.figure()
    sns.lineplot(data=df, x="x", y="y")
    plt.scatter(x_pool_scaled, y_pool, c="green", marker="*", alpha=0.1)  # Plot actual y values
    plt.scatter(x_selected_scaled, y_selected, c="red", marker="*", alpha=0.2) # plot train data on top
    plt.title(f'Predictions vs Actual Step {step+1}')
    plt.legend(['Mean prediction', 'Pool data (unseen)', 'Seen data'], fontsize='small')
    plt.close(fig)

    # Log the table figure
    writer.add_figure(f'Prediction vs Actual Table Epoch {step+1}', fig, step+1)

    # Log the table figure
    writer.add_figure(f'Prediction vs Actual Table Epoch {step+1}', fig, step+1)

    return preds

# %%
import random

# %%
def predict(self, x): # 2: PREDICT THE UNCERTAINTY ON THE POOL DATA
        pass

def acquisition_function(n, pool_data=pool_data, known_data=known_data): # 3: DECIDE WHICH SAMPLES TO SELECT FROM THE POOL DATA (USING ACQUISITION FUNCTION)
    selected_indices = random.sample(range(len(pool_data)), n)
    known_data, pool_data = update_data(known_data, pool_data, selected_indices)

    return known_data, pool_data

# %%
data = Dataprep(dataset_type, sensor, initial_samplesize=samples_per_step)
known_data, pool_data = data.known_data, data.pool_data

# %%
from torch.utils.tensorboard import SummaryWriter
import datetime
import os

# %%
steps = 10
learning_rate = 0.01
epochs = 150
verbose=True
current_time = datetime.datetime.now().strftime("%Y%m%d-%H%M%S") # Unique directory based on datetime for each run
log_dir = os.path.join('Models/runs', 'BNN_' + dataset_type  + '_' + current_time)
writer = SummaryWriter(log_dir) 
scaler = MinMaxScaler()

device = torch.device("cpu" if torch.backends.mps.is_available() else "cpu")

# %%
known_data, pool_data = data.known_data, data.pool_data

# %%
# Train the model
for step in range(steps):
    start_step = time.time()
    preds = train_model(step,learning_rate) # Train the model
    print('Step: {} of {}, time-taken: {:.2f} seconds'.format(step+1, steps, time.time() - start_step))
    known_data, pool_data = acquisition_function(samples_per_step, pool_data, known_data) # Select the next samples from the pool
# Out:
# K_D, P_D (10, 2) (1990, 2)
# Epoch 1/150 - Loss: 1.690   lengthscale: 0.100   noise: 0.010
# Epoch 2/150 - Loss: 1.524   lengthscale: 0.091   noise: 0.011
# Epoch 3/150 - Loss: 1.392   lengthscale: 0.083   noise: 0.012
# Epoch 4/150 - Loss: 1.292   lengthscale: 0.075   noise: 0.013
# Epoch 5/150 - Loss: 1.221   lengthscale: 0.068   noise: 0.014
# Epoch 6/150 - Loss: 1.178   lengthscale: 0.062   noise: 0.016
# Epoch 7/150 - Loss: 1.157   lengthscale: 0.057   noise: 0.017
# Epoch 8/150 - Loss: 1.150   lengthscale: 0.053   noise: 0.018
# Epoch 9/150 - Loss: 1.153   lengthscale: 0.049   noise: 0.018
# Epoch 10/150 - Loss: 1.159   lengthscale: 0.046   noise: 0.019
# Epoch 11/150 - Loss: 1.167   lengthscale: 0.043   noise: 0.020
# Epoch 12/150 - Loss: 1.175   lengthscale: 0.042   noise: 0.021
# Epoch 13/150 - Loss: 1.181   lengthscale: 0.040   noise: 0.021
# Epoch 14/150 - Loss: 1.186   lengthscale: 0.039   noise: 0.022
# Epoch 15/150 - Loss: 1.188   lengthscale: 0.038   noise: 0.022
# Epoch 16/150 - Loss: 1.188   lengthscale: 0.037   noise: 0.022
# Epoch 17/150 - Loss: 1.187   lengthscale: 0.037   noise: 0.023
# Epoch 18/150 - Loss: 1.185   lengthscale: 0.037   noise: 0.023
# Epoch 19/150 - Loss: 1.183   lengthscale: 0.036   noise: 0.023
# Epoch 20/150 - Loss: 1.180   lengthscale: 0.036   noise: 0.023
# Epoch 21/150 - Loss: 1.177   lengthscale: 0.037   noise: 0.023
# Epoch 22/150 - Loss: 1.174   lengthscale: 0.037   noise: 0.023
# Epoch 23/150 - Loss: 1.170   lengthscale: 0.037   noise: 0.024
# Epoch 24/150 - Loss: 1.165   lengthscale: 0.038   noise: 0.024
# Epoch 25/150 - Loss: 1.161   lengthscale: 0.038   noise: 0.024
# Epoch 26/150 - Loss: 1.158   lengthscale: 0.039   noise: 0.023
# Epoch 27/150 - Loss: 1.155   lengthscale: 0.040   noise: 0.023
# Epoch 28/150 - Loss: 1.153   lengthscale: 0.041   noise: 0.023
# Epoch 29/150 - Loss: 1.151   lengthscale: 0.042   noise: 0.023
# Epoch 30/150 - Loss: 1.150   lengthscale: 0.042   noise: 0.023
# Epoch 31/150 - Loss: 1.149   lengthscale: 0.043   noise: 0.023
# Epoch 32/150 - Loss: 1.149   lengthscale: 0.044   noise: 0.023
# Epoch 33/150 - Loss: 1.149   lengthscale: 0.045   noise: 0.022
# Epoch 34/150 - Loss: 1.150   lengthscale: 0.046   noise: 0.022
# Epoch 35/150 - Loss: 1.150   lengthscale: 0.047   noise: 0.022
# Epoch 36/150 - Loss: 1.150   lengthscale: 0.047   noise: 0.022
# Epoch 37/150 - Loss: 1.150   lengthscale: 0.048   noise: 0.022
# Epoch 38/150 - Loss: 1.150   lengthscale: 0.048   noise: 0.021
# Epoch 39/150 - Loss: 1.149   lengthscale: 0.049   noise: 0.021
# Epoch 40/150 - Loss: 1.148   lengthscale: 0.049   noise: 0.021
# Epoch 41/150 - Loss: 1.147   lengthscale: 0.049   noise: 0.021
# Epoch 42/150 - Loss: 1.146   lengthscale: 0.049   noise: 0.020
# Epoch 43/150 - Loss: 1.145   lengthscale: 0.049   noise: 0.020
# Epoch 44/150 - Loss: 1.144   lengthscale: 0.049   noise: 0.020
# Epoch 45/150 - Loss: 1.143   lengthscale: 0.049   noise: 0.019
# Epoch 46/150 - Loss: 1.142   lengthscale: 0.049   noise: 0.019
# Epoch 47/150 - Loss: 1.142   lengthscale: 0.048   noise: 0.019
# Epoch 48/150 - Loss: 1.142   lengthscale: 0.048   noise: 0.019
# Epoch 49/150 - Loss: 1.141   lengthscale: 0.048   noise: 0.018
# Epoch 50/150 - Loss: 1.141   lengthscale: 0.048   noise: 0.018
# Epoch 51/150 - Loss: 1.141   lengthscale: 0.048   noise: 0.018
# Epoch 52/150 - Loss: 1.141   lengthscale: 0.048   noise: 0.018
# Epoch 53/150 - Loss: 1.141   lengthscale: 0.048   noise: 0.017
# Epoch 54/150 - Loss: 1.141   lengthscale: 0.048   noise: 0.017
# Epoch 55/150 - Loss: 1.141   lengthscale: 0.048   noise: 0.017
# Epoch 56/150 - Loss: 1.140   lengthscale: 0.048   noise: 0.017
# Epoch 57/150 - Loss: 1.140   lengthscale: 0.048   noise: 0.016
# Epoch 58/150 - Loss: 1.140   lengthscale: 0.048   noise: 0.016
# Epoch 59/150 - Loss: 1.139   lengthscale: 0.048   noise: 0.016
# Epoch 60/150 - Loss: 1.139   lengthscale: 0.048   noise: 0.015
# Epoch 61/150 - Loss: 1.138   lengthscale: 0.048   noise: 0.015
# Epoch 62/150 - Loss: 1.138   lengthscale: 0.048   noise: 0.015
# Epoch 63/150 - Loss: 1.138   lengthscale: 0.048   noise: 0.015
# Epoch 64/150 - Loss: 1.137   lengthscale: 0.048   noise: 0.014
# Epoch 65/150 - Loss: 1.137   lengthscale: 0.048   noise: 0.014
# Epoch 66/150 - Loss: 1.137   lengthscale: 0.048   noise: 0.014
# Epoch 67/150 - Loss: 1.137   lengthscale: 0.048   noise: 0.014
# Epoch 68/150 - Loss: 1.136   lengthscale: 0.048   noise: 0.014
# Epoch 69/150 - Loss: 1.136   lengthscale: 0.048   noise: 0.013
# Epoch 70/150 - Loss: 1.136   lengthscale: 0.048   noise: 0.013
# Epoch 71/150 - Loss: 1.136   lengthscale: 0.048   noise: 0.013
# Epoch 72/150 - Loss: 1.135   lengthscale: 0.048   noise: 0.013
# Epoch 73/150 - Loss: 1.135   lengthscale: 0.048   noise: 0.012
# Epoch 74/150 - Loss: 1.135   lengthscale: 0.047   noise: 0.012
# Epoch 75/150 - Loss: 1.135   lengthscale: 0.047   noise: 0.012
# Epoch 76/150 - Loss: 1.134   lengthscale: 0.047   noise: 0.012
# Epoch 77/150 - Loss: 1.134   lengthscale: 0.047   noise: 0.012
# Epoch 78/150 - Loss: 1.134   lengthscale: 0.047   noise: 0.011
# Epoch 79/150 - Loss: 1.134   lengthscale: 0.047   noise: 0.011
# Epoch 80/150 - Loss: 1.134   lengthscale: 0.047   noise: 0.011
# Epoch 81/150 - Loss: 1.133   lengthscale: 0.047   noise: 0.011
# Epoch 82/150 - Loss: 1.133   lengthscale: 0.047   noise: 0.011
# Epoch 83/150 - Loss: 1.133   lengthscale: 0.047   noise: 0.011
# Epoch 84/150 - Loss: 1.133   lengthscale: 0.047   noise: 0.010
# Epoch 85/150 - Loss: 1.133   lengthscale: 0.047   noise: 0.010
# Epoch 86/150 - Loss: 1.132   lengthscale: 0.047   noise: 0.010
# Epoch 87/150 - Loss: 1.132   lengthscale: 0.047   noise: 0.010
# Epoch 88/150 - Loss: 1.132   lengthscale: 0.047   noise: 0.010
# Epoch 89/150 - Loss: 1.132   lengthscale: 0.047   noise: 0.010
# Epoch 90/150 - Loss: 1.132   lengthscale: 0.047   noise: 0.009
# Epoch 91/150 - Loss: 1.131   lengthscale: 0.047   noise: 0.009
# Epoch 92/150 - Loss: 1.131   lengthscale: 0.047   noise: 0.009
# Epoch 93/150 - Loss: 1.131   lengthscale: 0.047   noise: 0.009
# Epoch 94/150 - Loss: 1.131   lengthscale: 0.047   noise: 0.009
# Epoch 95/150 - Loss: 1.131   lengthscale: 0.047   noise: 0.009
# Epoch 96/150 - Loss: 1.131   lengthscale: 0.047   noise: 0.009
# Epoch 97/150 - Loss: 1.130   lengthscale: 0.047   noise: 0.008
# Epoch 98/150 - Loss: 1.130   lengthscale: 0.047   noise: 0.008
# Epoch 99/150 - Loss: 1.130   lengthscale: 0.047   noise: 0.008
# Epoch 100/150 - Loss: 1.130   lengthscale: 0.047   noise: 0.008
# Epoch 101/150 - Loss: 1.130   lengthscale: 0.047   noise: 0.008
# Epoch 102/150 - Loss: 1.130   lengthscale: 0.047   noise: 0.008
# Epoch 103/150 - Loss: 1.129   lengthscale: 0.047   noise: 0.008
# Epoch 104/150 - Loss: 1.129   lengthscale: 0.047   noise: 0.008
# Epoch 105/150 - Loss: 1.129   lengthscale: 0.047   noise: 0.008
# Epoch 106/150 - Loss: 1.129   lengthscale: 0.047   noise: 0.007
# Epoch 107/150 - Loss: 1.129   lengthscale: 0.047   noise: 0.007
# Epoch 108/150 - Loss: 1.129   lengthscale: 0.047   noise: 0.007
# Epoch 109/150 - Loss: 1.129   lengthscale: 0.047   noise: 0.007
# Epoch 110/150 - Loss: 1.128   lengthscale: 0.047   noise: 0.007
# Epoch 111/150 - Loss: 1.128   lengthscale: 0.047   noise: 0.007
# Epoch 112/150 - Loss: 1.128   lengthscale: 0.047   noise: 0.007
# Epoch 113/150 - Loss: 1.128   lengthscale: 0.047   noise: 0.007
# Epoch 114/150 - Loss: 1.128   lengthscale: 0.047   noise: 0.007
# Epoch 115/150 - Loss: 1.128   lengthscale: 0.047   noise: 0.007
# Epoch 116/150 - Loss: 1.128   lengthscale: 0.047   noise: 0.006
# Epoch 117/150 - Loss: 1.128   lengthscale: 0.047   noise: 0.006
# Epoch 118/150 - Loss: 1.127   lengthscale: 0.047   noise: 0.006
# Epoch 119/150 - Loss: 1.127   lengthscale: 0.047   noise: 0.006
# Epoch 120/150 - Loss: 1.127   lengthscale: 0.047   noise: 0.006
# Epoch 121/150 - Loss: 1.127   lengthscale: 0.047   noise: 0.006
# Epoch 122/150 - Loss: 1.127   lengthscale: 0.047   noise: 0.006
# Epoch 123/150 - Loss: 1.127   lengthscale: 0.047   noise: 0.006
# Epoch 124/150 - Loss: 1.127   lengthscale: 0.047   noise: 0.006
# Epoch 125/150 - Loss: 1.127   lengthscale: 0.047   noise: 0.006
# Epoch 126/150 - Loss: 1.127   lengthscale: 0.047   noise: 0.006
# Epoch 127/150 - Loss: 1.127   lengthscale: 0.047   noise: 0.006
# Epoch 128/150 - Loss: 1.126   lengthscale: 0.047   noise: 0.006
# Epoch 129/150 - Loss: 1.126   lengthscale: 0.047   noise: 0.005
# Epoch 130/150 - Loss: 1.126   lengthscale: 0.047   noise: 0.005
# Epoch 131/150 - Loss: 1.126   lengthscale: 0.047   noise: 0.005
# Epoch 132/150 - Loss: 1.126   lengthscale: 0.047   noise: 0.005
# Epoch 133/150 - Loss: 1.126   lengthscale: 0.047   noise: 0.005
# Epoch 134/150 - Loss: 1.126   lengthscale: 0.047   noise: 0.005
# Epoch 135/150 - Loss: 1.126   lengthscale: 0.047   noise: 0.005
# Epoch 136/150 - Loss: 1.126   lengthscale: 0.047   noise: 0.005
# Epoch 137/150 - Loss: 1.126   lengthscale: 0.047   noise: 0.005
# Epoch 138/150 - Loss: 1.126   lengthscale: 0.047   noise: 0.005
# Epoch 139/150 - Loss: 1.125   lengthscale: 0.047   noise: 0.005
# Epoch 140/150 - Loss: 1.125   lengthscale: 0.047   noise: 0.005
# Epoch 141/150 - Loss: 1.125   lengthscale: 0.047   noise: 0.005
# Epoch 142/150 - Loss: 1.125   lengthscale: 0.047   noise: 0.005
# Epoch 143/150 - Loss: 1.125   lengthscale: 0.047   noise: 0.005
# Epoch 144/150 - Loss: 1.125   lengthscale: 0.047   noise: 0.005
# Epoch 145/150 - Loss: 1.125   lengthscale: 0.047   noise: 0.005
# Epoch 146/150 - Loss: 1.125   lengthscale: 0.047   noise: 0.004
# Epoch 147/150 - Loss: 1.125   lengthscale: 0.047   noise: 0.004
# Epoch 148/150 - Loss: 1.125   lengthscale: 0.047   noise: 0.004
# Epoch 149/150 - Loss: 1.125   lengthscale: 0.047   noise: 0.004
# Epoch 150/150 - Loss: 1.125   lengthscale: 0.047   noise: 0.004
# Step: 1, Val-Loss: 194.9061
# [-0.43888497 -0.30816287  0.8810768  ... -0.8199736   0.9379991
#   0.23810832]
# Step: 1 of 10, time-taken: 13.03 seconds
# K_D, P_D (20, 2) (1980, 2)
# Epoch 1/150 - Loss: 4.321   lengthscale: 0.100   noise: 0.010
# Epoch 2/150 - Loss: 3.932   lengthscale: 0.110   noise: 0.011
# Epoch 3/150 - Loss: 3.595   lengthscale: 0.118   noise: 0.012
# Epoch 4/150 - Loss: 3.289   lengthscale: 0.119   noise: 0.013
# Epoch 5/150 - Loss: 3.013   lengthscale: 0.117   noise: 0.015
# Epoch 6/150 - Loss: 2.772   lengthscale: 0.114   noise: 0.016
# Epoch 7/150 - Loss: 2.559   lengthscale: 0.113   noise: 0.018
# Epoch 8/150 - Loss: 2.368   lengthscale: 0.114   noise: 0.020
# Epoch 9/150 - Loss: 2.199   lengthscale: 0.117   noise: 0.021
# Epoch 10/150 - Loss: 2.048   lengthscale: 0.120   noise: 0.023
# Epoch 11/150 - Loss: 1.917   lengthscale: 0.123   noise: 0.026
# Epoch 12/150 - Loss: 1.801   lengthscale: 0.126   noise: 0.028
# Epoch 13/150 - Loss: 1.699   lengthscale: 0.127   noise: 0.030
# Epoch 14/150 - Loss: 1.609   lengthscale: 0.127   noise: 0.033
# Epoch 15/150 - Loss: 1.529   lengthscale: 0.126   noise: 0.035
# Epoch 16/150 - Loss: 1.458   lengthscale: 0.125   noise: 0.038
# Epoch 17/150 - Loss: 1.397   lengthscale: 0.124   noise: 0.041
# Epoch 18/150 - Loss: 1.343   lengthscale: 0.123   noise: 0.044
# Epoch 19/150 - Loss: 1.296   lengthscale: 0.122   noise: 0.047
# Epoch 20/150 - Loss: 1.254   lengthscale: 0.123   noise: 0.050
# Epoch 21/150 - Loss: 1.217   lengthscale: 0.124   noise: 0.053
# Epoch 22/150 - Loss: 1.185   lengthscale: 0.125   noise: 0.056
# Epoch 23/150 - Loss: 1.156   lengthscale: 0.126   noise: 0.059
# Epoch 24/150 - Loss: 1.132   lengthscale: 0.128   noise: 0.062
# Epoch 25/150 - Loss: 1.110   lengthscale: 0.129   noise: 0.066
# Epoch 26/150 - Loss: 1.091   lengthscale: 0.130   noise: 0.069
# Epoch 27/150 - Loss: 1.073   lengthscale: 0.130   noise: 0.072
# Epoch 28/150 - Loss: 1.058   lengthscale: 0.130   noise: 0.075
# Epoch 29/150 - Loss: 1.045   lengthscale: 0.130   noise: 0.079
# Epoch 30/150 - Loss: 1.034   lengthscale: 0.130   noise: 0.082
# Epoch 31/150 - Loss: 1.023   lengthscale: 0.130   noise: 0.085
# Epoch 32/150 - Loss: 1.014   lengthscale: 0.130   noise: 0.088
# Epoch 33/150 - Loss: 1.006   lengthscale: 0.131   noise: 0.091
# Epoch 34/150 - Loss: 0.999   lengthscale: 0.132   noise: 0.094
# Epoch 35/150 - Loss: 0.993   lengthscale: 0.132   noise: 0.097
# Epoch 36/150 - Loss: 0.988   lengthscale: 0.133   noise: 0.100
# Epoch 37/150 - Loss: 0.983   lengthscale: 0.134   noise: 0.103
# Epoch 38/150 - Loss: 0.979   lengthscale: 0.135   noise: 0.105
# Epoch 39/150 - Loss: 0.975   lengthscale: 0.136   noise: 0.108
# Epoch 40/150 - Loss: 0.972   lengthscale: 0.136   noise: 0.110
# Epoch 41/150 - Loss: 0.969   lengthscale: 0.136   noise: 0.113
# Epoch 42/150 - Loss: 0.966   lengthscale: 0.136   noise: 0.115
# Epoch 43/150 - Loss: 0.964   lengthscale: 0.136   noise: 0.118
# Epoch 44/150 - Loss: 0.962   lengthscale: 0.136   noise: 0.120
# Epoch 45/150 - Loss: 0.960   lengthscale: 0.136   noise: 0.122
# Epoch 46/150 - Loss: 0.959   lengthscale: 0.135   noise: 0.124
# Epoch 47/150 - Loss: 0.957   lengthscale: 0.135   noise: 0.126
# Epoch 48/150 - Loss: 0.956   lengthscale: 0.135   noise: 0.128
# Epoch 49/150 - Loss: 0.955   lengthscale: 0.135   noise: 0.129
# Epoch 50/150 - Loss: 0.954   lengthscale: 0.135   noise: 0.131
# Epoch 51/150 - Loss: 0.953   lengthscale: 0.135   noise: 0.133
# Epoch 52/150 - Loss: 0.952   lengthscale: 0.135   noise: 0.134
# Epoch 53/150 - Loss: 0.952   lengthscale: 0.136   noise: 0.136
# Epoch 54/150 - Loss: 0.951   lengthscale: 0.136   noise: 0.137
# Epoch 55/150 - Loss: 0.951   lengthscale: 0.136   noise: 0.139
# Epoch 56/150 - Loss: 0.950   lengthscale: 0.136   noise: 0.140
# Epoch 57/150 - Loss: 0.950   lengthscale: 0.136   noise: 0.141
# Epoch 58/150 - Loss: 0.950   lengthscale: 0.136   noise: 0.142
# Epoch 59/150 - Loss: 0.949   lengthscale: 0.136   noise: 0.143
# Epoch 60/150 - Loss: 0.949   lengthscale: 0.136   noise: 0.145
# Epoch 61/150 - Loss: 0.949   lengthscale: 0.136   noise: 0.146
# Epoch 62/150 - Loss: 0.948   lengthscale: 0.136   noise: 0.147
# Epoch 63/150 - Loss: 0.948   lengthscale: 0.137   noise: 0.147
# Epoch 64/150 - Loss: 0.948   lengthscale: 0.137   noise: 0.148
# Epoch 65/150 - Loss: 0.948   lengthscale: 0.137   noise: 0.149
# Epoch 66/150 - Loss: 0.948   lengthscale: 0.137   noise: 0.150
# Epoch 67/150 - Loss: 0.948   lengthscale: 0.137   noise: 0.151
# Epoch 68/150 - Loss: 0.948   lengthscale: 0.137   noise: 0.151
# Epoch 69/150 - Loss: 0.948   lengthscale: 0.137   noise: 0.152
# Epoch 70/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.153
# Epoch 71/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.153
# Epoch 72/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.154
# Epoch 73/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.154
# Epoch 74/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.155
# Epoch 75/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.155
# Epoch 76/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.156
# Epoch 77/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.156
# Epoch 78/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.156
# Epoch 79/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.157
# Epoch 80/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.157
# Epoch 81/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.158
# Epoch 82/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.158
# Epoch 83/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.158
# Epoch 84/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.158
# Epoch 85/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.159
# Epoch 86/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.159
# Epoch 87/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.159
# Epoch 88/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.159
# Epoch 89/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.160
# Epoch 90/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.160
# Epoch 91/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.160
# Epoch 92/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.160
# Epoch 93/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.160
# Epoch 94/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.160
# Epoch 95/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.161
# Epoch 96/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.161
# Epoch 97/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.161
# Epoch 98/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.161
# Epoch 99/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.161
# Epoch 100/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.161
# Epoch 101/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.161
# Epoch 102/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.161
# Epoch 103/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.161
# Epoch 104/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.161
# Epoch 105/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 106/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 107/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 108/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 109/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 110/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 111/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 112/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 113/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 114/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 115/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 116/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 117/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 118/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 119/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 120/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 121/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 122/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 123/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 124/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 125/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 126/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 127/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 128/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 129/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 130/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 131/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 132/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 133/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 134/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 135/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 136/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 137/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 138/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 139/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 140/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 141/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 142/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 143/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 144/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 145/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 146/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 147/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 148/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 149/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Epoch 150/150 - Loss: 0.947   lengthscale: 0.137   noise: 0.162
# Step: 2, Val-Loss: 2.5849
# [-0.7596241  -0.0888904   0.97760046 ... -0.8458798   1.0032991
#  -0.6710258 ]
# Step: 2 of 10, time-taken: 12.55 seconds
# K_D, P_D (30, 2) (1970, 2)
# Epoch 1/150 - Loss: 3.501   lengthscale: 0.100   noise: 0.010
# Epoch 2/150 - Loss: 3.162   lengthscale: 0.110   noise: 0.011
# Epoch 3/150 - Loss: 2.851   lengthscale: 0.119   noise: 0.012
# Epoch 4/150 - Loss: 2.575   lengthscale: 0.129   noise: 0.013
# Epoch 5/150 - Loss: 2.338   lengthscale: 0.140   noise: 0.015
# Epoch 6/150 - Loss: 2.127   lengthscale: 0.142   noise: 0.016
# Epoch 7/150 - Loss: 1.935   lengthscale: 0.140   noise: 0.018
# Epoch 8/150 - Loss: 1.766   lengthscale: 0.136   noise: 0.020
# Epoch 9/150 - Loss: 1.621   lengthscale: 0.133   noise: 0.021
# Epoch 10/150 - Loss: 1.496   lengthscale: 0.130   noise: 0.023
# Epoch 11/150 - Loss: 1.385   lengthscale: 0.130   noise: 0.026
# Epoch 12/150 - Loss: 1.288   lengthscale: 0.132   noise: 0.028
# Epoch 13/150 - Loss: 1.202   lengthscale: 0.135   noise: 0.030
# Epoch 14/150 - Loss: 1.128   lengthscale: 0.139   noise: 0.033
# Epoch 15/150 - Loss: 1.065   lengthscale: 0.144   noise: 0.035
# Epoch 16/150 - Loss: 1.010   lengthscale: 0.147   noise: 0.038
# Epoch 17/150 - Loss: 0.963   lengthscale: 0.149   noise: 0.040
# Epoch 18/150 - Loss: 0.923   lengthscale: 0.150   noise: 0.043
# Epoch 19/150 - Loss: 0.887   lengthscale: 0.150   noise: 0.046
# Epoch 20/150 - Loss: 0.856   lengthscale: 0.148   noise: 0.049
# Epoch 21/150 - Loss: 0.830   lengthscale: 0.146   noise: 0.052
# Epoch 22/150 - Loss: 0.807   lengthscale: 0.145   noise: 0.055
# Epoch 23/150 - Loss: 0.788   lengthscale: 0.143   noise: 0.058
# Epoch 24/150 - Loss: 0.772   lengthscale: 0.142   noise: 0.061
# Epoch 25/150 - Loss: 0.758   lengthscale: 0.142   noise: 0.064
# Epoch 26/150 - Loss: 0.746   lengthscale: 0.142   noise: 0.067
# Epoch 27/150 - Loss: 0.735   lengthscale: 0.143   noise: 0.070
# Epoch 28/150 - Loss: 0.727   lengthscale: 0.144   noise: 0.073
# Epoch 29/150 - Loss: 0.719   lengthscale: 0.146   noise: 0.075
# Epoch 30/150 - Loss: 0.713   lengthscale: 0.147   noise: 0.078
# Epoch 31/150 - Loss: 0.708   lengthscale: 0.148   noise: 0.081
# Epoch 32/150 - Loss: 0.704   lengthscale: 0.148   noise: 0.083
# Epoch 33/150 - Loss: 0.700   lengthscale: 0.148   noise: 0.086
# Epoch 34/150 - Loss: 0.697   lengthscale: 0.147   noise: 0.088
# Epoch 35/150 - Loss: 0.694   lengthscale: 0.146   noise: 0.090
# Epoch 36/150 - Loss: 0.692   lengthscale: 0.145   noise: 0.093
# Epoch 37/150 - Loss: 0.690   lengthscale: 0.144   noise: 0.095
# Epoch 38/150 - Loss: 0.689   lengthscale: 0.143   noise: 0.097
# Epoch 39/150 - Loss: 0.688   lengthscale: 0.143   noise: 0.099
# Epoch 40/150 - Loss: 0.687   lengthscale: 0.143   noise: 0.100
# Epoch 41/150 - Loss: 0.686   lengthscale: 0.143   noise: 0.102
# Epoch 42/150 - Loss: 0.686   lengthscale: 0.143   noise: 0.104
# Epoch 43/150 - Loss: 0.685   lengthscale: 0.144   noise: 0.105
# Epoch 44/150 - Loss: 0.685   lengthscale: 0.145   noise: 0.107
# Epoch 45/150 - Loss: 0.685   lengthscale: 0.146   noise: 0.108
# Epoch 46/150 - Loss: 0.685   lengthscale: 0.147   noise: 0.109
# Epoch 47/150 - Loss: 0.684   lengthscale: 0.147   noise: 0.110
# Epoch 48/150 - Loss: 0.684   lengthscale: 0.147   noise: 0.111
# Epoch 49/150 - Loss: 0.684   lengthscale: 0.147   noise: 0.112
# Epoch 50/150 - Loss: 0.684   lengthscale: 0.147   noise: 0.113
# Epoch 51/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.114
# Epoch 52/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.115
# Epoch 53/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.115
# Epoch 54/150 - Loss: 0.684   lengthscale: 0.145   noise: 0.116
# Epoch 55/150 - Loss: 0.685   lengthscale: 0.145   noise: 0.117
# Epoch 56/150 - Loss: 0.685   lengthscale: 0.145   noise: 0.117
# Epoch 57/150 - Loss: 0.685   lengthscale: 0.146   noise: 0.118
# Epoch 58/150 - Loss: 0.685   lengthscale: 0.146   noise: 0.118
# Epoch 59/150 - Loss: 0.685   lengthscale: 0.146   noise: 0.118
# Epoch 60/150 - Loss: 0.685   lengthscale: 0.147   noise: 0.119
# Epoch 61/150 - Loss: 0.685   lengthscale: 0.147   noise: 0.119
# Epoch 62/150 - Loss: 0.685   lengthscale: 0.147   noise: 0.119
# Epoch 63/150 - Loss: 0.685   lengthscale: 0.147   noise: 0.119
# Epoch 64/150 - Loss: 0.685   lengthscale: 0.146   noise: 0.119
# Epoch 65/150 - Loss: 0.685   lengthscale: 0.146   noise: 0.119
# Epoch 66/150 - Loss: 0.685   lengthscale: 0.146   noise: 0.119
# Epoch 67/150 - Loss: 0.685   lengthscale: 0.145   noise: 0.119
# Epoch 68/150 - Loss: 0.685   lengthscale: 0.145   noise: 0.119
# Epoch 69/150 - Loss: 0.685   lengthscale: 0.145   noise: 0.119
# Epoch 70/150 - Loss: 0.685   lengthscale: 0.145   noise: 0.119
# Epoch 71/150 - Loss: 0.685   lengthscale: 0.145   noise: 0.119
# Epoch 72/150 - Loss: 0.685   lengthscale: 0.145   noise: 0.119
# Epoch 73/150 - Loss: 0.685   lengthscale: 0.146   noise: 0.119
# Epoch 74/150 - Loss: 0.685   lengthscale: 0.146   noise: 0.119
# Epoch 75/150 - Loss: 0.685   lengthscale: 0.146   noise: 0.119
# Epoch 76/150 - Loss: 0.685   lengthscale: 0.146   noise: 0.119
# Epoch 77/150 - Loss: 0.685   lengthscale: 0.146   noise: 0.119
# Epoch 78/150 - Loss: 0.685   lengthscale: 0.146   noise: 0.119
# Epoch 79/150 - Loss: 0.685   lengthscale: 0.146   noise: 0.118
# Epoch 80/150 - Loss: 0.685   lengthscale: 0.146   noise: 0.118
# Epoch 81/150 - Loss: 0.685   lengthscale: 0.146   noise: 0.118
# Epoch 82/150 - Loss: 0.685   lengthscale: 0.146   noise: 0.118
# Epoch 83/150 - Loss: 0.685   lengthscale: 0.146   noise: 0.118
# Epoch 84/150 - Loss: 0.685   lengthscale: 0.146   noise: 0.118
# Epoch 85/150 - Loss: 0.685   lengthscale: 0.146   noise: 0.117
# Epoch 86/150 - Loss: 0.685   lengthscale: 0.146   noise: 0.117
# Epoch 87/150 - Loss: 0.685   lengthscale: 0.146   noise: 0.117
# Epoch 88/150 - Loss: 0.685   lengthscale: 0.146   noise: 0.117
# Epoch 89/150 - Loss: 0.685   lengthscale: 0.146   noise: 0.117
# Epoch 90/150 - Loss: 0.685   lengthscale: 0.146   noise: 0.117
# Epoch 91/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.116
# Epoch 92/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.116
# Epoch 93/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.116
# Epoch 94/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.116
# Epoch 95/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.116
# Epoch 96/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.116
# Epoch 97/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.116
# Epoch 98/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.115
# Epoch 99/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.115
# Epoch 100/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.115
# Epoch 101/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.115
# Epoch 102/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.115
# Epoch 103/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.115
# Epoch 104/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.115
# Epoch 105/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.115
# Epoch 106/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.114
# Epoch 107/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.114
# Epoch 108/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.114
# Epoch 109/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.114
# Epoch 110/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.114
# Epoch 111/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.114
# Epoch 112/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.114
# Epoch 113/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.114
# Epoch 114/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.114
# Epoch 115/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.114
# Epoch 116/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.114
# Epoch 117/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 118/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 119/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 120/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 121/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 122/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 123/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 124/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 125/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 126/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 127/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 128/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 129/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 130/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 131/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 132/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 133/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 134/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 135/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 136/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 137/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 138/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 139/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 140/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 141/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 142/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 143/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 144/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 145/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 146/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 147/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 148/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 149/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Epoch 150/150 - Loss: 0.684   lengthscale: 0.146   noise: 0.113
# Step: 3, Val-Loss: 9.0228
# [-0.8461523   0.45392248  1.041531   ... -0.92064023  1.0641071
#  -0.7038659 ]
# Step: 3 of 10, time-taken: 12.54 seconds
# K_D, P_D (40, 2) (1960, 2)
# Epoch 1/150 - Loss: 3.555   lengthscale: 0.100   noise: 0.010
# Epoch 2/150 - Loss: 3.145   lengthscale: 0.091   noise: 0.011
# Epoch 3/150 - Loss: 2.811   lengthscale: 0.083   noise: 0.012
# Epoch 4/150 - Loss: 2.526   lengthscale: 0.076   noise: 0.013
# Epoch 5/150 - Loss: 2.272   lengthscale: 0.070   noise: 0.015
# Epoch 6/150 - Loss: 2.052   lengthscale: 0.064   noise: 0.016
# Epoch 7/150 - Loss: 1.869   lengthscale: 0.059   noise: 0.018
# Epoch 8/150 - Loss: 1.723   lengthscale: 0.054   noise: 0.019
# Epoch 9/150 - Loss: 1.605   lengthscale: 0.050   noise: 0.021
# Epoch 10/150 - Loss: 1.508   lengthscale: 0.047   noise: 0.023
# Epoch 11/150 - Loss: 1.425   lengthscale: 0.044   noise: 0.025
# Epoch 12/150 - Loss: 1.353   lengthscale: 0.042   noise: 0.027
# Epoch 13/150 - Loss: 1.290   lengthscale: 0.040   noise: 0.029
# Epoch 14/150 - Loss: 1.235   lengthscale: 0.039   noise: 0.032
# Epoch 15/150 - Loss: 1.185   lengthscale: 0.038   noise: 0.034
# Epoch 16/150 - Loss: 1.141   lengthscale: 0.037   noise: 0.036
# Epoch 17/150 - Loss: 1.100   lengthscale: 0.036   noise: 0.039
# Epoch 18/150 - Loss: 1.064   lengthscale: 0.036   noise: 0.041
# Epoch 19/150 - Loss: 1.031   lengthscale: 0.036   noise: 0.044
# Epoch 20/150 - Loss: 1.001   lengthscale: 0.036   noise: 0.046
# Epoch 21/150 - Loss: 0.974   lengthscale: 0.037   noise: 0.049
150 - Loss: 0.668   lengthscale: 0.131   noise: 0.123
# Epoch 103/150 - Loss: 0.668   lengthscale: 0.131   noise: 0.123
# Epoch 104/150 - Loss: 0.668   lengthscale: 0.130   noise: 0.123
# Epoch 105/150 - Loss: 0.668   lengthscale: 0.130   noise: 0.123
# Epoch 106/150 - Loss: 0.668   lengthscale: 0.130   noise: 0.123
# Epoch 107/150 - Loss: 0.668   lengthscale: 0.129   noise: 0.123
# Epoch 108/150 - Loss: 0.668   lengthscale: 0.129   noise: 0.122
# Epoch 109/150 - Loss: 0.668   lengthscale: 0.129   noise: 0.122
# Epoch 110/150 - Loss: 0.668   lengthscale: 0.129   noise: 0.122
# Epoch 111/150 - Loss: 0.668   lengthscale: 0.129   noise: 0.122
# Epoch 112/150 - Loss: 0.668   lengthscale: 0.129   noise: 0.122
# Epoch 113/150 - Loss: 0.668   lengthscale: 0.129   noise: 0.122
# Epoch 114/150 - Loss: 0.668   lengthscale: 0.129   noise: 0.122
# Epoch 115/150 - Loss: 0.668   lengthscale: 0.129   noise: 0.122
# Epoch 116/150 - Loss: 0.668   lengthscale: 0.129   noise: 0.122
# Epoch 117/150 - Loss: 0.668   lengthscale: 0.130   noise: 0.122
# Epoch 118/150 - Loss: 0.668   lengthscale: 0.130   noise: 0.122
# Epoch 119/150 - Loss: 0.668   lengthscale: 0.130   noise: 0.122
# Epoch 120/150 - Loss: 0.668   lengthscale: 0.130   noise: 0.122
# Epoch 121/150 - Loss: 0.668   lengthscale: 0.130   noise: 0.121
# Epoch 122/150 - Loss: 0.668   lengthscale: 0.130   noise: 0.121
# Epoch 123/150 - Loss: 0.668   lengthscale: 0.131   noise: 0.121
# Epoch 124/150 - Loss: 0.668   lengthscale: 0.131   noise: 0.121
# Epoch 125/150 - Loss: 0.668   lengthscale: 0.131   noise: 0.121
# Epoch 126/150 - Loss: 0.668   lengthscale: 0.131   noise: 0.121
# Epoch 127/150 - Loss: 0.668   lengthscale: 0.131   noise: 0.121
# Epoch 128/150 - Loss: 0.668   lengthscale: 0.131   noise: 0.121
# Epoch 129/150 - Loss: 0.668   lengthscale: 0.131   noise: 0.121
# Epoch 130/150 - Loss: 0.668   lengthscale: 0.131   noise: 0.121
# Epoch 131/150 - Loss: 0.668   lengthscale: 0.131   noise: 0.121
# Epoch 132/150 - Loss: 0.668   lengthscale: 0.131   noise: 0.121
# Epoch 133/150 - Loss: 0.668   lengthscale: 0.131   noise: 0.121
# Epoch 134/150 - Loss: 0.668   lengthscale: 0.131   noise: 0.121
# Epoch 135/150 - Loss: 0.668   lengthscale: 0.131   noise: 0.121
# Epoch 136/150 - Loss: 0.668   lengthscale: 0.131   noise: 0.121
# Epoch 137/150 - Loss: 0.668   lengthscale: 0.131   noise: 0.121
# Epoch 138/150 - Loss: 0.668   lengthscale: 0.131   noise: 0.121
# Epoch 139/150 - Loss: 0.668   lengthscale: 0.131   noise: 0.121
# Epoch 140/150 - Loss: 0.668   lengthscale: 0.131   noise: 0.121
# Epoch 141/150 - Loss: 0.668   lengthscale: 0.131   noise: 0.121
# Epoch 142/150 - Loss: 0.668   lengthscale: 0.131   noise: 0.121
# Epoch 143/150 - Loss: 0.668   lengthscale: 0.131   noise: 0.121
# Epoch 144/150 - Loss: 0.668   lengthscale: 0.131   noise: 0.121
# Epoch 145/150 - Loss: 0.668   lengthscale: 0.131   noise: 0.121
# Epoch 146/150 - Loss: 0.668   lengthscale: 0.131   noise: 0.121
# Epoch 147/150 - Loss: 0.668   lengthscale: 0.131   noise: 0.121
# Epoch 148/150 - Loss: 0.668   lengthscale: 0.131   noise: 0.121
# Epoch 149/150 - Loss: 0.668   lengthscale: 0.131   noise: 0.121
# Epoch 150/150 - Loss: 0.668   lengthscale: 0.131   noise: 0.121
# Step: 4, Val-Loss: 0.6386
# [-0.8443968   0.41439077  1.0599495  ... -0.9061014   1.086296
#  -0.69749016]
# Step: 4 of 10, time-taken: 12.55 seconds
# K_D, P_D (50, 2) (1950, 2)
# Epoch 1/150 - Loss: 3.028   lengthscale: 0.100   noise: 0.010
# Epoch 2/150 - Loss: 2.681   lengthscale: 0.091   noise: 0.011
# Epoch 3/150 - Loss: 2.392   lengthscale: 0.083   noise: 0.012
# Epoch 4/150 - Loss: 2.150   lengthscale: 0.076   noise: 0.013
# Epoch 5/150 - Loss: 1.942   lengthscale: 0.070   noise: 0.015
# Epoch 6/150 - Loss: 1.761   lengthscale: 0.066   noise: 0.016
# Epoch 7/150 - Loss: 1.605   lengthscale: 0.062   noise: 0.018
# Epoch 8/150 - Loss: 1.471   lengthscale: 0.058   noise: 0.019
# Epoch 9/150 - Loss: 1.356   lengthscale: 0.055   noise: 0.021
# Epoch 10/150 - Loss: 1.259   lengthscale: 0.052   noise: 0.023
# Epoch 11/150 - Loss: 1.176   lengthscale: 0.050   noise: 0.025
# Epoch 12/150 - Loss: 1.105   lengthscale: 0.048   noise: 0.027
# Epoch 13/150 - Loss: 1.045   lengthscale: 0.047   noise: 0.030
# Epoch 14/150 - Loss: 0.994   lengthscale: 0.045   noise: 0.032
# Epoch 15/150 - Loss: 0.950   lengthscale: 0.044   noise: 0.034
# Epoch 16/150 - Loss: 0.913   lengthscale: 0.043   noise: 0.037
# Epoch 17/150 - Loss: 0.881   lengthscale: 0.042   noise: 0.039
# Epoch 18/150 - Loss: 0.854   lengthscale: 0.042   noise: 0.042
# Epoch 19/150 - Loss: 0.830   lengthscale: 0.041   noise: 0.044
# Epoch 20/150 - Loss: 0.810   lengthscale: 0.041   noise: 0.047
# Epoch 21/150 - Loss: 0.793   lengthscale: 0.040   noise: 0.049
# Epoch 22/150 - Loss: 0.779   lengthscale: 0.040   noise: 0.052
# Epoch 23/150 - Loss: 0.767   lengthscale: 0.040   noise: 0.054
# Epoch 24/150 - Loss: 0.756   lengthscale: 0.041   noise: 0.057
# Epoch 25/150 - Loss: 0.745   lengthscale: 0.041   noise: 0.059
# Epoch 26/150 - Loss: 0.735   lengthscale: 0.042   noise: 0.062
# Epoch 27/150 - Loss: 0.724   lengthscale: 0.043   noise: 0.064
# Epoch 28/150 - Loss: 0.712   lengthscale: 0.045   noise: 0.067
# Epoch 29/150 - Loss: 0.698   lengthscale: 0.047   noise: 0.069
# Epoch 30/150 - Loss: 0.683   lengthscale: 0.050   noise: 0.071
# Epoch 31/150 - Loss: 0.666   lengthscale: 0.053   noise: 0.074
# Epoch 32/150 - Loss: 0.649   lengthscale: 0.056   noise: 0.076
# Epoch 33/150 - Loss: 0.632   lengthscale: 0.061   noise: 0.078
# Epoch 34/150 - Loss: 0.616   lengthscale: 0.065   noise: 0.080
# Epoch 35/150 - Loss: 0.601   lengthscale: 0.071   noise: 0.082
# Epoch 36/150 - Loss: 0.588   lengthscale: 0.077   noise: 0.084
# Epoch 37/150 - Loss: 0.576   lengthscale: 0.083   noise: 0.085
# Epoch 38/150 - Loss: 0.565   lengthscale: 0.090   noise: 0.087
# Epoch 39/150 - Loss: 0.555   lengthscale: 0.098   noise: 0.089
# Epoch 40/150 - Loss: 0.546   lengthscale: 0.106   noise: 0.090
# Epoch 41/150 - Loss: 0.537   lengthscale: 0.115   noise: 0.092
# Epoch 42/150 - Loss: 0.530   lengthscale: 0.124   noise: 0.093
# Epoch 43/150 - Loss: 0.524   lengthscale: 0.133   noise: 0.094
# Epoch 44/150 - Loss: 0.521   lengthscale: 0.143   noise: 0.095
# Epoch 45/150 - Loss: 0.519   lengthscale: 0.152   noise: 0.096
# Epoch 46/150 - Loss: 0.518   lengthscale: 0.161   noise: 0.097
# Epoch 47/150 - Loss: 0.518   lengthscale: 0.169   noise: 0.098
# Epoch 48/150 - Loss: 0.518   lengthscale: 0.176   noise: 0.099
# Epoch 49/150 - Loss: 0.517   lengthscale: 0.181   noise: 0.100
# Epoch 50/150 - Loss: 0.517   lengthscale: 0.185   noise: 0.101
# Epoch 51/150 - Loss: 0.515   lengthscale: 0.188   noise: 0.101
# Epoch 52/150 - Loss: 0.514   lengthscale: 0.189   noise: 0.102
# Epoch 77/150 - Loss: 0.582   lengthscale: 0.088   noise: 0.116
# Epoch 78/150 - Loss: 0.579   lengthscale: 0.090   noise: 0.117
# Epoch 79/150 - Loss: 0.577   lengthscale: 0.093   noise: 0.117
# Epoch 80/150 - Loss: 0.575   lengthscale: 0.095   noise: 0.118
# Epoch 81/150 - Loss: 0.573   lengthscale: 0.098   noise: 0.118
# Epoch 82/150 - Loss: 0.571   lengthscale: 0.101   noise: 0.119
# Epoch 83/150 - Loss: 0.569   lengthscale: 0.103   noise: 0.119
# Epoch 84/150 - Loss: 0.567   lengthscale: 0.106   noise: 0.120
# Epoch 85/150 - Loss: 0.565   lengthscale: 0.109   noise: 0.120
# Epoch 86/150 - Loss: 0.563   lengthscale: 0.112   noise: 0.121
# Epoch 87/150 - Loss: 0.562   lengthscale: 0.115   noise: 0.121
# Epoch 88/150 - Loss: 0.560   lengthscale: 0.118   noise: 0.121
# Epoch 89/150 - Loss: 0.559   lengthscale: 0.121   noise: 0.122
# Epoch 90/150 - Loss: 0.558   lengthscale: 0.123   noise: 0.122
# Epoch 91/150 - Loss: 0.557   lengthscale: 0.126   noise: 0.122
# Epoch 92/150 - Loss: 0.556   lengthscale: 0.129   noise: 0.123
# Epoch 93/150 - Loss: 0.555   lengthscale: 0.132   noise: 0.123
# Epoch 94/150 - Loss: 0.554   lengthscale: 0.134   noise: 0.123
# Epoch 95/150 - Loss: 0.554   lengthscale: 0.137   noise: 0.124
# Epoch 96/150 - Loss: 0.553   lengthscale: 0.139   noise: 0.124
# Epoch 97/150 - Loss: 0.552   lengthscale: 0.141   noise: 0.124
# Epoch 98/150 - Loss: 0.552   lengthscale: 0.144   noise: 0.125
# Epoch 99/150 - Loss: 0.551   lengthscale: 0.146   noise: 0.125
# Epoch 100/150 - Loss: 0.551   lengthscale: 0.148   noise: 0.125
# Epoch 101/150 - Loss: 0.551   lengthscale: 0.150   noise: 0.125
# Epoch 102/150 - Loss: 0.550   lengthscale: 0.152   noise: 0.126
# Epoch 103/150 - Loss: 0.550   lengthscale: 0.153   noise: 0.126
# Epoch 104/150 - Loss: 0.549   lengthscale: 0.155   noise: 0.126
# Epoch 105/150 - Loss: 0.549   lengthscale: 0.157   noise: 0.126
# Epoch 106/150 - Loss: 0.549   lengthscale: 0.158   noise: 0.126
# Epoch 107/150 - Loss: 0.549   lengthscale: 0.159   noise: 0.126
# Epoch 108/150 - Loss: 0.548   lengthscale: 0.161   noise: 0.127
# Epoch 109/150 - Loss: 0.548   lengthscale: 0.162   noise: 0.127
# Epoch 110/150 - Loss: 0.548   lengthscale: 0.163   noise: 0.127
# Epoch 111/150 - Loss: 0.548   lengthscale: 0.164   noise: 0.127
# Epoch 112/150 - Loss: 0.548   lengthscale: 0.165   noise: 0.127
# Epoch 113/150 - Loss: 0.548   lengthscale: 0.166   noise: 0.127
# Epoch 114/150 - Loss: 0.547   lengthscale: 0.167   noise: 0.127
# Epoch 115/150 - Loss: 0.547   lengthscale: 0.168   noise: 0.127
# Epoch 116/150 - Loss: 0.547   lengthscale: 0.169   noise: 0.127
# Epoch 4/150 - Loss: 2.986   lengthscale: 0.075   noise: 0.013
# Epoch 5/150 - Loss: 2.633   lengthscale: 0.068   noise: 0.015
# Epoch 6/150 - Loss: 2.322   lengthscale: 0.062   noise: 0.016
# Epoch 7/150 - Loss: 2.062   lengthscale: 0.056   noise: 0.018
# Epoch 8/150 - Loss: 1.837   lengthscale: 0.051   noise: 0.019
# Epoch 9/150 - Loss: 1.634   lengthscale: 0.046   noise: 0.021
# Epoch 10/150 - Loss: 1.469   lengthscale: 0.042   noise: 0.023
# Epoch 11/150 - Loss: 1.346   lengthscale: 0.038   noise: 0.025
# Epoch 12/150 - Loss: 1.249   lengthscale: 0.035   noise: 0.027
# Epoch 13/150 - Loss: 1.169   lengthscale: 0.032   noise: 0.029
# Epoch 14/150 - Loss: 1.103   lengthscale: 0.030   noise: 0.031
# Epoch 15/150 - Loss: 1.048   lengthscale: 0.028   noise: 0.034
# Epoch 16/150 - Loss: 1.003   lengthscale: 0.026   noise: 0.036
# Epoch 17/150 - Loss: 0.965   lengthscale: 0.025   noise: 0.038
# Epoch 18/150 - Loss: 0.933   lengthscale: 0.024   noise: 0.040
# Epoch 19/150 - Loss: 0.904   lengthscale: 0.023   noise: 0.043
# Epoch 20/150 - Loss: 0.879   lengthscale: 0.022   noise: 0.045
# Epoch 21/150 - Loss: 0.857   lengthscale: 0.022   noise: 0.047
# Epoch 22/150 - Loss: 0.838   lengthscale: 0.022   noise: 0.050
# Epoch 23/150 - Loss: 0.821   lengthscale: 0.021   noise: 0.052
# Epoch 24/150 - Loss: 0.807   lengthscale: 0.021   noise: 0.054
# Epoch 25/150 - Loss: 0.794   lengthscale: 0.021   noise: 0.057
# Epoch 26/150 - Loss: 0.783   lengthscale: 0.022   noise: 0.059
# Epoch 27/150 - Loss: 0.773   lengthscale: 0.022   noise: 0.061
# Epoch 28/150 - Loss: 0.763   lengthscale: 0.022   noise: 0.063
# Epoch 29/150 - Loss: 0.754   lengthscale: 0.023   noise: 0.065
# Epoch 30/150 - Loss: 0.744   lengthscale: 0.023   noise: 0.067
# Epoch 31/150 - Loss: 0.734   lengthscale: 0.024   noise: 0.069
# Epoch 32/150 - Loss: 0.724   lengthscale: 0.025   noise: 0.071
# Epoch 33/150 - Loss: 0.714   lengthscale: 0.026   noise: 0.073
# Epoch 34/150 - Loss: 0.704   lengthscale: 0.027   noise: 0.075
# Epoch 35/150 - Loss: 0.695   lengthscale: 0.027   noise: 0.077
# Epoch 36/150 - Loss: 0.686   lengthscale: 0.029   noise: 0.078
# Epoch 37/150 - Loss: 0.677   lengthscale: 0.030   noise: 0.080
# Epoch 38/150 - Loss: 0.670   lengthscale: 0.031   noise: 0.082
# Epoch 39/150 - Loss: 0.662   lengthscale: 0.032   noise: 0.083
# Epoch 40/150 - Loss: 0.656   lengthscale: 0.033   noise: 0.085
# Epoch 41/150 - Loss: 0.650   lengthscale: 0.035   noise: 0.086
# Epoch 42/150 - Loss: 0.645   lengthscale: 0.036   noise: 0.088
# Epoch 43/150 - Loss: 0.640   lengthscale: 0.038   noise: 0.089
# Epoch 44/150 - Loss: 0.636   lengthscale: 0.039   noise: 0.090
# Epoch 45/150 - Loss: 0.632   lengthscale: 0.041   noise: 0.091
# Epoch 46/150 - Loss: 0.627   lengthscale: 0.042   noise: 0.093
# Epoch 47/150 - Loss: 0.623   lengthscale: 0.044   noise: 0.094
# Epoch 48/150 - Loss: 0.619   lengthscale: 0.046   noise: 0.095
# Epoch 49/150 - Loss: 0.615   lengthscale: 0.048   noise: 0.096
# Epoch 50/150 - Loss: 0.610   lengthscale: 0.049   noise: 0.097
# Epoch 51/150 - Loss: 0.606   lengthscale: 0.051   noise: 0.098
# Epoch 52/150 - Loss: 0.602   lengthscale: 0.053   noise: 0.099
# Epoch 53/150 - Loss: 0.598   lengthscale: 0.055   noise: 0.100
# Epoch 54/150 - Loss: 0.593   lengthscale: 0.057   noise: 0.101
# Epoch 55/150 - Loss: 0.589   lengthscale: 0.060   noise: 0.102
# Epoch 56/150 - Loss: 0.585   lengthscale: 0.062   noise: 0.103
# Epoch 57/150 - Loss: 0.581   lengthscale: 0.064   noise: 0.104
# Epoch 58/150 - Loss: 0.576   lengthscale: 0.067   noise: 0.104
# Epoch 59/150 - Loss: 0.572   lengthscale: 0.070   noise: 0.105
# Epoch 60/150 - Loss: 0.568   lengthscale: 0.072   noise: 0.106
# Epoch 61/150 - Loss: 0.564   lengthscale: 0.075   noise: 0.107
# Epoch 62/150 - Loss: 0.560   lengthscale: 0.078   noise: 0.108
# Epoch 63/150 - Loss: 0.556   lengthscale: 0.081   noise: 0.108
# Epoch 64/150 - Loss: 0.552   lengthscale: 0.085   noise: 0.109
# Epoch 65/150 - Loss: 0.548   lengthscale: 0.088   noise: 0.110
# Epoch 66/150 - Loss: 0.544   lengthscale: 0.092   noise: 0.110
# Epoch 67/150 - Loss: 0.540   lengthscale: 0.095   noise: 0.111
# Epoch 68/150 - Loss: 0.537   lengthscale: 0.099   noise: 0.112
# Epoch 69/150 - Loss: 0.533   lengthscale: 0.103   noise: 0.112
# Epoch 70/150 - Loss: 0.530   lengthscale: 0.107   noise: 0.113
# Epoch 71/150 - Loss: 0.528   lengthscale: 0.112   noise: 0.113
# Epoch 72/150 - Loss: 0.525   lengthscale: 0.116   noise: 0.114
# Epoch 73/150 - Loss: 0.523   lengthscale: 0.120   noise: 0.114
# Epoch 74/150 - Loss: 0.521   lengthscale: 0.124   noise: 0.115
# Epoch 75/150 - Loss: 0.520   lengthscale: 0.129   noise: 0.115
# Epoch 76/150 - Loss: 0.518   lengthscale: 0.133   noise: 0.116
# Epoch 77/150 - Loss: 0.517   lengthscale: 0.137   noise: 0.116
# Epoch 78/150 - Loss: 0.516   lengthscale: 0.140   noise: 0.116
# Epoch 79/150 - Loss: 0.515   lengthscale: 0.144   noise: 0.117
# Epoch 80/150 - Loss: 0.514   lengthscale: 0.148   noise: 0.117
# Epoch 81/150 - Loss: 0.513   lengthscale: 0.151   noise: 0.118
# Epoch 82/150 - Loss: 0.512   lengthscale: 0.154   noise: 0.118
# Epoch 123/150 - Loss: 0.507   lengthscale: 0.187   noise: 0.120
# Epoch 124/150 - Loss: 0.507   lengthscale: 0.187   noise: 0.120
# Epoch 125/150 - Loss: 0.507   lengthscale: 0.187   noise: 0.120
# Epoch 126/150 - Loss: 0.507   lengthscale: 0.187   noise: 0.120
# Epoch 127/150 - Loss: 0.507   lengthscale: 0.187   noise: 0.120
# Epoch 128/150 - Loss: 0.507   lengthscale: 0.187   noise: 0.120
# Epoch 129/150 - Loss: 0.507   lengthscale: 0.187   noise: 0.120
# Epoch 130/150 - Loss: 0.507   lengthscale: 0.187   noise: 0.120
# Epoch 131/150 - Loss: 0.507   lengthscale: 0.186   noise: 0.120
# Epoch 132/150 - Loss: 0.507   lengthscale: 0.186   noise: 0.120
# Epoch 133/150 - Loss: 0.507   lengthscale: 0.186   noise: 0.120
# Epoch 134/150 - Loss: 0.507   lengthscale: 0.186   noise: 0.120
# Epoch 135/150 - Loss: 0.507   lengthscale: 0.186   noise: 0.120
# Epoch 136/150 - Loss: 0.507   lengthscale: 0.186   noise: 0.120
# Epoch 137/150 - Loss: 0.507   lengthscale: 0.186   noise: 0.120
# Epoch 138/150 - Loss: 0.507   lengthscale: 0.186   noise: 0.120
# Epoch 139/150 - Loss: 0.507   lengthscale: 0.186   noise: 0.120
# Epoch 140/150 - Loss: 0.507   lengthscale: 0.186   noise: 0.120
# Epoch 141/150 - Loss: 0.507   lengthscale: 0.185   noise: 0.120
# Epoch 142/150 - Loss: 0.507   lengthscale: 0.185   noise: 0.120
# Epoch 143/150 - Loss: 0.507   lengthscale: 0.185   noise: 0.120
# Epoch 144/150 - Loss: 0.507   lengthscale: 0.185   noise: 0.120
# Epoch 145/150 - Loss: 0.507   lengthscale: 0.185   noise: 0.120
# Epoch 146/150 - Loss: 0.507   lengthscale: 0.185   noise: 0.120
# Epoch 147/150 - Loss: 0.507   lengthscale: 0.185   noise: 0.120
# Epoch 148/150 - Loss: 0.507   lengthscale: 0.185   noise: 0.120
# Epoch 149/150 - Loss: 0.507   lengthscale: 0.185   noise: 0.120
# Epoch 150/150 - Loss: 0.507   lengthscale: 0.185   noise: 0.120
# Step: 10, Val-Loss: 0.2940
# [-0.926515    0.4083023   0.7918408  ... -0.9970535   0.8468981
#  -0.80492735]
# Step: 10 of 10, time-taken: 11.96 seconds

# %%
preds
# Out:
# MultivariateNormal(loc: torch.Size([1900]))

# %%
preds[0].mean.numpy()
# Out:
# array(-0.926515, dtype=float32)

# %%
len(preds.stddev)
# Out:
# 1900

# %%
plt.figure(figsize=(20, 6))  # Set the figure size to be wider
plt.plot(preds.stddev.numpy())
plt.xlabel('Data Point')
plt.ylabel('Standard Deviation')
plt.title('Standard Deviation Plot')
plt.show()

# %%
count = len(preds.stddev[preds.stddev > 0.4])
print(count)
count = len(preds.stddev[preds.stddev > 0.39])
print(count)
count = len(preds.stddev[preds.stddev > 0.38])
print(count)
count = len(preds.stddev[preds.stddev > 0.37])
print(count)
# Out:
# 4
# 25
# 53
# 108
